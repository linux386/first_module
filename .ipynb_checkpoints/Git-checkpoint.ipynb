import pandas as pd
from bs4 import BeautifulSoup
import datetime as date
from urllib.request import urlopen

# 사용자의 PC내 폴더 주소를 입력하시면 됩니다.

def get_money_trend():
    folder_adress = 'd:\\'
    file_name = 'pre_mondy_trend.xlsx'
        
    url = 'http://finance.naver.com/sise/sise_deposit.nhn?&page='
    source = urlopen(url).read()
    source = BeautifulSoup(source,'lxml')
    last = source.find('td',class_='pgRR').find('a')['href']
    last = last.split('&')[1]
    last = last.split('=')[1]
    last = int(last)
    
    Data = pd.DataFrame(columns = ['고객예탁금', '신용잔고','주식형 펀드','혼합형 펀드','채권형 펀드'])

    # 날짜를 받을 리스트
    date_list = []
        
    # 값을 받을 사전
    dictionary = {'고객예탁금': [],'신용잔고': [],'주식형 펀드': [],'혼합형 펀드': [],'채권형 펀드': []}

    # dictionary key 인덱싱을 위한 리스트
    name_list = ['고객예탁금','신용잔고','주식형 펀드','혼합형 펀드','채권형 펀드']

    # count mask
    mask = [0,1,3,5,7,9]
    
    for i in range(1,last+5):
        source = urlopen(url+ str(i)).read()
        source = BeautifulSoup(source,'lxml')

        tbody = source.find('div',{'id':'wrap'}).find('div',{'class':'box_type_m'})
        trs = tbody.find_all('tr')

        for tr in trs:
            tds = tr.find_all('td')
            count = 0
            for td in tds:
                # 변화량 제외하고 잔고량만 가져오기
                if not td.text.strip() == 0:
                    if len(td.text.strip()) >= 4:
            
                        if count == 0:
                            date_ = td.text.strip().replace('.','-')
                        
                            if not date_ in date_list:
                                date_list.append(date_)
                            
                            else:
                                print(str(i-1) + '번째 페이지에서 크롤링 종료')
                                
                                data = DataFrame(dictionary,index = date_list)
                                data.to_csv(folder_adress + '/money_trend.csv')
    
                                return data

                        elif count in mask:
                            temp = int((count-1)/2)
                            dictionary[name_list[temp]].append(td.text.strip())
        
                    count += 1
            
            # 누락된 값을 발견하면 (펀드 자료에 누락된 값이 존재함)
            if len(dictionary['고객예탁금']) != len(dictionary['주식형 펀드']):
                print(str(i)+ '번째 페이지에서 누락된 값 발생')
                print('누락된 데이터를 제거합니다')
                    
                date_list.pop(-1)
                dictionary['고객예탁금'].pop(-1)
                dictionary['신용잔고'].pop(-1)
                
        print(str(i) + '번째 페이지 크롤링 완료')

# %%
get_money_trend()
# Out:
# 1번째 페이지 크롤링 완료
# 2번째 페이지 크롤링 완료
# 3번째 페이지 크롤링 완료
# 4번째 페이지 크롤링 완료
# 5번째 페이지 크롤링 완료
# 6번째 페이지 크롤링 완료
# 7번째 페이지 크롤링 완료
# 8번째 페이지 크롤링 완료
# 9번째 페이지 크롤링 완료
# 10번째 페이지 크롤링 완료
# 11번째 페이지 크롤링 완료
# 12번째 페이지 크롤링 완료
# 13번째 페이지 크롤링 완료
# 14번째 페이지 크롤링 완료
# 15번째 페이지 크롤링 완료
# 16번째 페이지 크롤링 완료
# 17번째 페이지 크롤링 완료
# 18번째 페이지 크롤링 완료
# 19번째 페이지 크롤링 완료
# 20번째 페이지 크롤링 완료
# 21번째 페이지 크롤링 완료
# 22번째 페이지 크롤링 완료
# 23번째 페이지 크롤링 완료
# 24번째 페이지 크롤링 완료
# 25번째 페이지 크롤링 완료
# 26번째 페이지 크롤링 완료
# 27번째 페이지 크롤링 완료
# 28번째 페이지 크롤링 완료
# 29번째 페이지 크롤링 완료
# 30번째 페이지 크롤링 완료
# 31번째 페이지 크롤링 완료
# 32번째 페이지 크롤링 완료
# 33번째 페이지 크롤링 완료
# 34번째 페이지 크롤링 완료
# 35번째 페이지 크롤링 완료
# 36번째 페이지 크롤링 완료
# 37번째 페이지 크롤링 완료
# 38번째 페이지 크롤링 완료
# 39번째 페이지 크롤링 완료
# 40번째 페이지 크롤링 완료
# 41번째 페이지 크롤링 완료
# 42번째 페이지 크롤링 완료
# 43번째 페이지 크롤링 완료
# 44번째 페이지 크롤링 완료
# 45번째 페이지 크롤링 완료
# 46번째 페이지 크롤링 완료
# 47번째 페이지 크롤링 완료
# 48번째 페이지 크롤링 완료
# 49번째 페이지 크롤링 완료
# 50번째 페이지 크롤링 완료
# 51번째 페이지 크롤링 완료
# 52번째 페이지 크롤링 완료
# 53번째 페이지 크롤링 완료
# 54번째 페이지 크롤링 완료
# 55번째 페이지 크롤링 완료
# 56번째 페이지 크롤링 완료
# 57번째 페이지 크롤링 완료
# 58번째 페이지 크롤링 완료
# 59번째 페이지 크롤링 완료
# 60번째 페이지 크롤링 완료
# 61번째 페이지 크롤링 완료
# 62번째 페이지 크롤링 완료
# 63번째 페이지 크롤링 완료
# 64번째 페이지 크롤링 완료
# 65번째 페이지 크롤링 완료
# 66번째 페이지 크롤링 완료
# 67번째 페이지 크롤링 완료
# 68번째 페이지 크롤링 완료
# 69번째 페이지 크롤링 완료
# 70번째 페이지 크롤링 완료
# 71번째 페이지 크롤링 완료
# 72번째 페이지 크롤링 완료
# 73번째 페이지 크롤링 완료
# 74번째 페이지 크롤링 완료
# 75번째 페이지 크롤링 완료
# 76번째 페이지 크롤링 완료
# 77번째 페이지 크롤링 완료
# 78번째 페이지 크롤링 완료
# 79번째 페이지 크롤링 완료
# 80번째 페이지 크롤링 완료
# 81번째 페이지 크롤링 완료
# 82번째 페이지 크롤링 완료
# 83번째 페이지 크롤링 완료
# 84번째 페이지 크롤링 완료
# 85번째 페이지 크롤링 완료
# 86번째 페이지 크롤링 완료
# 87번째 페이지 크롤링 완료
# 88번째 페이지 크롤링 완료
# 89번째 페이지 크롤링 완료
# 90번째 페이지 크롤링 완료
# 91번째 페이지 크롤링 완료
# 92번째 페이지 크롤링 완료
# 93번째 페이지 크롤링 완료
# 94번째 페이지 크롤링 완료
# 95번째 페이지 크롤링 완료
# 96번째 페이지 크롤링 완료
# 97번째 페이지 크롤링 완료
# 98번째 페이지 크롤링 완료
# 99번째 페이지 크롤링 완료
# 100번째 페이지 크롤링 완료
# 101번째 페이지 크롤링 완료
# 102번째 페이지 크롤링 완료
# 103번째 페이지 크롤링 완료
# 104번째 페이지 크롤링 완료
# 105번째 페이지 크롤링 완료
# 106번째 페이지 크롤링 완료
# 107번째 페이지 크롤링 완료
# 108번째 페이지 크롤링 완료
# 109번째 페이지 크롤링 완료
# 110번째 페이지 크롤링 완료
# 111번째 페이지 크롤링 완료
# 112번째 페이지 크롤링 완료
# 113번째 페이지 크롤링 완료
# 114번째 페이지 크롤링 완료
# 115번째 페이지 크롤링 완료
# 116번째 페이지 크롤링 완료
# 117번째 페이지 크롤링 완료
# 118번째 페이지 크롤링 완료
# 119번째 페이지 크롤링 완료
# 120번째 페이지 크롤링 완료
# 121번째 페이지 크롤링 완료
# 122번째 페이지 크롤링 완료
# 123번째 페이지에서 누락된 값 발생
# 누락된 데이터를 제거합니다
# 123번째 페이지 크롤링 완료
# 124번째 페이지 크롤링 완료
# 125번째 페이지 크롤링 완료
# 126번째 페이지 크롤링 완료
# 127번째 페이지 크롤링 완료
# 128번째 페이지 크롤링 완료
# 129번째 페이지 크롤링 완료
# 130번째 페이지 크롤링 완료
# 131번째 페이지 크롤링 완료
# 132번째 페이지 크롤링 완료
# 133번째 페이지 크롤링 완료
# 134번째 페이지 크롤링 완료
# 135번째 페이지 크롤링 완료
# 136번째 페이지 크롤링 완료
# 137번째 페이지 크롤링 완료
# 138번째 페이지 크롤링 완료
# 139번째 페이지 크롤링 완료
# 140번째 페이지 크롤링 완료
# 141번째 페이지 크롤링 완료
# 142번째 페이지 크롤링 완료
# 143번째 페이지 크롤링 완료
# 144번째 페이지 크롤링 완료
# 145번째 페이지 크롤링 완료
# 146번째 페이지 크롤링 완료
# 147번째 페이지 크롤링 완료
# 148번째 페이지 크롤링 완료
# 149번째 페이지 크롤링 완료
# 150번째 페이지 크롤링 완료
# 151번째 페이지 크롤링 완료
# 152번째 페이지 크롤링 완료
# 153번째 페이지 크롤링 완료
# 154번째 페이지 크롤링 완료
# 155번째 페이지 크롤링 완료
# 156번째 페이지 크롤링 완료
# 157번째 페이지 크롤링 완료
# 158번째 페이지 크롤링 완료
# 159번째 페이지 크롤링 완료
# 160번째 페이지 크롤링 완료
# 161번째 페이지 크롤링 완료
# 162번째 페이지 크롤링 완료
# 163번째 페이지 크롤링 완료
# 164번째 페이지 크롤링 완료
# 165번째 페이지 크롤링 완료
# 166번째 페이지 크롤링 완료
# 167번째 페이지 크롤링 완료
# 168번째 페이지 크롤링 완료
# 169번째 페이지 크롤링 완료
# 170번째 페이지 크롤링 완료
# 171번째 페이지 크롤링 완료
# 172번째 페이지 크롤링 완료
# 173번째 페이지 크롤링 완료
# 174번째 페이지 크롤링 완료
# 175번째 페이지 크롤링 완료
# 176번째 페이지 크롤링 완료
# 177번째 페이지 크롤링 완료
# 178번째 페이지 크롤링 완료
# 179번째 페이지 크롤링 완료
# 180번째 페이지 크롤링 완료
# 181번째 페이지 크롤링 완료
# 182번째 페이지 크롤링 완료
# 183번째 페이지 크롤링 완료
# 184번째 페이지 크롤링 완료
# 185번째 페이지 크롤링 완료
# 186번째 페이지 크롤링 완료
# 187번째 페이지 크롤링 완료
# 188번째 페이지 크롤링 완료
# 189번째 페이지 크롤링 완료
# 190번째 페이지 크롤링 완료
# 191번째 페이지 크롤링 완료
# 192번째 페이지 크롤링 완료
# 193번째 페이지 크롤링 완료
# 194번째 페이지 크롤링 완료
# 195번째 페이지 크롤링 완료
# 196번째 페이지 크롤링 완료
# 197번째 페이지 크롤링 완료
# 198번째 페이지 크롤링 완료
# 199번째 페이지 크롤링 완료
# 200번째 페이지 크롤링 완료
# 201번째 페이지 크롤링 완료
# 202번째 페이지 크롤링 완료
# 203번째 페이지 크롤링 완료
# 204번째 페이지 크롤링 완료
# 205번째 페이지 크롤링 완료
# 206번째 페이지 크롤링 완료
# 207번째 페이지 크롤링 완료
# 207번째 페이지에서 크롤링 종료
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-76c6796fe951> in <module>
# ----> 1 get_money_trend()
#
# <ipython-input-13-5d83eca93b22> in get_money_trend()
#      57                                 print(str(i-1) + '번째 페이지에서 크롤링 종료')
#      58
# ---> 59                                 data = DataFrame(dictionary,index = date_list)
#      60                                 data.to_csv(folder_adress + '/money_trend.csv')
#      61
#
# NameError: name 'DataFrame' is not defined

# %%
df = pd.read_excel('d:\\pre_mondy_trend.xlsx')
df = df.sort_index()
df.to_excel('d:\\money_trends.xlsx')
