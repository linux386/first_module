# %%
import mod1

# %%
mod1.stock_select_with_Volume_Close()
# Out:
# 어제날짜를 입력하세요 : sample: '2019-02-07'  2019-02-20
# 오늘날짜를 입력하세요 : sample: '2019-02-07'  2019-02-21
#      Name  yester_Volume  yester_Close  today_Volume  today_Close     Close  \
# 0    케이사인         673265          1270      31269914         1650  1.299213
# 1     시큐브        1457903          1715      36498204         2000  1.166181
# 2   스포츠서울        1142356          1375      11021756         1745  1.269091
# 3   골든센츄리        2761149           953      21877878         1000  1.049318
# 4  우리기술투자        1561719          2780      10533225         2975  1.070144
# 5   파워로직스         575163          8360       3604355         8000  0.956938
# 6    이엘케이        2386465           829      14302050          866  1.044632
# 7   와이비엠넷        1082040          4950       4679956         5480  1.107071
# 8     디피씨        2085489          6650       8957974         7090  1.066165
# 9  한류AI센터        1374878          3690       5786876         3870  1.048780
#
#       Volume
# 0  46.445180
# ...

# %%
mod1.stock_price_graph()
# Out:
# 주식이름을 입력하세요:케이사인 시큐브 한류AI센터
# 날짜를 입력하세요 sample: '2019-01-10':2018-01-01

# %%
mod1.money_trend_graph()
# Out:
# 항목을 입력하세요: 선택항목: 'kpi200', '거래량', '고객예탁금', '신용잔고', '주식형펀드', '혼합형펀드', '채권형펀드'거래량 고객예탁금 신용잔고
# 날짜를 입력하세요 sample: '2019-01-10':2018-01-01

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined
