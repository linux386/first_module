# %%
import mod1

# %%
a = mod1.to_report()

# %%
a.stock_select_with_Volume_Close(type=2)
# Out:
#        Name  yester_Volume  yester_Close  today_Volume  today_Close     Close  \
# 0    제이씨케미칼        1005075          4915      16566786         5930  1.206511
# 1     세우글로벌        1033694          1830      13053716         1995  1.090164
# 2      한신기계         524796          1740       5147353         1755  1.008621
# 3      에프알텍         886245          6150       6612056         7450  1.211382
# 4    텔콘RF제약         816663          5090       5923865         4740  0.931238
# 5    서암기계공업        1956192          6750      13966509         8160  1.208889
# 6      두올산업        1305775           789       8821923          822  1.041825
# 7      메가엠디        1005198          2670       5661744         2645  0.990637
# 8   우리손에프앤지        1802221          2250       8999438         2325  1.033333
# 9     화인베스틸         520731          3295       2295113         3355  1.018209
# 10       인콘        1721305          1540       7582067         1610  1.045455
# ...

# %%
df3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-3357e37d2add> in <module>
# ----> 1 df3
#
# NameError: name 'df3' is not defined

# %%
a.get_graph(type=2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-f165cd38708d> in <module>
# ----> 1 a.get_graph(type=2)
#
# ~\notebook\Git\first_module\mod1.py in get_graph(self, type)
#     333                     plt.figure(figsize=(16,4))
#     334                     for i in range(len(basis_name)):
# --> 335                         plt.plot(basis_df1[basis_name[i]]/basis_df1[basis_name[i]].loc[basis_df.index[0]]*100)
#     336
#     337                     plt.legend(loc=0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    3956         if is_scalar(key):
#    3957             key = com.cast_scalar_indexer(key)
# -> 3958             return getitem(key)
#    3959
#    3960         if isinstance(key, slice):
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
mod1.get_graph()
# Out:
# 그래프종류를 입력하세요 sample: 'money' or 'program' or 'stock': money
# 날짜를 입력하세요 sample: '2019-01-10':2019-01-01

# %%
mod1.get_graph()
# Out:
# 그래프종류를 입력하세요 sample: 'money' or 'program' or 'stock': program
# 날짜를 입력하세요 sample: '2019-01-10':2019-01-01
