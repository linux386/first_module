# %%
import mod1

# %%
a = mod1.to_report()

# %%
a.stock_select_with_Volume_Close(type=2)
# Out:
#          Name  yester_Volume  yester_Close  today_Volume  today_Close  \
# 0        삼륭물산         501133          7260      11445448         8690
# 1          켐온         892589          1580      10888078         1680
# 2        디에스티        1166574           653      12363612          735
# 3        일지테크        3925687          5250      35291004         6560
# 4        모나리자        1102388          3650       9740694         3750
# 5        삼익악기         526993          1815       4223294         1820
# 6         모나미        4164889          5900      25116876         6930
# 7        화신테크         822772          2760       4896210         3090
# 8   퓨쳐스트림네트웍스        2789008          1365      16045421         1480
# 9        삼본전자        1094688          2845       5936093         3100
# 10     아가방컴퍼니        1068940          3360       5428306         3455
# 11     토박스코리아        1146855          1175       5205834         1195
# ...

# %%
a.get_graph(type=2)
