# %%
## kpi200 - stock price (kpi200 astype(float))
## limit == loc[dt.date(2006,1,3)]

import FinanceDataReader as fdr
import pandas as pd
from bs4 import BeautifulSoup
import datetime as dt
from urllib.request import urlopen
import sqlalchemy 
import pymysql
pymysql.install_as_MySQLdb() # MySQLdb와 호환 
import MySQLdb
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
# %matplotlib inline

now = dt.datetime.today().strftime('%Y-%m-%d')
engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
conn = engine.connect()

def graph(sql1,sql2):
    df=pd.read_sql(sql1, con=engine)
    df.columns=['Date','삼성전자']


    df1=pd.read_sql(sql2, con= engine)
    df1['kpi200']=df1['kpi200'].astype(float)
    df1.rename(columns={'DATE(Date)':'Date'}, inplace=True)

    df2 = pd.merge(df,df1,on='Date')
    df2.columns=['Date','삼성전자','KPI200']
    df2=df2.set_index('Date')

    plt.figure(figsize=(12,5))
    plt.plot(df2['삼성전자']/df2['삼성전자'].loc[dt.date(2017,1,2)]*100)
    plt.plot(df2['KPI200']/df2['KPI200'].loc[dt.date(2017,1,2)]*100)
    plt.legend(loc=0)
    plt.grid(True,color='0.7',linestyle=':',linewidth=1)

# %%
graph("select DATE(Date),Close from kospi where Name='삼성전자' and Date > '2017-01-01'","select DATE(Date),kpi200 from kpi200 where Date > '2017-01-01'")

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

connect = create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')

l = ['삼성전자','일진전기','포스코','풍산']

t = tuple(l)

df = pd.read_sql("select * from kospi where Name IN {} && Date > '2019-01-19'".format(t),connect)
df
# Out:
#                    Date    Code  Name    Open    High     Low    Volume  \
# 0   2019-01-21 00:00:00  005930  삼성전자   42700   42750   41900  11355701
# 1   2019-01-22 00:00:00  005930  삼성전자   42750   42850   41850   9964356
# 2   2019-01-23 00:00:00  005930  삼성전자   41350   42250   41350  11071079
# 3   2019-01-24 00:00:00  005930  삼성전자   43050   43100   42350  14747623
# 4   2019-01-25 00:00:00  005930  삼성전자   44300   44750   43750  22789395
# 5   2019-01-28 00:00:00  005930  삼성전자   45000   45500   44600  17998914
# 6   2019-01-29 00:00:00  005930  삼성전자   45050   45500   44350  16215017
# 7   2019-01-30 00:00:00  005930  삼성전자   44800   46400   44800  17505980
# 8   2019-01-31 00:00:00  005930  삼성전자   46650   47050   46150  21621145
# 9   2019-02-01 00:00:00  005930  삼성전자   46650   46950   46250  13627887
# 10  2019-01-21 00:00:00  103590  일진전기    3425    3645    3420    212237
# 11  2019-01-22 00:00:00  103590  일진전기    3480    3550    3420     99474
# 12  2019-01-23 00:00:00  103590  일진전기    3490    3510    3405     80228
# 13  2019-01-24 00:00:00  103590  일진전기    3455    3530    3450     60951
# 14  2019-01-25 00:00:00  103590  일진전기    3490    3530    3410     63917
# 15  2019-01-28 00:00:00  103590  일진전기    3510    3545    3500     39871
# 16  2019-01-29 00:00:00  103590  일진전기    3530    3530    3430     69133
# 17  2019-01-30 00:00:00  103590  일진전기    3500    3540    3415     38622
# 18  2019-01-31 00:00:00  103590  일진전기    3480    3540    3435     56262
# 19  2019-02-01 00:00:00  103590  일진전기    3440    3540    3440     63575
# 20  2019-01-21 00:00:00  005490   포스코  265500  269500  265000    247916
# 21  2019-01-22 00:00:00  005490   포스코  269000  270500  266000    253465
# 22  2019-01-23 00:00:00  005490   포스코  265500  269000  260000    200955
# 23  2019-01-24 00:00:00  005490   포스코  261500  267000  261000    309534
# 24  2019-01-25 00:00:00  005490   포스코  262500  270000  262000    281853
# 25  2019-01-28 00:00:00  005490   포스코  268500  272500  266000    248313
# 26  2019-01-29 00:00:00  005490   포스코  266000  268500  264000    180807
# 27  2019-01-30 00:00:00  005490   포스코  274500  285000  271000    549605
# 28  2019-01-31 00:00:00  005490   포스코  288500  289000  274000    408983
# 29  2019-02-01 00:00:00  005490   포스코  273000  275500  270000    274106
# 30  2019-01-21 00:00:00  103140    풍산   30200   30900   30050    105874
# 31  2019-01-22 00:00:00  103140    풍산   30450   30450   29550     71151
# 32  2019-01-23 00:00:00  103140    풍산   29450   30150   29200     85331
# 33  2019-01-24 00:00:00  103140    풍산   29800   30000   29450     69831
# 34  2019-01-25 00:00:00  103140    풍산   29400   29700   29100     81340
# 35  2019-01-28 00:00:00  103140    풍산   29450   29900   29250     94463
# 36  2019-01-29 00:00:00  103140    풍산   29550   29600   28750     94558
# 37  2019-01-30 00:00:00  103140    풍산   29550   29900   29200     87422
# 38  2019-01-31 00:00:00  103140    풍산   30100   30650   29550    107190
# 39  2019-02-01 00:00:00  103140    풍산   30200   31050   30200    122450
#
#      Close
# 0    42750
# 1    42150
# 2    42000
# 3    43050
# 4    44750
# 5    45050
# 6    45500
# 7    46400
# 8    46150
# 9    46350
# 10    3470
# 11    3465
# 12    3490
# 13    3460
# 14    3490
# 15    3525
# 16    3470
# 17    3465
# 18    3435
# 19    3540
# 20  268000
# 21  267000
# 22  265000
# 23  264500
# 24  268000
# 25  269000
# 26  268500
# 27  285000
# 28  274000
# 29  270500
# 30   30450
# 31   29700
# 32   29650
# 33   29450
# 34   29500
# 35   29550
# 36   29200
# 37   29850
# 38   30500
# 39   30950

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

connect = create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')

select_query = "select * from kospi where Name= "

ids = ['삼성전자','일진전기','포스코','풍산']
tds = tuple(ids)

for x in tds:
    print(x)
    var = select_query +"'"+x+"'"
    print(var)
    df = pd.read_sql(var ,connect)
    print(df)
    #df = pd.read_sql("select * from kospi where Name IN {} && Date > '2019-01-19'".format(t),connect)
    #df = pd.read_sql(select_query + x ,connect)
    #df
# Out:
# 삼성전자
# select * from kospi where Name= '삼성전자'
#                      Date    Code  Name   Open   High    Low    Volume  Close
# 0     1995-05-27 00:00:00  005930  삼성전자   1382   1395   1369     65050   1370
# 1     1995-05-29 00:00:00  005930  삼성전자   1421   1440   1395    180720   1441
# 2     1995-05-30 00:00:00  005930  삼성전자   1434   1434   1408     78620   1408
# 3     1995-05-31 00:00:00  005930  삼성전자   1395   1427   1395     70670   1428
# 4     1995-06-01 00:00:00  005930  삼성전자   1440   1460   1440     70290   1460
# 5     1995-06-02 00:00:00  005930  삼성전자   1466   1531   1466    178650   1512
# 6     1995-06-03 00:00:00  005930  삼성전자   1511   1524   1492     74450   1512
# 7     1995-06-05 00:00:00  005930  삼성전자   1511   1563   1511    214900   1564
# 8     1995-06-07 00:00:00  005930  삼성전자   1576   1582   1537    191590   1564
# 9     1995-06-08 00:00:00  005930  삼성전자   1569   1582   1544    325580   1544
# 10    1995-06-09 00:00:00  005930  삼성전자   1537   1557   1518    344100   1538
# 11    1995-06-10 00:00:00  005930  삼성전자   1537   1557   1531    130030   1538
# 12    1995-06-12 00:00:00  005930  삼성전자   1544   1550   1531    204520   1551
# 13    1995-06-13 00:00:00  005930  삼성전자   1550   1569   1544    161140   1544
= select_query +"'"+x+"'"+" "+"&&"+" "+date_query+"'"+date+"'"
    #var = select_query +"'"+x+"'"
    #var = "select * from kospi where Name= '삼성전자' and Date > '2019-01-11'"
    #var = "select DATE(Date),Close from kospi where Name='삼성전자' and Date > '2019-01-01'"
    print(var)
    df = pd.read_sql(var ,connect)
    df.columns=['Date',x]
    print(df)
# Out:
# 삼성전자
# select DATE(Date),Close from kospi where Name= '삼성전자' && Date > '2019-01-10'
#           Date   삼성전자
# 0   2019-01-10  39800
# 1   2019-01-11  40500
# 2   2019-01-14  40050
# 3   2019-01-15  41100
# 4   2019-01-16  41450
# 5   2019-01-17  41950
# 6   2019-01-18  42300
# 7   2019-01-21  42750
# 8   2019-01-22  42150
# 9   2019-01-23  42000
# 10  2019-01-24  43050
# 11  2019-01-25  44750
# 12  2019-01-28  45050
# 13  2019-01-29  45500
# 14  2019-01-30  46400
# 15  2019-01-31  46150
# 16  2019-02-01  46350
# 일진전기
# select DATE(Date),Close from kospi where Name= '일진전기' && Date > '2019-01-10'
#           Date  일진전기
# 0   2019-01-10  3285
# 1   2019-01-11  3340
# 2   2019-01-14  3365
# 3   2019-01-15  3385
# 4   2019-01-16  3440
# 5   2019-01-17  3390
# 6   2019-01-18  3420
# 7   2019-01-21  3470
# 8   2019-01-22  3465
# 9   2019-01-23  3490
# 10  2019-01-24  3460
# 11  2019-01-25  3490
# 12  2019-01-28  3525
# 13  2019-01-29  3470
# 14  2019-01-30  3465
# 15  2019-01-31  3435
# 16  2019-02-01  3540
# 포스코
# select DATE(Date),Close from kospi where Name= '포스코' && Date > '2019-01-10'
#           Date     포스코
# 0   2019-01-14  250000
# 1   2019-01-15  256500
# 2   2019-01-16  263500
# 3   2019-01-17  263000
# 4   2019-01-18  262500
# 5   2019-01-21  268000
# 6   2019-01-22  267000
# 7   2019-01-23  265000
# 8   2019-01-24  264500
# 9   2019-01-25  268000
# 10  2019-01-28  269000
# 11  2019-01-29  268500
# 12  2019-01-30  285000
# 13  2019-01-31  274000
# 14  2019-02-01  270500
# 풍산
# select DATE(Date),Close from kospi where Name= '풍산' && Date > '2019-01-10'
#           Date     풍산
# 0   2019-01-10  29500
# 1   2019-01-11  29450
# 2   2019-01-14  28600
# 3   2019-01-15  29300
# 4   2019-01-16  29350
# 5   2019-01-17  29150
# 6   2019-01-18  30200
# 7   2019-01-21  30450
# 8   2019-01-22  29700
# 9   2019-01-23  29650
# 10  2019-01-24  29450
# 11  2019-01-25  29500
# 12  2019-01-28  29550
# 13  2019-01-29  29200
# 14  2019-01-30  29850
# 15  2019-01-31  30500
# 16  2019-02-01  30950

# %%
## kpi200 - stock price (kpi200 astype(float))
## limit == loc[dt.date(2006,1,3)]

import FinanceDataReader as fdr
import pandas as pd
from bs4 import BeautifulSoup
import datetime as dt
from urllib.request import urlopen
import sqlalchemy 
import pymysql
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
# %matplotlib inline

now = dt.datetime.today().strftime('%Y-%m-%d')
engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
conn = engine.connect()

def graph():
    
    name = input('주식이름을 입력하세요:')
    date = input("'날짜를 입력하세요 sample '2019-01-10':")
    table= input('write table name:')
    date_query = "Date > "
    
    select_query = "select DATE(Date),Close from"+" "+table+" "+"where Name=""'"+name+"'"+"&&"+" "+date_query+"'"+date+"'"
    print(select_query)
    
    
    df=pd.read_sql(select_query, con=engine)
    return df
                 
graph()
# Out:
# 주식이름을 입력하세요:삼성전자
# '날짜를 입력하세요 sample '2019-01-10':2019-01-10
# write table name:kospi
# select DATE(Date),Close from kospi where Name='삼성전자'&& Date > '2019-01-10'
#     DATE(Date)  Close
# 0   2019-01-10  39800
# 1   2019-01-11  40500
# 2   2019-01-14  40050
# 3   2019-01-15  41100
# 4   2019-01-16  41450
# 5   2019-01-17  41950
# 6   2019-01-18  42300
# 7   2019-01-21  42750
# 8   2019-01-22  42150
# 9   2019-01-23  42000
# 10  2019-01-24  43050
# 11  2019-01-25  44750
# 12  2019-01-28  45050
# 13  2019-01-29  45500
# 14  2019-01-30  46400
# 15  2019-01-31  46150
# 16  2019-02-01  46350

# %%
## kpi200 - stock price (kpi200 astype(float))
## limit == loc[dt.date(2006,1,3)]

import FinanceDataReader as fdr
import pandas as pd
from bs4 import BeautifulSoup
import datetime as dt
from urllib.request import urlopen
import sqlalchemy 
import pymysql
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
# %matplotlib inline

now = dt.datetime.today().strftime('%Y-%m-%d')
engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
conn = engine.connect()

def graph():
    
    name = input('주식이름을 입력하세요:').split()
    date = input("'날짜를 입력하세요 sample '2019-01-10':")
    table= input('write table name:')
    
    select_query = "select DATE(Date),Close from kospi where Name= "
    date_query = "Date > "
    
    #select_query = "select DATE(Date),Close from"+" "+table+" "+"where Name=""'"+name+"'"+"&&"+" "+date_query+"'"+date+"'"
    
    print(select_query)
    tuple_name=tuple(name)
    
    for x in tuple_name:
        print(x)
        df1 = pd.DataFrame()
        var = select_query +"'"+x+"'"+" "+"&&"+" "+date_query+"'"+date+"'"
        #var = select_query +"'"+x+"'"
        #var = "select * from kospi where Name= '삼성전자' and Date > '2019-01-11'"
        #var = "select DATE(Date),Close from kospi where Name='삼성전자' and Date > '2019-01-01'"
        print(var)
        df = pd.read_sql(var ,connect)
        df.columns=['Date',x]
        #df1.concat(df, axis = 1)
        #print(df1)
        print(df)
        df=df.set_index('Date')
        plt.figure(figsize=(12,5))
        plt.plot(df[x]/df[x].loc[dt.date(2019,1,10)]*100)
        plt.legend(loc=0)
        plt.grid(True,color='0.7',linestyle=':',linewidth=1)
graph()
# Out:
# 주식이름을 입력하세요:삼성전자
# '날짜를 입력하세요 sample '2019-01-10':2019-01-10
# write table name:kospi
# select DATE(Date),Close from kospi where Name=
# 삼성전자
# select DATE(Date),Close from kospi where Name= '삼성전자' && Date > '2019-01-10'
#           Date   삼성전자
# 0   2019-01-10  39800
# 1   2019-01-11  40500
# 2   2019-01-14  40050
# 3   2019-01-15  41100
# 4   2019-01-16  41450
# 5   2019-01-17  41950
# 6   2019-01-18  42300
# 7   2019-01-21  42750
# 8   2019-01-22  42150
# 9   2019-01-23  42000
# 10  2019-01-24  43050
# 11  2019-01-25  44750
# 12  2019-01-28  45050
# 13  2019-01-29  45500
# 14  2019-01-30  46400
# 15  2019-01-31  46150
# 16  2019-02-01  46350

# %%
## kpi200 - stock price (kpi200 astype(float))
## limit == loc[dt.date(2006,1,3)]

import FinanceDataReader as fdr
import pandas as pd
from bs4 import BeautifulSoup
import datetime as dt
from urllib.request import urlopen
import sqlalchemy 
import pymysql
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
# %matplotlib inline

now = dt.datetime.today().strftime('%Y-%m-%d')
engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
conn = engine.connect()

def graph():
    
    name = input('주식이름을 입력하세요:').split()
    date = input("'날짜를 입력하세요 sample '2019-01-10':")
    table= input('write table name:')
    
    select_query = "select DATE(Date),Close from kospi where Name= "
    date_query = "Date > "
    
    #select_query = "select DATE(Date),Close from"+" "+table+" "+"where Name=""'"+name+"'"+"&&"+" "+date_query+"'"+date+"'"
    
    print(select_query)
    tuple_name=tuple(name)
    df1 = pd.DataFrame()
    
    for x in tuple_name:
        print(x)
        
        var = select_query +"'"+x+"'"+" "+"&&"+" "+date_query+"'"+date+"'"
        #var = select_query +"'"+x+"'"
        #var = "select * from kospi where Name= '삼성전자' and Date > '2019-01-11'"
        #var = "select DATE(Date),Close from kospi where Name='삼성전자' and Date > '2019-01-01'"
        print(var)
        df = pd.read_sql(var ,connect)
        df.columns=['Date',x]
        if df1.empty:
            df1 = df
        else:
            df1 = pd.merge (df,df1,on='Date')
    print(df1)
graph()
# Out:
# 주식이름을 입력하세요:삼성전자 일진전기
# '날짜를 입력하세요 sample '2019-01-10':2019-01-20
# write table name:kospi
# select DATE(Date),Close from kospi where Name=
# 삼성전자
# select DATE(Date),Close from kospi where Name= '삼성전자' && Date > '2019-01-20'
# 일진전기
# select DATE(Date),Close from kospi where Name= '일진전기' && Date > '2019-01-20'
#          Date  일진전기   삼성전자
# 0  2019-01-21  3470  42750
# 1  2019-01-22  3465  42150
# 2  2019-01-23  3490  42000
# 3  2019-01-24  3460  43050
# 4  2019-01-25  3490  44750
# 5  2019-01-28  3525  45050
# 6  2019-01-29  3470  45500
# 7  2019-01-30  3465  46400
# 8  2019-01-31  3435  46150
# 9  2019-02-01  3540  46350

# %%
## kpi200 - stock price (kpi200 astype(float))
## limit == loc[dt.date(2006,1,3)]

import FinanceDataReader as fdr
import pandas as pd
from bs4 import BeautifulSoup
import datetime as dt
from urllib.request import urlopen
import sqlalchemy 
import pymysql
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
# %matplotlib inline

now = dt.datetime.today().strftime('%Y-%m-%d')
engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
conn = engine.connect()

def graph():
    
    name = input('주식이름을 입력하세요:').split()
    date = input("'날짜를 입력하세요 sample '2019-01-10':")
    table= input('write table name:')
    
    select_query = "select DATE(Date),Close from kospi where Name= "
    date_query = "Date > "
    
    #select_query = "select DATE(Date),Close from"+" "+table+" "+"where Name=""'"+name+"'"+"&&"+" "+date_query+"'"+date+"'"
    
    print(select_query)
    tuple_name=tuple(name)
    df1 = pd.DataFrame()
    
    for x in tuple_name:
        print(x)
        
        var = select_query +"'"+x+"'"+" "+"&&"+" "+date_query+"'"+date+"'"
        #var = select_query +"'"+x+"'"
        #var = "select * from kospi where Name= '삼성전자' and Date > '2019-01-11'"
        #var = "select DATE(Date),Close from kospi where Name='삼성전자' and Date > '2019-01-01'"
        print(var)
        df = pd.read_sql(var ,connect)
        df.columns=['Date',x]
        if df1.empty:
            df1 = df
        else:
            df1 = pd.merge (df,df1,on='Date')
    df1=df1.set_index('Date')
    plt.figure(figsize=(12,5))
    plt.plot(df1['삼성전자']/df1['삼성전자'].loc[dt.date(2017,1,2)]*100)
    plt.plot(df1['일진전기']/df1['일진전기'].loc[dt.date(2017,1,2)]*100)
    plt.legend(loc=0)
    plt.grid(True,color='0.7',linestyle=':',linewidth=1)    
graph()
# Out:
# 주식이름을 입력하세요:삼성전자 일진전기
# '날짜를 입력하세요 sample '2019-01-10':2016-12-20
# write table name:kospi
# select DATE(Date),Close from kospi where Name=
# 삼성전자
# select DATE(Date),Close from kospi where Name= '삼성전자' && Date > '2016-12-20'
# 일진전기
# select DATE(Date),Close from kospi where Name= '일진전기' && Date > '2016-12-20'

# %%
## kpi200 - stock price (kpi200 astype(float))
## limit == loc[dt.date(2006,1,3)]

import FinanceDataReader as fdr
import pandas as pd
from bs4 import BeautifulSoup
import datetime as dt
from urllib.request import urlopen
import sqlalchemy 
import pymysql
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
# %matplotlib inline

now = dt.datetime.today().strftime('%Y-%m-%d')
engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
conn = engine.connect()

def graph():
    
    name = input('주식이름을 입력하세요:').split()
    date = input("'날짜를 입력하세요 sample '2019-01-10':")
    table= input('write table name:')
    
    select_query = "select DATE(Date),Close from kospi where Name= "
    date_query = "Date > "
    
    #select_query = "select DATE(Date),Close from"+" "+table+" "+"where Name=""'"+name+"'"+"&&"+" "+date_query+"'"+date+"'"
    
    print(select_query)
    tuple_name=tuple(name)
    df1 = pd.DataFrame()
    
    for x in tuple_name:
        print(x)
        
        var = select_query +"'"+x+"'"+" "+"&&"+" "+date_query+"'"+date+"'"
        print(var)
        df = pd.read_sql(var ,engine)
        df.columns=['Date',x]
        if df1.empty:
            df1 = df
        else:
            df1 = pd.merge (df,df1,on='Date')
    df1=df1.set_index('Date')
    plt.figure(figsize=(12,5))
    for i in range(len(name)):
        plt.plot(df1[name[i]]/df1[name[i]].loc[dt.date(2017,1,2)]*100)
        #plt.plot(df1[name[1]]/df1[name[1]].loc[dt.date(2017,1,2)]*100)
    plt.legend(loc=0)
    plt.grid(True,color='0.7',linestyle=':',linewidth=1)    
graph()
# Out:
# 주식이름을 입력하세요:삼성전자
# '날짜를 입력하세요 sample '2019-01-10':2016-01-01
# write table name:kospi
# select DATE(Date),Close from kospi where Name=
# 삼성전자
# select DATE(Date),Close from kospi where Name= '삼성전자' && Date > '2016-01-01'

# %%
## kpi200 - stock price (kpi200 astype(float))
## limit == loc[dt.date(2006,1,3)]

import FinanceDataReader as fdr
import pandas as pd
from bs4 import BeautifulSoup
import datetime as dt
from urllib.request import urlopen
import sqlalchemy 
import pymysql
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
# %matplotlib inline

now = dt.datetime.today().strftime('%Y-%m-%d')
engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
conn = engine.connect()

def graph():
    
    name = input('주식이름을 입력하세요:').split()
    date = input("날짜를 입력하세요 sample: '2019-01-10':")
    #table= input('write table name:')
    
    select_query = "select DATE(Date),Close from market where Name= "
    date_query = "Date > "
    
    #select_query = "select DATE(Date),Close from"+" "+table+" "+"where Name=""'"+name+"'"+"&&"+" "+date_query+"'"+date+"'"
    
    #print("\n")
    tuple_name=tuple(name)
    df1 = pd.DataFrame()
    
    for x in tuple_name:
        #print(x)
        
        var = select_query +"'"+x+"'"+" "+"&&"+" "+date_query+"'"+date+"'"
        #print(var)
        df = pd.read_sql(var ,engine)
        df.columns=['Date',x]
        if df1.empty:
            df1 = df
        else:
            df1 = pd.merge (df,df1,on='Date')
    df1=df1.set_index('Date')
    plt.figure(figsize=(12,5))
    for i in range(len(name)):
        plt.plot(df1[name[i]]/df1[name[i]].loc[df['Date'][0]]*100)
        #plt.plot(df1[name[1]]/df1[name[1]].loc[dt.date(2017,1,2)]*100)
    plt.legend(loc=0)
    plt.grid(True,color='0.7',linestyle=':',linewidth=1)    
graph()
# Out:
# 주식이름을 입력하세요:삼성전자 LG
# 날짜를 입력하세요 sample: '2019-01-10':2016-01-01

# %%
def date_format(d):
    d = str(d).replace('-','.')
    yyyy = int(d.split('.')[0])
    mm = int(d.split('.')[1])
    dd = int(d.split('.')[2])
    format_date=(yyyy,mm,dd)
    return format_date

# %%
date_format('2018-01-01')
# Out:
# (2018, 1, 1)

# %%
## kpi200 - stock price (kpi200 astype(float))
## limit == loc[dt.date(2006,1,3)]

import FinanceDataReader as fdr
import pandas as pd
from bs4 import BeautifulSoup
import datetime as dt
from urllib.request import urlopen
import sqlalchemy 
import pymysql
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
# %matplotlib inline

now = dt.datetime.today().strftime('%Y-%m-%d')
engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
conn = engine.connect()

def graph():
    
    name = input('주식이름을 입력하세요:').split()
    date = input("날짜를 입력하세요 sample: '2019-01-10':")
    #table= input('write table name:')
    
    select_query = "select DATE(Date),Close from market where Name= "
    date_query = "Date > "
    
    #select_query = "select DATE(Date),Close from"+" "+table+" "+"where Name=""'"+name+"'"+"&&"+" "+date_query+"'"+date+"'"
    
    #print("\n")
    tuple_name=tuple(name)
    df1 = pd.DataFrame()
    
    for x in tuple_name:
        #print(x)
        
        var = select_query +"'"+x+"'"+" "+"&&"+" "+date_query+"'"+date+"'"
        #print(var)
        df = pd.read_sql(var ,engine)
        df.columns=['Date',x]
        if df1.empty:
            df1 = df
        else:
            df1 = pd.merge (df,df1,on='Date')
    df1=df1.set_index('Date')
    #first_date = date_format(df['Date'][0])
    plt.figure(figsize=(12,5))
    for i in range(len(name)):
        plt.plot(df1[name[i]]/df1[name[i]].loc[df['Date'][0]]*100)
        #plt.plot(df1[name[1]]/df1[name[1]].loc[dt.date(2017,1,2)]*100)
    plt.legend(loc=0)
    plt.grid(True,color='0.7',linestyle=':',linewidth=1)    
graph()
# Out:
# 주식이름을 입력하세요:삼성전자 한국내화 LG
# 날짜를 입력하세요 sample: '2019-01-10':2018-10-01

# %%
## kpi200 - stock price (kpi200 astype(float))
## limit == loc[dt.date(2006,1,3)]

import FinanceDataReader as fdr
import pandas as pd
from bs4 import BeautifulSoup
import datetime as dt
from urllib.request import urlopen
import sqlalchemy 
import pymysql
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
# %matplotlib inline

now = dt.datetime.today().strftime('%Y-%m-%d')
engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
conn = engine.connect()

def graph():
    
    name = input('주식이름을 입력하세요:').split()
    date = input("날짜를 입력하세요 sample: '2019-01-10':")
    #table= input('write table name:')
    
    select_query = "select DATE(Date),Close from market where Name= "
    date_query = "Date > "
    
    #select_query = "select DATE(Date),Close from"+" "+table+" "+"where Name=""'"+name+"'"+"&&"+" "+date_query+"'"+date+"'"
    
    #print("\n")
    tuple_name=tuple(name)
    df1 = pd.DataFrame()
    
    for x in tuple_name:
        #print(x)
        
        var = select_query +"'"+x+"'"+" "+"&&"+" "+date_query+"'"+date+"'"
        #print(var)
        df = pd.read_sql(var ,engine)
        df.columns=['Date',x]
        if df1.empty:
            df1 = df
        else:
            df1 = pd.merge (df,df1,on='Date')
    df1=df1.set_index('Date')
    #first_date = date_format(df['Date'][0])
    plt.figure(figsize=(12,5))
    for i in range(len(name)):
        plt.plot(df1[name[i]]/df1[name[i]].loc[df['Date'][0]]*100)
        #plt.plot(df1[name[1]]/df1[name[1]].loc[dt.date(2017,1,2)]*100)
    plt.legend(loc=0)
    plt.grid(True,color='0.7',linestyle=':',linewidth=1)    
graph()
# Out:
# 주식이름을 입력하세요:국일신동 나노메딕스 라이브플렉스
# 날짜를 입력하세요 sample: '2019-01-10':2018-10-01

# %% [markdown]
# # TEST

# %%
import FinanceDataReader as fdr
import pandas as pd
from bs4 import BeautifulSoup
import datetime as dt
from urllib.request import urlopen
import sqlalchemy 
import pymysql
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
# %matplotlib inline

now = dt.datetime.today().strftime('%Y-%m-%d')
engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
conn = engine.connect()

var = "select * from market where Date > '2019-02-07' && Volume >  500000"
df = pd.read_sql(var ,engine)

# %%
df1 = df[df['Date'] == '2019-02-07 00:00:00']
df1 = df1[['Name','Volume','Close']]
df1.columns = ['Name','yester_Volume','yester_Close']
df1
# Out:
#           Name  yester_Volume  yester_Close
# 0        AP시스템         661245         28700
# 1      BNK금융지주         839747          7340
# 4        CMG제약         876148          4800
# 6           DB        1143535           958
# 8          F&F         594809         51400
# 9    GMR 머티리얼즈        2141722           600
# 11       GS글로벌        1184506          2905
# 12          GV        2583073          3000
# 14     HB테크놀러지        2800115          3900
# 16         HDC         620268         18550
# 17       HSD엔진        1015846          5340
# 19         IHQ        1925522          1985
# 21      JB금융지주         560329          6300
# 22    JYP Ent.         593138         28800
# 23        KB금융        1042757         48050
# 25        KCTC        1269170          4015
# 27        KD건설        4951019           108
# 29         KEC        4187817          1250
# 32        KH바텍         728631         10200
# 34     LG디스플레이        1725315         19150
# 36      LG유플러스        2537880         14700
# 38        LG전자         662444         65900
# 40        MP한강         790506          1590
# 41       NAVER         550928        129000
# 43      NH투자증권         638304         14050
# 46         SDN        1049650          1770
# 48      SG세계물산        1157174           808
# 50        SG충방         794686          2445
# 52     SH에너지화학         627438          1190
# 54    SKC코오롱PI         853665         37100
# ..         ...            ...           ...
# 677         한라         709509          5470
# 678      한미글로벌        1906175         13050
# 679      한솔홈데코        2152385          1655
# 681      한송네오텍         856224          1695
# 683      한온시스템         684687         12400
# 685    한올바이오파마         552019         36450
# 687       한일사료         771596          2100
# 688       한일진공         650801          1570
# 690       한전산업         730720          3905
# 691      한진중공업        3131243          1235
# 693        한진칼         876694         27300
# 695         한창        4534240          2190
# 697       한창제지        4186252          3265
# 699       한화생명        1024737          4320
# 701      한화케미칼         550165         22700
# 703   해마로푸드서비스         914798          2300
# 704       헝셩그룹         997471           967
# 706       현대건설         872183         65000
# 708       현대로템        2295238         29400
# 711       현대상선        5691486          4445
# 713     현대엘리베이         871700        123000
# 714      현대중공업         597158        128000
# 716        현대차         528101        126000
# 717      형지엘리트         696291          2070
# 719         혜인         676676          7870
# 720       호텔신라         577291         76800
# 722     홈센타홀딩스        1076584          1800
# 724         후성         710297          8380
# 726      휠라코리아         772514         48900
# 728       흥구석유        3435718          4130
#
# [379 rows x 3 columns]

# %%
df2 = df[df['Date'] == '2019-02-08 00:00:00']
df2 = df2[['Name','Volume','Close']]
df2.columns = ['Name','today_Volume','today_Close']
df2
# Out:
#           Name  today_Volume  today_Close
# 2      BNK금융지주        674098         7280
# 3         CJ헬로       7008819        11800
# 5        CMG제약       1216532         4805
# 7           DB       1144775          960
# 10   GMR 머티리얼즈       1103538          585
# 13          GV       1086712         3005
# 15     HB테크놀러지       1220254         3905
# 18       HSD엔진        531209         5580
# 20         IHQ       5229965         2110
# 24        KB금융       1080909        48100
# 26        KCTC       1029957         4150
# 28        KD건설       3233496          107
# 30         KEC       1449472         1225
# 31      KG이니시스        606952        15050
# 33     KTB투자증권        605031         3230
# 35     LG디스플레이        963485        18850
# 37      LG유플러스       5794837        15600
# 39        LG전자        688421        64800
# 42       NAVER        702671       126000
# 44      NH투자증권        854014        13550
# 45   SBI인베스트먼트        657807          717
# 47         SDN        685467         1745
# 49      SG세계물산        576221          808
# 51        SG충방       2728774         2605
# 53     SH에너지화학       1044985         1195
# 55    SKC코오롱PI        591836        36100
# 57      SK네트웍스        857354         6230
# 59        SK증권       1683167          741
# 60       SK증권우       1331710         3680
# 62      SK하이닉스       4002821        73500
# ..         ...           ...          ...
# 664        필링크       1693118         2135
# 666     하나금융지주       1289591        40350
# 667    하이비젼시스템        502037         9470
# 669       한국내화       7067060         9590
# 671       한국전력       1231190        33650
# 674       한국카본        776593         7890
# 676    한국테크놀로지        929582         1195
# 680      한솔홈데코       1363808         1665
# 682      한송네오텍       1345201         1695
# 684      한온시스템        575973        12450
# 686    한올바이오파마        876720        37300
# 689       한일진공      10224360         1610
# 692      한진중공업       2751165         1205
# 694        한진칼        542845        27250
# 696         한창       1911968         2215
# 698       한창제지      23106369         3295
# 700       한화생명       1056343         4285
# 702      한화케미칼        671999        21900
# 705       헝셩그룹        506873          976
# 707       현대건설        530627        64300
# 709       현대로템       1289800        29550
# 710      현대바이오        558209         5920
# 712       현대상선       1670011         4415
# 715      현대중공업        506771       128000
# 718      형지엘리트        504586         2040
# 721       호텔신라        969780        73700
# 723     홈센타홀딩스        707008         1800
# 725         후성        639588         8220
# 727      휠라코리아       1211673        45000
# 729       흥구석유        751218         4220
#
# [351 rows x 3 columns]

# %%
df3 = pd.merge(df1,df2,on='Name')
df3
# Out:
#           Name  yester_Volume  yester_Close  today_Volume  today_Close
# 0      BNK금융지주         839747          7340        674098         7280
# 1        CMG제약         876148          4800       1216532         4805
# 2           DB        1143535           958       1144775          960
# 3    GMR 머티리얼즈        2141722           600       1103538          585
# 4           GV        2583073          3000       1086712         3005
# 5      HB테크놀러지        2800115          3900       1220254         3905
# 6        HSD엔진        1015846          5340        531209         5580
# 27   0.993258   1.270914
# 28   1.004662   1.789971
# 29   0.991058   0.413566
# ..        ...        ...
# 256  0.859425   2.045236
# 257  0.992958   0.802143
# 258  0.986711   0.613337
# 259  1.025424   1.363205
# 260  1.001241   1.132006
# 261  1.042391   2.055424
# 262  1.004478   1.171286
# 263  1.004202   0.322561
# 264  1.006042   0.633626
# 265  1.000000   1.571085
# 266  1.004032   0.841221
# 267  1.023320   1.588206
# 268  1.025478  15.710425
# 269  0.975709   0.878618
# 270  0.998168   0.619196
# 271  1.011416   0.421673
# 272  1.009188   5.519584
# 273  0.991898   1.030843
# 274  0.964758   1.221450
# 275  1.009307   0.508158
# 276  0.989231   0.608390
# 277  1.005102   0.561946
# 278  0.993251   0.293423
# 279  1.000000   0.848638
# 280  0.985507   0.724677
# 281  0.959635   1.679881
# 282  1.000000   0.656714
# 283  0.980907   0.900452
# 284  0.920245   1.568480
# 285  1.021792   0.218649
#
# [286 rows x 7 columns]

# %%
df4 = df3[['Name','Volume','Close']]
df4 = df4[df4['Volume'] > 1.5]
df4 = df4.sort_values(by=['Volume','Close'],ascending=False)
df4
# Out:
#          Name     Volume     Close
# 164  와이제이엠게임즈  31.808375  1.080092
# 268      한일진공  15.710425  1.025478
# 177        웹스  12.499307  1.097510
# 33       국일신동  10.887889  1.126174
# 72     라이브플렉스   9.572682  1.195524
# 135     아시아종묘   8.798451  1.064677
# 38      나노메딕스   8.687266  1.144975
# 252    포비스티앤씨   6.849531  1.125364
# 236      태양금속   5.530291  1.021875
# 272      한창제지   5.519584  1.009188
# 157       엠게임   5.308515  1.051005
# 103      서전기전   5.198678  1.026534
# 109     세우글로벌   5.075347  1.076233
# 192       이월드   4.896257  1.064202
# 43       넥슨지티   4.672879  1.003636
# 118      시노펙스   3.704978  1.007321
# 186      이라이콤   3.690143  1.082609
# 19       SG충방   3.433776  1.065440
# 202       인터엠   2.992065  1.008487
# 134      아세아텍   2.905018  0.967433
# 102    서울전자통신   2.888265  1.018450
# 44       넷게임즈   2.856648  0.988506
# 7         IHQ   2.716128  1.062972
# 155      엔피케이   2.638143  1.016878
# 191     이엠코리아   2.487884  1.025670
# 225      케이티스   2.453413  1.013605
# 112     세종텔레콤   2.431530  1.047431
# 171      우원개발   2.357382  1.046233
# 13     LG유플러스   2.283338  1.061224
# 168       우리로   2.281208  1.090517
# ..        ...        ...       ...
# 256       포티스   2.045236  0.859425
# 140     에스에프씨   1.982591  1.029801
# 36       기업은행   1.960591  0.968966
# 195      이화공영   1.836379  1.061159
# 34       국일제지   1.792690  1.000000
# 28         경농   1.789971  1.004662
# 158      영진약품   1.755314  1.022082
# 73     루미마이크로   1.732823  1.042042
# 153     엔케이물산   1.727210  1.177040
# 188    이수페타시스   1.725026  1.047619
# 242       티비씨   1.719769  0.992248
# 254     포스코엠텍   1.703114  1.037736
# 234   키위미디어그룹   1.701239  1.000000
# 210     제이스테판   1.686457  1.000000
# 281      호텔신라   1.679881  0.959635
# 20    SH에너지화학   1.665479  1.004202
# 206     자연과환경   1.662784  1.008351
# 187    이매진아시아   1.642918  1.110909
# 51       대영포장   1.640625  1.010676
# 226       코디엠   1.610425  0.973282
# 217   지스마트글로벌   1.602251  1.018568
# 67        디알텍   1.599850  1.030675
# 98      삼표시멘트   1.594665  1.028571
# 209     제미니투자   1.589820  1.021505
# 267   한올바이오파마   1.588206  1.023320
# 265     한송네오텍   1.571085  1.000000
# 40       남해화학   1.570100  1.013605
# 284     휠라코리아   1.568480  0.920245
# 130     씨아이에스   1.540461  1.019231
# 87       보해양조   1.526579  1.005348
#
# [62 rows x 3 columns]

# %%
df5 = df4[df4['Close'] > 1.1]
df5 = df5.sort_values(by=['Volume','Close'],ascending=False)
df5
# Out:
#        Name     Volume     Close
# 33     국일신동  10.887889  1.126174
# 72   라이브플렉스   9.572682  1.195524
# 38    나노메딕스   8.687266  1.144975
# 252  포비스티앤씨   6.849531  1.125364
# 153   엔케이물산   1.727210  1.177040
# 187  이매진아시아   1.642918  1.110909

# %%
df6 = pd.merge(df4,df5,on='Name')
df6
# Out:
#      Name   Volume_x   Close_x   Volume_y   Close_y
# 0    국일신동  10.887889  1.126174  10.887889  1.126174
# 1   나노메딕스   8.687266  1.144975   8.687266  1.144975
# 2  라이브플렉스   9.572682  1.195524   9.572682  1.195524
# 3   엔케이물산   1.727210  1.177040   1.727210  1.177040
# 4  이매진아시아   1.642918  1.110909   1.642918  1.110909
# 5  포비스티앤씨   6.849531  1.125364   6.849531  1.125364

# %%
plt.figure(figsize=(16,4))
df1['일진전기_Volume'].plot()
df1['일진전기'].plot(secondary_y=True)
plt.legend(loc=0)
plt.grid(True,color='0.7',linestyle=':',linewidth=1)

# %%
plt.figure(figsize=(16,4))
df1['일진전기_Volume'].plot()
df1['일진전기'].plot()

# %%
plt.figure(figsize=(16,4))
df1['Volume'].plot()
df1['한국내화'].plot(secondary_y=True)
plt.legend(loc=0)
plt.grid(True,color='0.7',linestyle=':',linewidth=1)

# %%
import FinanceDataReader as fdr
import pandas as pd
from bs4 import BeautifulSoup
import datetime as dt
from urllib.request import urlopen
import sqlalchemy 
import pymysql
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
# %matplotlib inline

now = dt.datetime.today().strftime('%Y-%m-%d')
engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
conn = engine.connect()

name = input('주식이름을 입력하세요:').split()
date = input("날짜를 입력하세요 sample: '2019-01-10':")
volume = 'Volume'
    
select_query = "select DATE(Date),Close,Volume from market where Name= "
date_query = "Date > "
    
#select_query = "select DATE(Date),Close from"+" "+table+" "+"where Name=""'"+name+"'"+"&&"+" "+date_query+"'"+date+"'"
    
#print("\n")
tuple_name=tuple(name)
df1 = pd.DataFrame()
    
for x in tuple_name:
    #print(x)
        
    var = select_query +"'"+x+"'"+" "+"&&"+" "+date_query+"'"+date+"'"
    #print(var)
    df = pd.read_sql(var ,engine)
    df.columns=['Date',x,x+'_'+'Volume']
    if df1.empty:
        df1 = df
    else:
        df1 = pd.merge (df,df1,on='Date')
df1=df1.set_index('Date')
df1
#first_date = date_format(df['Date'][0])
plt.figure(figsize=(12,5))
for i in range(len(name)):
    plt.plot(df1[name[i]]/df1[name[i]].loc[df['Date'][0]]*100)
#    plt.plot(df1[volume[i]]/df1[volume[i]].loc[df['Date'][0]]*100,secondary_y=True)
#    print(volume)
#    print(name)
    #plt.plot(df1[name[1]]/df1[name[1]].loc[dt.date(2017,1,2)]*100)
    plt.legend(loc=0)
    plt.grid(True,color='0.7',linestyle=':',linewidth=1)
# Out:
# 주식이름을 입력하세요:삼성전자 연우
# 날짜를 입력하세요 sample: '2019-01-10':2019-01-25

# %%
# KOSDAQ_STOCK PRICE TO MYSQL
import pandas as pd
import FinanceDataReader as fdr
import sqlalchemy 
import pymysql
pymysql.install_as_MySQLdb() # MySQLdb와 호환 
import MySQLdb

engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
conn = engine.connect()

data = pd.read_excel('d:\\market_list.xlsx')

code_list = data['종목코드'].tolist()
code_list = [str(item).zfill(6) for item in code_list]
name_list = data['종목명'].tolist()

# 코스닥상장종목 전체
stock_dic = dict(list(zip(code_list,name_list)))

for code in stock_dic.keys():
    df  = fdr.DataReader(code,'2019-02-08')
    print(code,stock_dic[code])
    df['Code'],df['Name'] = code,stock_dic[code]
    df = df[['Code','Name','Open','High','Low','Volume','Close']]
    df.to_sql(name='market', con=engine, if_exists='append')
# Out:
# 094190 이엘케이
# 094360 칩스앤미디어
# 094480 갤럭시아컴즈
# 094820 일진파워
# 094840 슈프리마에이치큐
# 094850 참좋은여행
# 094860 코닉글로리
# 094940 푸른기술
# 094970 제이엠티
# 095190 이엠코리아
# 095270 웨이브일렉트로
# 095340 ISC
# 095500 미래나노텍
# 095610 테스
# 095660 네오위즈
# 095700 제넥신
# 095910 에스에너지
# 096040 이트론
# 096240 청담러닝
# 096350 대창솔루션
# 096530 씨젠
# 096610 알에프세미
# 096630 에스코넥
# 096640 멜파스
# 096690 제이스테판
# 096870 엘디티
# 097520 엠씨넥스
# 097780 에스맥
# 097800 윈팩
# 097870 효성오앤비
# 098120 마이크로컨텍솔
# 098460 고영
# 098660 에스티오
# 099190 아이센스
# 099220 SDN
# 099320 쎄트렉아이
# 099410 동방선기
# 099440 스맥
# 099520 ITX엠투엠
# 100030 모바일리더
# 100090 삼강엠앤티
# 100120 뷰웍스
# 100130 동국S&C
# 100590 머큐리
# 100660 서암기계공업
# 100700 세운메디칼
# 101000 디엠씨
# 101160 월덱스
# 101170 우림기계
# 101240 씨큐브
# 101330 모베이스
# 101390 아이엠
# 101400 엔시트론
# 101490 에스앤에스텍
# 101670 코리아에스이
# 101680 한국정밀기계
# 101730 조이맥스
# 101930 인화정공
# 102120 어보브반도체
# 102210 해덕파워웨이
# 102710 이엔에프테크놀로지
# 102940 코오롱생명과학
# 103230 에스앤더블류
# 104040 대성파인텍
# 104200 NHN벅스
# 104460 동양피엔에프
# 104480 티케이케미칼
# 104540 코렌텍
# 104830 원익머트리얼즈
# 105330 케이엔더블유
# 105550 트루윈
# 105740 디케이락
# 106080 지투하이소닉
# 106190 하이텍팜
# 106240 파인테크닉스
# 106520 디지탈옵틱
# 108230 톱텍
# 108320 실리콘웍스
# 108380 대양전기공업
# 108490 로보티즈
# 108790 인터파크
# 108860 셀바스AI
# 109080 옵티시스
# 109610 에스와이패널
# 109740 디에스케이
# 109820 진매트릭스
# 109860 동일금속
# 109960 에이프로젠 H&G
# 110020 전진바이오팜
# 110790 크리스에프앤씨
# 110990 디아이티
# 111710 남화산업
# 111820 지와이커머스
# 111870 삼본정밀전자
# 112040 위메이드
# 112240 에스에프씨
# 113810 디젠스
# 114120 크루셜텍
# 114190 웰크론강원
# 114450 KPX생명과학
# 114570 지스마트글로벌
# 114630 우노앤컴퍼니
# 114810 아이원스
# 115160 휴맥스
# 115180 큐리언트
# 115310 인포바인
# 115440 우리넷
# 115450 지트리비앤티
# 115480 씨유메디칼
# 115500 케이씨에스
# 115530 씨엔플러스
# 115570 스타플렉스
# 115610 이미지스
# 115960 연우
# 117670 알파홀딩스
# 117730 티로보틱스
# 118990 모트렉스
# 119500 포메탈
# 119610 인터로조
# 119830 아이텍반도체
# 119850 지엔씨에너지
# 119860 다나와
# 120240 대정화금
# 121440 골프존뉴딘홀딩스
# 121600 나노신소재
# 121800 비덴트
# 121850 코이즈
# 121890 에스디시스템
# 122310 제노레이
# 122350 삼기오토모티브
# 122450 KMH
# 122640 예스티
# 122690 서진오토모티브
# 122800 썬텍
# 122870 와이지엔터테인먼트
# 122990 와이솔
# 123010 옵토팩
# 123040 엠에스오토텍
# 123100 원익테라세미콘
# 123260 STC
# 123330 제닉
# 123410 코리아에프티
# 123420 선데이토즈
# 123570 이엠넷
# 123750 알톤스포츠
# 123840 한일진공
# 123860 아나패스
# 124500 아이티센
# 126600 코프라
# 126640 화신정공
# 126700 하이비젼시스템
# 126870 뉴로스
# 126880 제이엔케이히터
# 127120 디엔에이링크
# 127160 매직마이크로
# 127710 아시아경제
# 128540 에코캡
# 128660 피제이메탈
# 130500 GH신소재
# 130580 나이스디앤비
# 130740 티피씨글로벌
# 131030 디에이치피코리아
# 131090 시큐브
# 131100 리켐
# 131180 딜리
# 131220 대한과학
# 131290 티에스이
# 131370 알서포트
# 131390 피앤이솔루션
# 131400 액트
# 131760 파인텍
# 131970 테스나
# 133750 메가엠디
# 134060 이퓨쳐
# 134580 디엠티
# 134780 화진
# 136480 하림
# 136510 쎄미시스코
# 136540 윈스
# 137400 피엔티
# 137940 넥스트아이
# 137950 제이씨케미칼
# 138070 신진에스엠
# 138080 오이솔루션
# 138360 에이씨티
# 138580 비즈니스온
# 138610 나이벡
# 138690 엘아이에스
# 139050 데일리블록체인
# 139670 넥스트리밍
# 140070 서플러스글로벌
# 140410 메지온
# 140520 대창스틸
# 140670 알에스오토메이션
# 140860 파크시스템스
# 141000 비아트론
# 141020 포티스
# 141070 맥스로텍
# 141080 레고켐바이오
# 142210 유니트론텍
# 142280 녹십자엠에스
# 142760 바이오리더스
# 143160 아이디스
# 143240 사람인에이치알
# 143540 영우디에스피
# 144510 녹십자랩셀
# 144960 뉴파워프라즈마
# 145020 휴젤
# 147760 마이크로프랜드
# 147830 제룡산업
# 148140 비디아이
# 148250 알엔투테크놀로지
# 149940 모다
# 149950 아바텍
# 149980 하이로닉
# 150840 인트로메딕
# 150900 파수닷컴
# 151860 KG ETS
# 151910 나노스
# 153460 네이블
# 153490 우리이앤엘
# 153710 옵티팜
# 154030 아시아종묘
# 154040 솔루에타
# 155650 와이엠씨
# 156100 엘앤케이바이오
# 158310 인터불스
# 159580 제로투세븐
# 159910 스킨앤스킨
# 160550 NEW
# 160600 에스엔텍
# 160980 싸이맥스
# 161570 THE MIDONG
# 161580 필옵틱스
# 166090 하나머티리얼즈
# 166480 코아스템
# 168330 내츄럴엔도텍
# 170030 현대공업
# 170790 파이오링크
# 170920 엘티씨
# 171010 램테크놀러지
# 171090 선익시스템
# 171120 라이온켐텍
# 173130 오파스넷
# 173940 에프엔씨엔터
# 174880 장원테크
# 174900 앱클론
# 175140 인포마크
# 175250 아이큐어
# 176440 에이치엔티
# 177350 베셀
# 177830 파버나인
# 178320 서진시스템
# 178780 유테크
# 178920 SKC코오롱PI
# 179290 엠아이텍
# 179900 유티아이
# 180400 캔서롭
# 181340 이즈미디어
# 182360 큐브엔터
# 182400 에이티젠
# 182690 테라셈
# 183300 코미코
# 183490 엔지켐생명과학
# 184230 SGA솔루션즈
# 185490 아이진
# 187220 디티앤씨
# 187270 신화콘텍
# 187420 제노포커스
# 187790 나노
# 187870 디바이스이엔지
# 189300 인텔리안테크
# 189690 포시에스
# 189860 서전기전
# 189980 흥국에프엔비
# 190510 나무가
# 191410 육일씨엔에쓰
# 191420 테고사이언스
# 192080 더블유게임즈
# 192250 케이사인
# 192390 윈하이텍
# 192410 감마누
# 192440 슈피겐코리아
# 193250 와이제이엠게임즈
# 194480 데브시스터즈
# 194510 파티게임즈
# 194700 노바렉스
# 195440 퓨전데이타
# 195990 유지인트
# 196170 알테오젠
# 196300 애니젠
# 196450 텔루스
# 196490 디에이테크놀로지
# 196700 웹스
# 197140 디지캡
# 197210 리드
# 198440 고려시멘트
# 200130 콜마비앤에이치
# 200230 텔콘RF제약
# 200470 하이셈
# 200670 휴메딕스
# 200710 에이디테크놀로지
# 200780 비씨월드제약
# 201490 미투온
# 203450 유니온커뮤니티
# 203650 드림시큐리티
# 203690 프로스테믹스
# 204020 엠코르셋
# 204620 글로벌텍스프리
# 204630 화이브라더스코리아
# 204840 지엘팜텍
# 204990 현성바이탈
# 205100 엑셈
# 205470 휴마시스
# 205500 액션스퀘어
# 206400 엔터메이트
# 206560 덱스터
# 206640 바디텍메드
# 206650 유바이오로직스
# 207760 미스터블루
# 208140 정다운
# 208340 파멥신
# 208350 지란지교시큐리티
# 208370 셀바스헬스케어
# 208640 썸에이지
# 208710 바이오로그디바이스
# 208860 엔지스테크널러지
# 211270 AP위성
# 212560 네오오토
# 213090 미래테크놀로지
# 213420 덕산네오룩스
# 214150 클래시스
# 214180 민앤지
# 214270 퓨쳐스트림네트웍스
# 214310 세미콘라이트
# 214370 케어젠
# 214430 아이쓰리시스템
# 214450 파마리서치프로덕트
# 214680 디알텍
# 214870 에치디프로
# 215000 골프존
# 215090 한컴유니맥스
# 215100 로보로보
# 215200 메가스터디교육
# 215360 우리산업
# 215380 우정바이오
# 215480 토박스코리아
# 215600 신라젠
# 215790 이노인스트루먼트
# 216050 인크로스
# 217190 제너셈
# 217270 넵튠
# 217330 싸이토젠
# 217480 에스디생명공학
# 217500 러셀
# 217600 켐온
# 217620 디딤
# 217730 강스템바이오텍
# 217820 엔에스
# 218150 미래생명자원
# 218410 RFHIC
# 219130 타이거일렉
# 219420 링크제니시스
# 219550 MP한강
# 219750 지티지웰니스
# 220100 퓨쳐켐
# 220180 핸디소프트
# 220260 켐트로스
# 220630 해마로푸드서비스
# 221610 한솔씨앤피
# 221840 하이즈항공
# 221980 케이디켐
# 222040 뉴트리바이오텍
# 222080 씨아이에스
# 222110 팬젠
# 222420 쎄노텍
# 222800 심텍
# 222810 한류AI센터
# 222980 한국맥널티
# 223310 이에스브이
# 224060 코디엠
# 224110 에이텍티앤
# 225190 삼양옵틱스
# 225330 씨엠에스에듀
# 225430 케이엠제약
# 225530 보광산업
# 225570 넷게임즈
# 225590 패션플랫폼
# 225650 쿠첸
# 226340 본느
# 226350 아이엠텍
# 226360 이엑스티
# 226400 오스테오닉
# 226440 한송네오텍
# 226950 올릭스
# 227100 디자인
# 227610 아우딘퓨쳐스
# 227950 마이크로텍
# 228340 동양파일
# 228850 레이언스
# 230240 에치에프알
# 230360 에코마케팅
# 230980 솔트웍스
# 232140 와이아이케이
# 232330 SK3호스팩
# 234100 세원
# 234300 에스트래픽
# 234920 자이글
# 236200 슈프리마
# 237690 에스티팜
# 237750 피앤씨테크
# 237880 클리오
# 238090 앤디포스
# 238120 로고스바이오
# 238200 비피도
# 238490 힘스
# 239340 미래에셋제5호스팩
# 239610 에이치엘사이언스
# 240540 한국4호스팩
# 240810 원익IPS
# 241520 DSC인베스트먼트
# 241690 유니테크노
# 241710 코스메카코리아
# 241770 메카로
# 241790 오션브릿지
# 241820 피씨엘
# 242040 나무기술
# 243070 휴온스
# 243840 신흥에스이씨
# 245620 EDGC
# 246690 티에스인베스트먼트
# 246710 티앤알바이오팹
# 246720 아스타
# 250000 보라티알
# 250060 모비스
# 250930 케이비제10호스팩
# 251370 와이엠티
# 251630 브이원텍
# 252500 세화피앤씨
# 253450 스튜디오드래곤
# 253590 대신밸런스제3호스팩
# 254120 IBKS제5호스팩
# 255220 SG
# 255440 야스
# 256630 엔에이치스팩10호
# 256840 엔에이치스팩11호
# 256940 케이피에스
# 257370 명성티엔에스
# 257730 신한제3호스팩
# 258610 이더블유케이
# 258790 케이비제11호스팩
# 258830 세종메디칼
# 259630 엠플러스
# 260660 알리코제약
# 260930 씨티케이코스메틱스
# 261200 하나금융9호스팩
# 262830 대신밸런스제4호스팩
# 263020 디케이앤디
# 263050 유틸렉스
# 263540 샘코
# 263600 덕우전자
# 263690 디알젬
# 263700 케어랩스
# 263720 디앤씨미디어
# 263750 펄어비스
# 263770 유에스티
# 263800 데이타솔루션
# 263810 상신전자
# 263860 지니언스
# 263920 에스엔피월드
# 264290 한화에이스스팩3호
# 264450 유비쿼스
# 264660 씨앤지하이테크
# 264850 IBKS제6호스팩
# 265480 미래에셋대우스팩1호
# 265520 AP시스템
# 265560 영화테크
# 265920 한화수성스팩
# 267320 교보7호스팩
# 267790 배럴
# 267980 매일유업
# 268600 셀리버리
# 269620 시스웍
# 270520 하나금융10호스팩
# 270870 뉴트리
# 271740 한국제5호스팩
# 272290 이녹스첨단소재
# 273060 엔에이치스팩12호
# 275630 에스에스알
# 276920 IBKS제7호스팩
# 277070 린드먼아시아
# 277410 인산가
# 277480 신한제4호스팩
# 279410 한화에이스스팩4호
# 281410 한국제6호스팩
# 281740 동부스팩5호
# 284620 하나금융11호스팩
# 285490 노바텍
# 287410 유안타제3호스팩
# 288620 에스퓨얼셀
# 289080 SV인베스트먼트
# 290120 대유에이피
# 290270 휴네시온
# 290380 대유
# 290550 디케이티
# 290650 엘앤씨바이오
# 290660 네오펙트
# 290670 대보마그네틱
# 290720 푸드나무
# 290740 액트로
# 291210 한국제7호스팩
# 291230 삼성스팩2호
# 293580 나우아이비캐피탈
# 297570 IBKS제9호스팩
# 298380 에이비엘바이오
# 299170 IBKS제10호스팩
# 299900 위지윅스튜디오
# 299910 베스파
# 302430 이노메트리
# 303030 대신밸런스제5호스팩
# 306620 DB금융스팩6호
# 307070 SK4호스팩
# 307160 하나머스트제6호스팩
# 307180 신영스팩4호
# 307280 교보8호스팩
# 307750 대신밸런스제6호스팩
# 307870 골든브릿지이안5호
# 309930 삼성머스트스팩3호
# 310200 미래에셋대우스팩2호
# 310840 엔에이치스팩13호
# 310870 한국제8호스팩
# 311270 키움제5호스팩
# 900040 차이나그레이트
# 900070 글로벌에스엠
# 900080 에스앤씨엔진그룹
# 900100 뉴프라이드
# 900110 이스트아시아홀딩스
# 900120 씨케이에이치
# 900250 크리스탈신소재
# 900260 로스웰
# 900270 헝셩그룹
# 900280 골든센츄리
# 900290 GRT
# 900300 오가닉티코스메틱
# 900310 컬러레이
# 900340 윙입푸드
# 950110 SBI핀테크솔루션즈
# 950130 엑세스바이오
# 950140 잉글우드랩
# 950160 코오롱티슈진
# 950170 JTC

# %%
26550832/834712
# Out:
# 31.808374625020367

# %%
import FinanceDataReader as fdr
import pandas as pd
from bs4 import BeautifulSoup
import datetime as dt
from urllib.request import urlopen
import sqlalchemy 
import pymysql
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
# %matplotlib inline

now = dt.datetime.today().strftime('%Y-%m-%d')
engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
conn = engine.connect()

def graph():
    
    name = input('주식이름을 입력하세요:').split()
    date = input("날짜를 입력하세요 sample: '2019-01-10':")
    volume = 'Volume'
    
    select_query = "select DATE(Date),Close,Volume from market where Name= "
    date_query = "Date > "
    
    #select_query = "select DATE(Date),Close from"+" "+table+" "+"where Name=""'"+name+"'"+"&&"+" "+date_query+"'"+date+"'"
    
    #print("\n")
    tuple_name=tuple(name)
    df1 = pd.DataFrame()
    
    for x in tuple_name:
        #print(x)
        
        var = select_query +"'"+x+"'"+" "+"&&"+" "+date_query+"'"+date+"'"
        #print(var)
        df = pd.read_sql(var ,engine)
        df.columns=['Date',x,'Volume']
        if df1.empty:
            df1 = df
        else:
            df1 = pd.merge (df,df1,on='Date')
    df1=df1.set_index('Date')
    #first_date = date_format(df['Date'][0])
    plt.figure(figsize=(12,5))
    for i in range(len(name)):
        print(df1[name[i]])

# %%
graph()
# Out:
# 주식이름을 입력하세요:삼성전자 일진전기
# 날짜를 입력하세요 sample: '2019-01-10':2019-01-25
# Date
# 2019-01-25    44750
# 2019-01-28    45050
# 2019-01-29    45500
# 2019-01-30    46400
# 2019-01-31    46150
# 2019-02-01    46350
# 2019-02-07    46200
# Name: 삼성전자, dtype: int64
# Date
# 2019-01-25    3490
# 2019-01-28    3525
# 2019-01-29    3470
# 2019-01-30    3465
# 2019-01-31    3435
# 2019-02-01    3540
# 2019-02-07    3720
# Name: 일진전기, dtype: int64

# %%
volume='Volume'
for i in range(len(name)):
        print(df1[name[i]]/df1[name[i]].loc[df['Date'][0]]*100)
# Out:
# Date
# 2019-01-02    100.000000
# 2019-01-03     97.032258
# 2019-01-04     96.645161
# 2019-01-07    100.000000
# 2019-01-08     98.322581
# 2019-01-09    102.193548
# 2019-01-10    102.709677
# 2019-01-11    104.516129
# 2019-01-14    103.354839
# 2019-01-15    106.064516
# 2019-01-16    106.967742
# 2019-01-17    108.258065
# 2019-01-18    109.161290
# 2019-01-21    110.322581
# 2019-01-22    108.774194
# 2019-01-23    108.387097
# 2019-01-24    111.096774
# 2019-01-25    115.483871
# 2019-01-28    116.258065
# 2019-01-29    117.419355
# 2019-01-30    119.741935
# 2019-01-31    119.096774
# 2019-02-01    119.612903
# 2019-02-07    119.225806
# Name: 삼성전자, dtype: float64

# %%
df1['Volume']
# Out:
# Date
# 2019-01-02     7847664
# 2019-01-03    12471493
# 2019-01-04    14108958
# 2019-01-07    12748997
# 2019-01-08    12756554
# 2019-01-09    17452708
# 2019-01-10    14731699
# 2019-01-11    11225320
# 2019-01-14    11984996
# 2019-01-15    11492756
# 2019-01-16     8491595
# 2019-01-17    11736903
# 2019-01-18    11029256
# 2019-01-21    11355701
# 2019-01-22     9964356
# 2019-01-23    11071079
# 2019-01-24    14747623
# 2019-01-25    22789395
# 2019-01-28    17998914
# 2019-01-29    16215017
# 2019-01-30    17505980
# 2019-01-31    21621145
# 2019-02-01    13627887
# 2019-02-07    15635449
# Name: Volume, dtype: int64

# %%
volume='Volume'
df1[volume]
# Out:
# Date
# 2019-01-02     7847664
# 2019-01-03    12471493
# 2019-01-04    14108958
# 2019-01-07    12748997
# 2019-01-08    12756554
# 2019-01-09    17452708
# 2019-01-10    14731699
# 2019-01-11    11225320
# 2019-01-14    11984996
# 2019-01-15    11492756
# 2019-01-16     8491595
# 2019-01-17    11736903
# 2019-01-18    11029256
# 2019-01-21    11355701
# 2019-01-22     9964356
# 2019-01-23    11071079
# 2019-01-24    14747623
# 2019-01-25    22789395
# 2019-01-28    17998914
# 2019-01-29    16215017
# 2019-01-30    17505980
# 2019-01-31    21621145
# 2019-02-01    13627887
# 2019-02-07    15635449
# Name: Volume, dtype: int64

# %%
df1.삼성전자.loc[df['Date'][0]]
# Out:
# 38750

# %%
df1.Volume.loc[df['Date'][0]]
# Out:
# 7847664

# %%
print(len(df1.Volume))
# Out:
# 24

# %%
for i in range(len(df1.Volume)):
        print(df1.Volume[i]/df1.Volume[0]*100)
# Out:
# 100.0
# 158.91981359038817
# 179.7854495299493
# 162.45594867466292
# 162.5522448463645
# 222.3936702692674
# 187.72081730308534
# 143.04027287610683
# 152.720554804589
# 146.44811500594318
# 108.2053844303222
# 149.55919366578385
# 140.54189883766685
# 144.7016717331425
# 126.97225569290428
# 141.07483449852083
# 187.92373118930678
# 290.39718061323725
# 229.35377967252418
# 206.62221267373323
# 223.0724964779328
# 275.5105850607264
# 173.65533233838758
# 199.23698313281506

# %%
plt.figure(figsize=(12,5))
df1['삼성전자'].plot(style='b')
df1['Volume'].plot(style='g',secondary_y=True)
