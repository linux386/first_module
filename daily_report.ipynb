# %%
import mod1

# %%
mod1.stock_select_with_Volume_Close()
# Out:
# 어제날짜를 입력하세요 : sample: '2019-02-07'  2019-02-18
# 오늘날짜를 입력하세요 : sample: '2019-02-07'  2019-02-19
#         Name  yester_Volume  yester_Close  today_Volume  today_Close  \
# 0  퓨쳐스트림네트웍스         641707          1475      40552679         1820
# 1  팬스타엔터프라이즈         554107           843      27734955         1095
# 2         러셀        1100095          2100      20001352         2280
# 3        위지트        1576818          1295      24031666         1330
# 4         한창        1545954          2200      22912994         2860
# 5      까뮤이앤씨         851666          1530      11677502         1535
# 6       이엑스티         562613          5570       7431217         6700
# 7     세미콘라이트        1133503           659      14043866          802
# 8        이트론         971118           180      11931327          190
# 9       한창제지        2525665          3270      28273087         3420
#
#       Close     Volume
# 0  1.233898  63.195008
# 1  1.298932  50.053428
# 2  1.085714  18.181477
# ...

# %%
mod1.stock_price_graph()
# Out:
# 주식이름을 입력하세요:한창 까뮤이앤씨 한창제지
# 날짜를 입력하세요 sample: '2019-01-10':2018-01-01

# %%
mod1.money_trend_graph()
# Out:
# 항목을 입력하세요: 선택항목: 'kpi200', '거래량', '고객예탁금', '신용잔고', '주식형펀드', '혼합형펀드', '채권형펀드'고객예탁금 신용잔고 주식형펀드
# 날짜를 입력하세요 sample: '2019-01-10':2019-01-01
