# %%
import mod1

# %%
mod1.stock_select_with_Volume_Close()
# Out:
# 어제날짜를 입력하세요 : sample: '2019-02-07'  2019-08-08
# 오늘날짜를 입력하세요 : sample: '2019-02-07'  2019-08-09
# Empty DataFrame
# Columns: [yester_Volume, yester_Close, Name, today_Volume, today_Close, Close, Volume]
# Index: []
# Empty DataFrame
# Columns: [yester_Volume, yester_Close, Name, today_Volume, today_Close, Close, Volume]
# Index: []

# %%
mod1.get_graph()
# Out:
# 그래프종류를 입력하세요 sample: 'money' or 'program' or 'stock': stock
# 날짜를 입력하세요 sample: '2019-01-10':
# 주식이름을 입력하세요:hrs 마니커 남선알미늄

# %%
mod1.get_graph()
# Out:
# 그래프종류를 입력하세요 sample: 'money' or 'program' or 'stock': money
# 날짜를 입력하세요 sample: '2019-01-10':2019-01-01

# %%
mod1.get_graph()
# Out:
# 그래프종류를 입력하세요 sample: 'money' or 'program' or 'stock': program
# 날짜를 입력하세요 sample: '2019-01-10':2019-01-01
