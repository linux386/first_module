# %%
import mod1

# %%
a = mod1.to_report()

# %%
a.stock_select_with_Volume_Close(choice=2)
# Out:
#          Name  yester_Volume  yester_Close  today_Volume  today_Close  \
# 0       알티캐스트         659856          1985      11242778         2160
# 1        삼성제약        2990644          2900      44459167         3460
# 2        켐트로스         715059          3550       8789188         3630
# 3          샘코        1212471          7630      14301906         8930
# 4        백광소재         888442          4650       8851685         4870
# 5    코너스톤네트웍스         711975          1165       7061625         1340
# 6         마니커       11503130           916     111757740          982
# 7   에이치엘비생명과학        1447028         14050      12757333        17750
# 8       엑사이엔씨        1033241          1990       9015051         2060
# 9        두올산업        3296153           974      28705369         1035
# 10        이월드        1529542          3305      12142804         3470
# 11      대호피앤씨        1699170          1070      13390226         1180
# 12     에스에이엠티         521893          2220       3319186         2245
# 13     씨케이에이치         967325           340       5804191          362
# 14       영진약품         604139          5010       3441897         5230
#
#        Close     Volume
# 0   1.088161  17.038230
# 1   1.193103  14.866085
# 2   1.022535  12.291556
# 3   1.170380  11.795669
# 4   1.047312   9.963155
# 5   1.150215   9.918361
# 6   1.072052   9.715420
# 7   1.263345   8.816231
# 8   1.035176   8.725023
# 9   1.062628   8.708749
# 10  1.049924   7.938850
# 11  1.102804   7.880451
# 12  1.011261   6.359898
# 13  1.064706   6.000249
# 14  1.043912   5.697194
#          Name  yester_Volume  yester_Close  today_Volume  today_Close  \
# 0       이에스에이        2298628          2400       6393887         3120
# 1   에이치엘비생명과학        1447028         14050      12757333        17750
# 2        삼성제약        2990644          2900      44459167         3460
# 3          샘코        1212471          7630      14301906         8930
# 4      동양네트웍스        4328530           844      18609234          975
# 5    코너스톤네트웍스         711975          1165       7061625         1340
# 6         뉴지랩         617550          9580       1582648        11000
# 7     마니커에프앤지         902424         12250       4503337        13800
# 8       대호피앤씨        1699170          1070      13390226         1180
# 9        원풍물산        5043461          5080       1030780         5540
# 10       KH바텍         995168         12300       2179605        13400
# 11      알티캐스트         659856          1985      11242778         2160
# 12    지스마트글로벌        1318270           468       4438650          503
# 13        마니커       11503130           916     111757740          982
# 14     씨케이에이치         967325           340       5804191          362
#
#        Close     Volume
# 0   1.300000   2.781610
# 1   1.263345   8.816231
# 2   1.193103  14.866085
# 3   1.170380  11.795669
# 4   1.155213   4.299204
# 5   1.150215   9.918361
# 6   1.148225   2.562785
# 7   1.126531   4.990267
# 8   1.102804   7.880451
# 9   1.090551   0.204379
# 10  1.089431   2.190188
# 11  1.088161  17.038230
# 12  1.074786   3.367026
# 13  1.072052   9.715420
# 14  1.064706   6.000249

# %%
a.get_graph(choice=2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:364: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:365: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)

# %%
## 개별종목분석

#from mod1 import *

#df = select_stock('hrs','2010-01-01')
#close_vol_ma(df,'ma120')

# %%
##  러닝머신 dataset 생성

#from mod1 import *

#df  = make_dataset('hrs','2017-01-01')
