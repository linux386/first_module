# %%
import mod1

# %%
mod1.stock_select_with_Volume_Close()
# Out:
# 어제날짜를 입력하세요 : sample: '2019-02-07'  2019-02-22
# 오늘날짜를 입력하세요 : sample: '2019-02-07'  2019-02-25
#         Name  yester_Volume  yester_Close  today_Volume  today_Close  \
# 0     중앙리빙테크         996470          1020      10461576          896
# 1  SBI인베스트먼트         983729           842       7103071          863
# 2    한국테크놀로지        1057283           945       6750597         1110
# 3  퓨쳐스트림네트웍스        3712748          1705      21953421         1780
# 4         러셀        1563130          2095       8686127         2230
# 5   에이티넘인베스트         678561          2365       3268282         2395
# 6       국일신동        1611090          6960       6676691         6910
# 7     라이브플렉스        2416658           923       9648132          935
# 8    THE E&M        1017618          1070       4009438         1270
# 9      이에스에이         748761          1260       2762732         1635
#
#       Close     Volume
# 0  0.878431  10.498636
# 1  1.024941   7.220557
# 2  1.174603   6.384853
# ...

# %%
mod1.stock_price_graph()
# Out:
# 주식이름을 입력하세요:러셀
# 날짜를 입력하세요 sample: '2019-01-10':2018-01-01

# %%
mod1.money_trend_graph()
# Out:
# 항목을 입력하세요: 선택항목: 'kpi200', '거래량', '고객예탁금', '신용잔고', '주식형펀드', '혼합형펀드', '채권형펀드'신용잔고
# 날짜를 입력하세요 sample: '2019-01-10':2018-01-01
