# %%
import mod1

# %%
mod1.stock_select_with_Volume_Close()
# Out:
# 어제날짜를 입력하세요 : sample: '2019-02-07'  2019-03-12
# 오늘날짜를 입력하세요 : sample: '2019-02-07'  2019-03-13
#       Name  yester_Volume  yester_Close  today_Volume  today_Close     Close  \
# 0     서희건설        1845968          1175      33863277         1265  1.076596
# 1      지엔코        1118186          1775       8018000         1830  1.030986
# 2      디알젬        1257041          9020       8873746        11400  1.263858
# 3      모토닉         855139         12100       4887941        14300  1.181818
# 4       일야         921300          1985       4894918         1915  0.964736
# 5       GV        1690114          5010       7965041         4700  0.938124
# 6     팜스토리         582424          1175       2315155         1230  1.046809
# 7   슈펙스비앤피        7402260           962      26941230         1250  1.299376
# 8      필룩스        1220522         12200       4365528        12300  1.008197
# 9  오리엔트바이오        4618241           556      15916732          581  1.044964
#
#       Volume
# ...

# %%
mod1.stock_price_graph()
# Out:
# 주식이름을 입력하세요:디알젬
# 날짜를 입력하세요 sample: '2019-01-10':2019-01-01

# %%
mod1.money_trend_graph_1()
# Out:
# 항목을 입력하세요: 선택항목: 'kpi200', '거래량', '고객예탁금', '신용잔고', '주식형펀드', '혼합형펀드', '채권형펀드' : kpi200 거래량 신용잔고 채권형펀드
# 날짜를 입력하세요 sample: '2019-01-10':2018-01-01
