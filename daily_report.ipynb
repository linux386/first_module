# %%
import mod1

# %%
a = mod1.to_report()

# %%
a.stock_select_with_Volume_Close(choice=2)
# Out:
#        Name  yester_Volume  yester_Close  today_Volume  today_Close     Close  \
# 0     골든센츄리         921655           419      54530295          464  1.107399
# 1      윙입푸드         646655          2030      24000813         2200  1.083744
# 2      헝셩그룹        2281771          1060      49053335         1120  1.056604
# 3       윌비스        2582653          1360      53370225         1435  1.055147
# 4      MP한강        2765308          1035      55650687         1345  1.299517
# 5      컬러레이         891120          1930      14277215         2000  1.036269
# 6      에너전트         500859          1625       7397432         1705  1.049231
# 7   제이준코스메틱         955064          4870      11727250         5220  1.071869
# 8   크리스탈신소재         999706          1970      12211971         2020  1.025381
# 9       IHQ         619410          1750       6722471         1790  1.022857
# 10     큐브엔터        1997312          3015      14232590         3915  1.298507
# 11     삼성제약        3485843          5180      24791428         4915  0.948842
# 12      이월드        4192884          4315      21718402         4885  1.132097
# 13      초록뱀         565176          1425       2845682         1450  1.017544
# 14      마니커        3005903           851      13242357          864  1.015276
#
#        Volume
# 0   59.165626
# 1   37.115329
# 2   21.497922
# 3   20.664884
# 4   20.124589
# 5   16.021653
# 6   14.769490
# 7   12.279020
# 8   12.215562
# 9   10.853023
# 10   7.125872
# 11   7.112032
# 12   5.179824
# 13   5.035037
# 14   4.405451
#        Name  yester_Volume  yester_Close  today_Volume  today_Close     Close  \
# 0      MP한강        2765308          1035      55650687         1345  1.299517
# 1      큐브엔터        1997312          3015      14232590         3915  1.298507
# 2   아시아나IDT        5141644         17450       6777838        22650  1.297994
# 3       이월드        4192884          4315      21718402         4885  1.132097
# 4   한국테크놀로지         619106          1505       1961358         1685  1.119601
# 5      에어부산       13760391          6410      30464635         7150  1.115445
# 6     골든센츄리         921655           419      54530295          464  1.107399
# 7       유엔젤         653594          4110       1451165         4520  1.099757
# 8      인스코비       33149318          3755      76964110         4120  1.097204
# 9    아시아나항공       15124422          5310      34423322         5820  1.096045
# 10   쌍용정보통신        1375346          1930       4494993         2110  1.093264
# 11     금호전기       11890034          3560       5970762         3880  1.089888
# 12      나이벡        1064444         10650        974699        11550  1.084507
# 13     윙입푸드         646655          2030      24000813         2200  1.083744
# 14    이에스에이        2253217          4185       3669857         4510  1.077658
#
#        Volume
# 0   20.124589
# 1    7.125872
# 2    1.318224
# 3    5.179824
# 4    3.168049
# 5    2.213937
# 6   59.165626
# 7    2.220285
# 8    2.321740
# 9    2.276009
# 10   3.268263
# 11   0.502165
# 12   0.915688
# 13  37.115329
# 14   1.628719

# %%
a.get_graph(choice=2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:364: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:365: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)

# %%
## 개별종목분석

#from mod1 import *

#df = select_stock('hrs','2010-01-01')
#close_vol_ma(df,'ma120')

# %%
##  러닝머신 dataset 생성

#from mod1 import *

#df  = make_dataset('hrs','2017-01-01')
