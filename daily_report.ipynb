# %%
import mod1

# %%
mod1.stock_select_with_Volume_Close()
# Out:
# 어제날짜를 입력하세요 : sample: '2019-02-07'  2019-03-08
# 오늘날짜를 입력하세요 : sample: '2019-02-07'  2019-03-11
#         Name  yester_Volume  yester_Close  today_Volume  today_Close  \
# 0       로보로보         508109          2330      10249625         2440
# 1      웅진씽크빅         989909          3155      14859202         3720
# 2        필링크         503728          2080       2455490         1960
# 3     세미콘라이트         905022           793       4297592          824
# 4        아리온        1164942           812       5473669          889
# 5     아주IB투자        2904758          1330      11350519         1435
# 6  와이지엔터테인먼트         500865         43250       1901261        37150
# 7   JYP Ent.         511222         30100       1844943        31200
# 8       엠아이텍        5169801          4700      18425261         5450
# 9    크린앤사이언스        1461099         18550       5120338        22600
#
#       Close     Volume
# 0  1.047210  20.172099
# 1  1.179081  15.010675
# 2  0.942308   4.874635
# ...

# %%
mod1.stock_price_graph()
# Out:
# 주식이름을 입력하세요:로보로보 웅진씽크빅 필링크
# 날짜를 입력하세요 sample: '2019-01-10':2018-01-01

# %%
mod1.money_trend_graph_1()
# Out:
# 항목을 입력하세요: 선택항목: 'kpi200', '거래량', '고객예탁금', '신용잔고', '주식형펀드', '혼합형펀드', '채권형펀드' : 고객예탁금 신용잔고 주식형펀드 거래량
# 날짜를 입력하세요 sample: '2019-01-10':2018-01-01
