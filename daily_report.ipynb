# %%
import mod1

# %%
a = mod1.to_report()

# %%
a.stock_select_with_Volume_Close(choice=2)
# Out:
#          Name  yester_Volume  yester_Close  today_Volume  today_Close  \
# 0        큐캐피탈         695393           611      56123728          695
# 1         지엔코         736952          1120      32111140         1375
# 2          큐로         776112           872      29337999          992
# 3       우정바이오         916334          6170      15453159         8020
# 4         이글벳        1705417          7420      22572550         8350
# 5         에스모        6962940          1840      69421504         2080
# 6        에너전트         679517          1270       4485493         1415
# 7   에이프로젠 KIC        1600687          2155       8690200         2200
# 8         디젠스         621037           590       3308412          638
# 9         에스맥        3401600          1030      17796372         1070
# 10      일신바이오         993120          2080       4464996         2195
# 11        포티스        2514326           660      11046269          740
# 12        캠시스        1292533          2605       5658114         2770
# 13       이화전기        1945137           227       8409409          233
# 14      좋은사람들         564456          3595       2114229         3750
#
#        Close     Volume
# 0   1.137480  80.707928
# 1   1.227679  43.572906
# 2   1.137615  37.801244
# 3   1.299838  16.864112
# 4   1.125337  13.235795
# 5   1.130435   9.970142
# 6   1.114173   6.601002
# 7   1.020882   5.429044
# 8   1.081356   5.327238
# 9   1.038835   5.231765
# 10  1.055288   4.495928
# 11  1.121212   4.393332
# 12  1.063340   4.377539
# 13  1.026432   4.323299
# 14  1.043115   3.745605
#       Name  yester_Volume  yester_Close  today_Volume  today_Close     Close  \
# 0    우정바이오         916334          6170      15453159         8020  1.299838
# 1     흥아해운       51176077           669      63822897          869  1.298954
# 2   루미마이크로        2370007          1610       5853794         2090  1.298137
# 3      지엔코         736952          1120      32111140         1375  1.227679
# 4    코닉글로리        3148784          1040      11563869         1195  1.149038
# 5       큐로         776112           872      29337999          992  1.137615
# 6     큐캐피탈         695393           611      56123728          695  1.137480
# 7      파인텍       14294705          1800      22708319         2035  1.130556
# 8      에스모        6962940          1840      69421504         2080  1.130435
# 9    동양이엔피        3363297         15450        818216        17400  1.126214
# 10     이글벳        1705417          7420      22572550         8350  1.125337
# 11  S&K폴리텍         966597          6250       2474481         7030  1.124800
# 12     포티스        2514326           660      11046269          740  1.121212
# 13   투비소프트        1491996          2745        955068         3065  1.116576
# 14    에너전트         679517          1270       4485493         1415  1.114173
#
#        Volume
# 0   16.864112
# 1    1.247124
# 2    2.469948
# 3   43.572906
# 4    3.672487
# 5   37.801244
# 6   80.707928
# 7    1.588583
# 8    9.970142
# 9    0.243278
# 10  13.235795
# 11   2.559992
# 12   4.393332
# 13   0.640128
# 14   6.601002

# %%
a.get_graph(choice=2)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
## 개별종목분석

#from mod1 import *

#df = select_stock('hrs','2010-01-01')
#close_vol_ma(df,'ma120')

# %%
##  러닝머신 dataset 생성

#from mod1 import *

#df  = make_dataset('hrs','2017-01-01')
