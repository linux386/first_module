# %%
import mod1

# %%
mod1.stock_select_with_Volume_Close()
# Out:
# 어제날짜를 입력하세요 : sample: '2019-02-07'  2019-03-07
# 오늘날짜를 입력하세요 : sample: '2019-02-07'  2019-03-08
#         Name  yester_Volume  yester_Close  today_Volume  today_Close  \
# 0  에이프로젠 KIC         729472          2590      44316665         3000
# 1       KD건설        3443941            98     108421474          107
# 2       케이사인        1205073          1465      20438037         1515
# 3      신성이엔지         609879          1160       9289409         1220
# 4      비츠로시스        2006783           480      21743248          506
# 5         풍강        1063568          4805      10078588         4605
# 6       한창제지        1188098          2700       9773085         2795
# 7     동양물산기업         509436          1875       4065203         1900
# 8         인콘         745319          1195       5505882         1215
# 9       판타지오         681343           816       4897581          828
#
#       Close     Volume
# 0  1.158301  60.751701
# 1  1.091837  31.481804
# 2  1.034130  16.959999
# ...

# %%
mod1.stock_price_graph()
# Out:
# 주식이름을 입력하세요:엠아이텍 삼진엘앤디 동아화성
# 날짜를 입력하세요 sample: '2019-01-10':2019-01-01

# %%
mod1.money_trend_graph_1()
# Out:
# 항목을 입력하세요: 선택항목: 'kpi200', '거래량', '고객예탁금', '신용잔고', '주식형펀드', '혼합형펀드', '채권형펀드' : 고객예탁금 신용잔고 주식형펀드 채권형펀드
# 날짜를 입력하세요 sample: '2019-01-10':2019-01-01
