# %%
import mod1

# %%
a = mod1.to_report()

# %%
a.stock_select_with_Volume_Close(choice=2)
# Out:
#          Name  yester_Volume  yester_Close  today_Volume  today_Close  \
# 0          한창        2197810          2985      34830059         3870
# 1       아시아종묘         546591          6550       6632433         7450
# 2     대명코퍼레이션         956088          1760       9709334         2000
# 3       고려시멘트        2065598          3185      16577688         3595
# 4     지스마트글로벌        2204610           547      16476173          614
# 5        우성사료         999174          3115       6809575         3330
# 6        백광소재         544981          3730       3556526         3865
# 7        대우건설        1009110          4380       6264917         4905
# 8        메가엠디        5661744          2645      31901090         3140
# 9       포스코엠텍        1352051          5880       6484743         6340
# 10      좋은사람들        2754241          3720      12796500         4200
# 11  팬스타엔터프라이즈        7635417          1175      30961142         1310
# ...

# %%
a.get_graph(choice=2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-80883feae520> in <module>
# ----> 1 a.get_graph(choice=2)
#
# ~\notebook\Git\first_module\mod1.py in get_graph(self, choice)
#     349                     plt.figure(figsize=(16,4))
#     350                     for i in range(len(basis_name)):
# --> 351                         plt.plot(basis_df1[basis_name[i]]/basis_df1[basis_name[i]].loc[basis_df.index[0]]*100)
#     352
#     353                     plt.legend(loc=0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    3956         if is_scalar(key):
#    3957             key = com.cast_scalar_indexer(key)
# -> 3958             return getitem(key)
#    3959
#    3960         if isinstance(key, slice):
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
