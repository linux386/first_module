# %% [markdown]
# # STOCK_PRICE Collection to Excel

# %%
# KOSPI_STOCK PRICE TO EXCEL

import FinanceDataReader as fdr
import pandas as pd
from datetime import datetime
print(datetime.now())

data = pd.read_excel('d:\\kospi_list.xlsx')

code_list = data['종목코드'].tolist()
code_list = [str(item).zfill(6) for item in code_list]
name_list = data['종목명'].tolist()

# 코스피 상장종목 전체
stock_dic = dict(list(zip(code_list,name_list)))

for code in stock_dic.keys():
    df  = fdr.DataReader(code,'2019-01-01')
    print(code,stock_dic[code])
    df['Code'],df['Name'] = code,stock_dic[code]
    df = df[['Code','Name','Open','High','Low','Volume','Close']]
    
    df.to_excel('d:\\data_set\\kospi\\'+ stock_dic[code] +'.xlsx',engine = 'xlsxwriter')

print(datetime.now())

# %%
# KOSDAQ_STOCK PRICE to EXCEL

import FinanceDataReader as fdr
import pandas as pd
from datetime import datetime
datetime.now()

data = pd.read_excel('d:\\kosdaq_list.xlsx')

code_list = data['종목코드'].tolist()
code_list = [str(item).zfill(6) for item in code_list]
name_list = data['종목명'].tolist()

# 코스피 상장종목 전체
stock_dic = dict(list(zip(code_list,name_list)))

for code in stock_dic.keys():
    df  = fdr.DataReader(code,'1995-05-01')
    print(code,stock_dic[code])
    df['Code'],df['Name'] = code,stock_dic[code]
    df = df[['Code','Name','Open','High','Low','Volume','Close']]    
    df.to_excel('d:\\data_set\\kosdaq\\'+ stock_dic[code] +'.xlsx',engine = 'xlsxwriter')

datetime.now()
# Out:
# Wall time: 0 ns
# 000250 삼천당제약
# 000440 중앙에너비스
# 001000 신라섬유
# 001540 안국약품
# 001810 무림SP
# 001840 이화공영
# 002230 피에스텍
# 002290 삼일기업공사
# 002680 한탑
# 002800 신신제약
# 003100 선광
# 003310 대주산업
# 003380 하림지주
# 003670 포스코켐텍
# 003800 에이스침대
# 004590 한국가구
# 004650 창해에탄올
# 004780 대륙제관
# 005160 동국산업
# 005290 동진쎄미켐
# 005670 푸드웰
# 005710 대원산업
# 005860 한일사료
# 005990 매일홀딩스
# 006050 국영지앤엠
# 006140 피제이전자
# 006580 대양제지
# 006620 동구바이오제약
# 006730 서부T&D
# 006910 보성파워텍
# 006920 모헨즈
# 007330 푸른저축은행
# 007370 진양제약
# 007390 네이처셀
# 007530 영신금속
# 007680 대원
# 007720 대명코퍼레이션
# 007770 한일화학
# 007820 에스엠코어
# 008290 원풍물산
# 008370 원풍
# 008470 부스타
# 008800 행남사
# 008830 대동기어
# 009300 삼아제약
# 009520 포스코엠텍
# 009620 삼보산업
# 009730 코센
# 009780 엠에스씨
# 010170 대한광통신
# 010240 흥국
# 010280 쌍용정보통신
# 010470 오리콤
# 011040 경동제약
# 011080 형지I&C
# 011320 유니크
# 011370 서한
# 011560 세보엠이씨
# 012340 뉴인텍
# 012620 원일특강
# 012700 리드코프
# 012790 신일제약
# 012860 서연전자
# 013030 하이록코리아
# 013120 동원개발
# 013310 아진산업
# 013720 청보산업
# 013810 스페코
# 013990 아가방컴퍼니
# 014100 보령메디앙스
# 014190 원익큐브
# 014200 광림
# 014470 부방
# 014570 고려제약
# 014620 성광벤드
# 014940 오리엔탈정공
# 014970 삼륭물산
# 015710 코콤
# 015750 성우하이텍
# 016100 리더스코스메틱
# 016250 이테크건설
# 016600 큐캐피탈
# 016670 포비스티앤씨
# 016790 현대사료
# 016920 카스
# 017000 신원종합개발
# 017250 인터엠
# 017480 삼현철강
# 017510 세명전기
# 017650 대림제지
# 017680 데코앤이
# 017890 한국알콜
# 018000 유니슨
# 018120 진로발효
# 018290 지엠피
# 018310 삼목에스폼
# 018620 우진비앤지
# 018680 서울제약
# 018700 바른손
# 019010 그랜드백화점
# 019210 와이지-원
# 019540 일지테크
# 019550 SBI인베스트먼트
# 019570 제미니투자
# 019590 엠벤처투자
# 019660 글로본
# 019770 서연탑메탈
# 019990 에너토크
# 020180 대신정보통신
# 020400 대동금속
# 020710 시공테크
# 021040 대호피앤씨
# 021045 대호피앤씨우
# 021080 에이티넘인베스트
# 021320 KCC건설
# 021650 한국큐빅
# 021880 메이슨캐피탈
# 022100 포스코 ICT
# 022220 정산애강
# 023160 태광
# 023410 유진기업
# 023440 제일제강
# 023460 CNH
# 023600 삼보판지
# 023760 한국캐피탈
# 023770 플레이위드
# 023790 동일철강
# 023890 아트라스BX
# 023900 풍국주정
# 023910 대한약품
# 024060 흥구석유
# 024120 KB오토시스
# 024740 한일단조
# 024800 유성티엔에스
# 024810 이화전기
# 024830 세원물산
# 024840 갑을메탈
# 024850 피에스엠씨
# 024880 케이피에프
# 024910 경창산업
# 024940 PN풍년
# 024950 삼천리자전거
# 025320 시노펙스
# 025440 대성엘텍
# 025550 한국선재
# 025770 한국정보통신
# 025870 신라에스지
# 025880 케이씨피드
# 025900 동화기업
# 025950 동신건설
# 025980 아난티
# 026040 제이에스티나
# 026150 특수건설
# 026180 현대정보기술
# 026910 광진실업
# 027040 서울전자통신
# 027050 코리아나
# 027360 아주IB투자
# 027580 상보
# 027710 팜스토리
# 027830 대성창투
# 028040 미래SCI
# 028080 휴맥스홀딩스
# 028150 GS홈쇼핑
# 028300 에이치엘비
# 029480 바른테크놀로지
# 029960 코엔텍
# 030190 NICE평가정보
# 030270 에스마크
# 030350 드래곤플라이
# 030520 한글과컴퓨터
# 030530 원익홀딩스
# 030960 양지사
# 031310 아이즈비전
# 031330 에스에이엠티
# 031390 녹십자셀
# 031510 오스템
# 031860 엔에스엔
# 031980 피에스케이
# 032080 아즈텍WB
# 032190 다우데이타
# 032280 삼일
# 032500 케이엠더블유
# 032540 TJ미디어
# 032580 피델릭스
# 032620 유비케어
# 032680 소프트센
# 032685 소프트센우
# 032750 삼진
# 032790 엠젠플러스
# 032800 판타지오
# 032820 우리기술
# 032850 비트컴퓨터
# 032860 GMR 머티리얼즈
# 032940 원익
# 032960 동일기연
# 032980 바이온
# 033050 제이엠아이
# 033100 제룡전기
# 033110 이디
# 033130 디지틀조선
# 033160 엠케이전자
# 033170 시그네틱스
# 033200 모아텍
# 033230 인성정보
# 033290 코웰패션
# 033310 디케이디앤아이
# 033320 제이씨현시스템
# 033340 좋은사람들
# 033430 디에스티
# 033500 동성화인텍
# 033540 파라텍
# 033560 블루콤
# 033600 에이코넬
# 033640 네패스
# 033790 스카이문스테크놀로지
# 033830 티비씨
# 034230 파라다이스
# 034810 해성산업
# 034940 조아제약
# 034950 한국기업평가
# 035080 인터파크홀딩스
# 035200 프럼파스트
# 035290 더블유에프엠
# 035460 기산텔레콤
# 035480 마제스타
# 035600 KG이니시스
# 035610 솔본
# 035620 바른손이앤에이
# 035760 CJ ENM
# 035810 이지바이오
# 035890 서희건설
# 035900 JYP Ent.
# 036000 예림당
# 036010 아비코전자
# 036030 KTH
# 036090 위지트
# 036120 SCI평가정보
# 036170 씨티젠
# 036180 영인프런티어
# 036190 금화피에스시
# 036200 유니셈
# 036260 이매진아시아
# 036420 제이콘텐트리
# 036480 대성미생물
# 036490 SK머티리얼즈
# 036540 SFA반도체
# 036560 영풍정밀
# 036620 버추얼텍
# 036630 세종텔레콤
# 036640 HRS
# 036670 KCI
# 036690 코맥스
# 036710 심텍홀딩스
# 036800 나이스정보통신
# 036810 에프에스티
# 036830 솔브레인
# 036890 진성티이씨
# 036930 주성엔지니어링
# 037030 파워넷
# 037070 파세코
# 037230 한국팩키지
# 037330 인지디스플레
# 037350 성도이엔지
# 037370 EG
# 037400 우리조명
# 037440 희림
# 037460 삼지전자
# 037760 쎄니트
# 037950 엘컴텍
# 038010 제일테크노스
# 038060 루멘스
# 038070 서린바이오
# 038110 에코플라스틱
# 038160 팍스넷
# 038290 마크로젠
# 038340 UCI
# 038390 레드캡투어
# 038460 바이오스마트
# 038500 삼표시멘트
# 038530 골드퍼시픽
# 038540 상상인
# 038620 위즈코프
# 038680 에스넷
# 038870 에코바이오
# 038880 아이에이
# 038950 파인디지털
# 039010 현대통신
# 039020 이건홀딩스
# 039030 이오테크닉스
# 039200 오스코텍
# 039230 에이아이비트
# 039240 경남스틸
# 039290 인포뱅크
# 039310 세중
# 039340 한국경제TV
# 039420 케이엘넷
# 039440 에스티아이
# 039560 다산네트웍스
# 039610 화성밸브
# 039670 스포츠서울
# 039740 한국정보공학
# 039830 오로라
# 039840 디오
# 039860 나노엔텍
# 039980 리노스
# 040160 누리텔레콤
# 040300 YTN
# 040350 큐로컴
# 040420 정상제이엘에스
# 040610 SG&G
# 040910 아이씨디
# 041020 인프라웨어
# 041140 넥슨지티
# 041190 우리기술투자
# 041440 에버다임
# 041460 한국전자인증
# 041510 에스엠
# 041520 이라이콤
# 041590 에너전트
# 041830 인바디
# 041910 에스텍파마
# 041920 메디아나
# 041930 동아화성
# 041960 코미팜
# 042000 카페24
# 042040 케이피엠테크
# 042110 에스씨디
# 042370 비츠로테크
# 042420 네오위즈홀딩스
# 042500 링네트
# 042510 라온시큐어
# 042520 한스바이오메드
# 042600 새로닉스
# 042940 상지카일룸
# 043090 팜스웰바이오
# 043100 솔고바이오
# 043150 바텍
# 043200 파루
# 043220 에이치엘비파워
# 043260 성호전자
# 043290 케이맥
# 043340 에쎈테크
# 043360 디지아이
# 043370 평화정공
# 043590 크로바하이텍
# 043610 지니뮤직
# 043650 국순당
# 043710 서울리거
# 043910 자연과환경
# 044060 조광ILI
# 044180 KD건설
# 044340 위닉스
# 044480 바이오제네틱스
# 044490 태웅
# 044780 에이치케이
# 044960 이글벳
# 045060 오공
# 045100 한양이엔지
# 045300 성우테크론
# 045340 토탈소프트
# 045390 대아티아이
# 045510 정원엔시스
# 045520 크린앤사이언스
# 045660 에이텍
# 045890 GV
# 045970 코아시아홀딩스
# 046070 코다코
# 046110 한일네트웍스
# 046120 오르비텍
# 046140 SBS콘텐츠허브
# 046210 파나진
# 046310 백금T&A
# 046390 삼화네트웍스
# 046440 KG모빌리언스
# 046890 서울반도체
# 046940 우원개발
# 046970 우리로
# 047080 한빛소프트
# 047310 파워로직스
# 047560 이스트소프트
# 047770 코데즈컴바인
# 047820 초록뱀
# 047920 씨트리
# 048260 오스템임플란트
# 048410 현대바이오
# 048430 유라테크
# 048470 대동스틸
# 048530 인트론바이오
# 048550 SM C&C
# 048770 TPC
# 048830 엔피케이
# 048870 시너지이노베이션
# 048910 대원미디어
# 049070 인탑스
# 049080 기가레인
# 049120 파인디앤씨
# 049180 셀루메드
# 049430 코메론
# 049470 SGA
# 049480 오픈베이스
# 049520 유아이엘
# 049550 잉크테크
# 049630 재영솔루텍
# 049720 고려신용정보
# 049830 승일
# 049950 미래컴퍼니
# 049960 쎌바이오텍
# 050090 휘닉스소재
# 050110 캠시스
# 050120 라이브플렉스
# 050320 에이앤티앤
# 050540 한국코퍼레이션
# 050760 에스폴리텍
# 050860 아세아텍
# 050890 쏠리드
# 050960 수산아이앤티
# 051160 지어소프트
# 051360 토비스
# 051370 인터플렉스
# 051380 피씨디렉트
# 051390 YW
# 051490 나라엠앤디
# 051500 CJ프레시웨이
# 051780 큐로홀딩스
# 051980 중앙리빙테크
# 052020 에스티큐브
# 052190 이에스에이
# 052220 iMBC
# 052260 SK바이오랜드
# 052300 W홀딩컴퍼니
# 052330 코텍
# 052400 코나아이
# 052420 오성첨단소재
# 052460 아이크래프트
# 052600 한네트
# 052670 제일바이오
# 052710 아모텍
# 052770 와이디온라인
# 052790 액토즈소프트
# 052860 아이앤씨
# 052900 KMH하이텍
# 053030 바이넥스
# 053050 지에스이
# 053060 세동
# 053110 소리바다
# 053160 프리엠스
# 053260 금강철강
# 053270 구영테크
# 053280 예스24
# 053290 NE능률
# 053300 한국정보인증
# 053350 이니텍
# 053450 세코닉스
# 053590 한국테크놀로지
# 053610 프로텍
# 053620 태양
# 053660 현진소재
# 053700 삼보모터스
# 053800 안랩
# 053950 경남제약
# 053980 오상자이엘
# 054040 한국컴퓨터
# 054050 농우바이오
# 054090 삼진엘앤디
# 054180 중앙오션
# 054210 이랜텍
# 054220 비츠로시스
# 054300 팬스타엔터프라이즈
# 054340 피앤텔
# 054410 케이피티유
# 054450 텔레칩스
# 054540 삼영엠텍
# 054620 APS홀딩스
# 054630 에이디칩스
# 054670 대한뉴팜
# 054780 키이스트
# 054800 아이디스홀딩스
# 054920 한컴시큐어
# 054930 유신
# 054940 엑사이엔씨
# 054950 제이브이엠
# 056000 신스타임즈
# 056080 유진로봇
# 056090 유앤아이
# 056190 에스에프에이
# 056360 코위버
# 056700 신화인터텍
# 056730 포스링크
# 057030 와이비엠넷
# 057500 SKC 솔믹스
# 057540 옴니시스템
# 057680 옴니텔
# 057880 토필드
# 058110 멕아이씨에스
# 058220 아리온
# 058400 KNN
# 058420 제이웨이
# 058450 일야
# 058470 리노공업
# 058530 슈펙스비앤피
# 058610 에스피지
# 058630 엠게임
# 058820 CMG제약
# 059090 미코
# 059100 아이컴포넌트
# 059120 아진엑스텍
# 059210 메타바이오메드
# 060150 인선이엔티
# 060230 이그잭스
# 060240 룽투코리아
# 060250 NHN한국사이버결제
# 060260 뉴보텍
# 060280 큐렉소
# 060300 레드로버
# 060310 3S
# 060370 KT서브마린
# 060380 동양에스텍
# 060480 국일신동
# 060540 에스에이티
# 060560 홈센타홀딩스
# 060570 아이리버
# 060590 씨티씨바이오
# 060720 KH바텍
# 060900 퍼시픽바이오
# 061040 알에프텍
# 061250 화일약품
# 061970 엘비세미콘
# 062860 티엘아이
# 063080 게임빌
# 063170 서울옥션
# 063440 SM Life Design
# 063570 한국전자금융
# 063760 이엘피
# 064090 에프앤리퍼블릭
# 064240 홈캐스트
# 064260 다날
# 064290 인텍플러스
# 064480 브리지텍
# 064510 에코마이스터
# 064520 바른전자
# 064550 바이오니아
# 064760 티씨케이
# 064800 필링크
# 064820 케이프
# 065060 지엔코
# 065130 탑엔지니어링
# 065150 MP그룹
# 065160 에프티이앤이
# 065170 넥스트BT
# 065350 신성델타테크
# 065420 에스아이리소스
# 065440 이루온
# 065450 빅텍
# 065500 오리엔트정공
# 065510 휴비츠
# 065530 전파기지국
# 065560 녹원씨엔아이
# 065570 삼영이엔씨
# 065620 제낙스
# 065650 메디프론
# 065660 안트로젠
# 065680 우주일렉트로
# 065690 대진디엠피
# 065710 서호전기
# 065770 CS
# 065940 바이오빌
# 065950 웰크론
# 066110 한프
# 066130 하츠
# 066310 큐에스아이
# 066360 체리부로
# 066410 버킷스튜디오
# 066430 와이오엠
# 066590 우수AMS
# 066620 국보디자인
# 066670 디스플레이텍
# 066700 테라젠이텍스
# 066790 씨씨에스
# 066900 디에이피
# 066910 손오공
# 066970 엘앤에프
# 066980 브레인콘텐츠
# 067000 조이시티
# 067010 이씨에스
# 067080 대화제약
# 067160 아프리카TV
# 067170 오텍
# 067280 멀티캠퍼스
# 067290 JW신약
# 067310 하나마이크론
# 067390 아스트
# 067570 엔브이에이치코리아
# 067630 에이치엘비생명과학
# 067730 로지시스
# 067770 세진티에스
# 067900 와이엔텍
# 067920 이글루시큐리티
# 067990 도이치모터스
# 068050 팬엔터테인먼트
# 068240 다원시스
# 068330 일신바이오
# 068760 셀트리온제약
# 068790 DMS
# 068930 디지털대성
# 068940 아이씨케이
# 069080 웹젠
# 069110 코스온
# 069140 누리플랜
# 069330 유아이디
# 069410 엔텔스
# 069510 에스텍
# 069540 라이트론
# 069920 아이에스이커머스
# 070300 한솔시큐어
# 070590 한솔인티큐브
# 071200 인피니트헬스케어
# 071280 로체시스템즈
# 071460 대유위니아
# 071670 에이테크솔루션
# 071850 캐스텍코리아
# 072020 중앙백신
# 072470 우리산업홀딩스
# 072520 제넨바이오
# 072770 네오디안테크놀로지
# 072870 메가스터디
# 072950 빛샘전자
# 072990 에이치시티
# 073010 케이에스피
# 073070 에스모
# 073110 엘엠에스
# 073190 듀오백
# 073490 이노와이어리스
# 073540 에프알텍
# 073560 우리손에프앤지
# 073570 피엠지파마
# 073640 삼원테크
# 074430 아미노로직스
# 074600 원익QnC
# 075130 플랜티넷
# 075970 동국알앤에스
# 076080 웰크론한텍
# 076610 해성옵틱스
# 077280 한컴지엠디
# 077360 덕산하이메탈
# 078020 이베스트투자증권
# 078070 유비쿼스홀딩스
# 078130 국일제지
# 078140 대봉엘에스
# 078150 HB테크놀러지
# 078160 메디포스트
# 078340 컴투스
# 078350 한양디지텍
# 078590 두올산업
# 078600 대주전자재료
# 078650 코렌
# 078860 아이오케이
# 078890 가온미디어
# 078940 일경산업개발
# 079000 와토스코리아
# 079170 한창산업
# 079190 EMW
# 079370 제우스
# 079650 서산
# 079810 디이엔티
# 079940 가비아
# 079950 인베니아
# 079960 동양이엔피
# 079970 투비소프트
# 080000 에스엔유
# 080010 이상네트웍스
# 080160 모두투어
# 080220 제주반도체
# 080420 모다이노칩
# 080440 에스제이케이
# 080470 성창오토텍
# 080520 오디텍
# 080530 코디
# 080580 오킨스전자
# 080720 한국유니온제약
# 081150 티플랙스
# 081580 성우전자
# 082210 옵트론텍
# 082270 젬백스
# 082660 삼우엠스
# 082800 루미마이크로
# 082850 우리이티아이
# 082920 비츠로셀
# 083310 엘오티베큠
# 083450 GST
# 083470 KJ프리텍
# 083500 에프엔에스테크
# 083550 케이엠
# 083640 인콘
# 083650 비에이치아이
# 083660 CSA 코스믹
# 083790 크리스탈
# 083930 아바코
# 084110 휴온스글로벌
# 084180 수성
# 084370 유진테크
# 084650 랩지노믹스
# 084730 팅크웨어
# 084990 바이로메드
# 085370 루트로닉
# 08537M 루트로닉3우C
# 085660 차바이오텍
# 085670 뉴프렉스
# 085810 알티캐스트
# 085910 네오티스
# 086040 바이오톡스텍
# 086060 진바이오텍
# 086250 화신테크
# 086390 유니테스트
# 086450 동국제약
# 086520 에코프로
# 086670 비엠티
# 086820 바이오솔루션
# 086890 이수앱지스
# 086900 메디톡스
# 086960 한컴MDS
# 086980 쇼박스
# 087010 펩트론
# 087260 모바일어플라이언스
# 087600 픽셀플러스
# 087730 네패스신소재
# 088130 동아엘텍
# 088290 이원컴포텍
# 088390 이녹스
# 088800 에이스테크
# 088910 동우팜투테이블
# 089010 켐트로닉스
# 089030 테크윙
# 089140 넥스턴
# 089150 케이씨티
# 089230 THE E&M
# 089530 에이티세미콘
# 089600 나스미디어
# 089790 제이티
# 089850 유비벨록스
# 089890 코세스
# 089970 에이피티씨
# 089980 상아프론테크
# 090150 광진윈텍
# 090360 로보스타
# 090410 덕신하우징
# 090460 비에이치
# 090470 제이스텍
# 090710 디에스티로봇
# 090740 연이정보통신
# 090850 이지웰페어
# 091120 이엠텍
# 091340 S&K폴리텍
# 091440 텔레필드
# 091580 상신이디피
# 091590 남화토건
# 091700 파트론
# 091970 나노캠텍
# 091990 셀트리온헬스케어
# 092040 아미코젠
# 092070 디엔에프
# 092130 이크레더블
# 092300 현우산업
# 092460 한라IMS
# 092600 넥스트칩
# 092730 네오팜
# 092870 엑시콘
# 093190 빅솔론
# 093320 케이아이엔엑스
# 093380 풍강
# 093520 매커스
# 093640 다믈멀티미디어
# 093920 서원인텍
# 094170 동운아나텍
# 094190 이엘케이
# 094360 칩스앤미디어
# 094480 갤럭시아컴즈
# 094820 일진파워
# 094840 슈프리마에이치큐
# 094850 참좋은여행
# 094860 코닉글로리
# 094940 푸른기술
# 094970 제이엠티
# 095190 이엠코리아
# 095270 웨이브일렉트로
# 095340 ISC
# 095500 미래나노텍
# 095610 테스
# 095660 네오위즈
# 095700 제넥신
# 095910 에스에너지
# 096040 이트론
# 096240 청담러닝
# 096350 대창솔루션
# 096530 씨젠
# 096610 알에프세미
# 096630 에스코넥
# 096640 멜파스
# 096690 제이스테판
# 096870 엘디티
# 097520 엠씨넥스
# 097780 에스맥
# 097800 윈팩
# 097870 효성오앤비
# 098120 마이크로컨텍솔
# 098460 고영
# 098660 에스티오
# 099190 아이센스
# 099220 SDN
# 099320 쎄트렉아이
# 099410 동방선기
# 099440 스맥
# 099520 ITX엠투엠
# 100030 모바일리더
# 100090 삼강엠앤티
# 100120 뷰웍스
# 100130 동국S&C
# 100590 머큐리
# 100660 서암기계공업
# 100700 세운메디칼
# 101000 디엠씨
# 101160 월덱스
# 101170 우림기계
# 101240 씨큐브
# 101330 모베이스
# 101390 아이엠
# 101400 엔시트론
# 101490 에스앤에스텍
# 101670 코리아에스이
# 101680 한국정밀기계
# 101730 조이맥스
# 101930 인화정공
# 102120 어보브반도체
# 102210 해덕파워웨이
# 102710 이엔에프테크놀로지
# 102940 코오롱생명과학
# 103230 에스앤더블류
# 104040 대성파인텍
# 104200 NHN벅스
# 104460 동양피엔에프
# 104480 티케이케미칼
# 104540 코렌텍
# 104830 원익머트리얼즈
# 105330 케이엔더블유
# 105550 트루윈
# 105740 디케이락
# 106080 지투하이소닉
# 106190 하이텍팜
# 106240 파인테크닉스
# 106520 디지탈옵틱
# 108230 톱텍
# 108320 실리콘웍스
# 108380 대양전기공업
# 108490 로보티즈
# 108790 인터파크
# 108860 셀바스AI
# 109080 옵티시스
# 109610 에스와이패널
# 109740 디에스케이
# 109820 진매트릭스
# 109860 동일금속
# 109960 에이프로젠 H&G
# 110020 전진바이오팜
# 110790 크리스에프앤씨
# 110990 디아이티
# 111710 남화산업
# 111820 지와이커머스
# 111870 삼본정밀전자
# 112040 위메이드
# 112240 에스에프씨
# 113810 디젠스
# 114120 크루셜텍
# 114190 웰크론강원
# 114450 KPX생명과학
# 114570 지스마트글로벌
# 114630 우노앤컴퍼니
# 114810 아이원스
# 115160 휴맥스
# 115180 큐리언트
# 115310 인포바인
# 115440 우리넷
# 115450 지트리비앤티
# 115480 씨유메디칼
# 115500 케이씨에스
# 115530 씨엔플러스
# 115570 스타플렉스
# 115610 이미지스
# 115960 연우
# 117670 알파홀딩스
# 117730 티로보틱스
# 118990 모트렉스
# 119500 포메탈
# 119610 인터로조
# 119830 아이텍반도체
# 119850 지엔씨에너지
# 119860 다나와
# 120240 대정화금
# 121440 골프존뉴딘홀딩스
# 121600 나노신소재
# 121800 비덴트
# 121850 코이즈
# 121890 에스디시스템
# 122310 제노레이
# 122350 삼기오토모티브
# 122450 KMH
# 122640 예스티
# 122690 서진오토모티브
# 122800 썬텍
# 122870 와이지엔터테인먼트
# 122990 와이솔
# 123010 옵토팩
# 123040 엠에스오토텍
# 123100 원익테라세미콘
# 123260 STC
# 123330 제닉
# 123410 코리아에프티
# 123420 선데이토즈
# 123570 이엠넷
# 123750 알톤스포츠
# 123840 한일진공
# 123860 아나패스
# 124500 아이티센
# 126600 코프라
# 126640 화신정공
# 126700 하이비젼시스템
# 126870 뉴로스
# 126880 제이엔케이히터
# 127120 디엔에이링크
# 127160 매직마이크로
# 127710 아시아경제
# 128540 에코캡
# 128660 피제이메탈
# 130500 GH신소재
# 130580 나이스디앤비
# 130740 티피씨글로벌
# 131030 디에이치피코리아
# 131090 시큐브
# 131100 리켐
# 131180 딜리
# 131220 대한과학
# 131290 티에스이
# 131370 알서포트
# 131390 피앤이솔루션
# 131400 액트
# 131760 파인텍
# 131970 테스나
# 133750 메가엠디
# 134060 이퓨쳐
# 134580 디엠티
# 134780 화진
# 136480 하림
# 136510 쎄미시스코
# 136540 윈스
# 137400 피엔티
# 137940 넥스트아이
# 137950 제이씨케미칼
# 138070 신진에스엠
# 138080 오이솔루션
# 138360 에이씨티
# 138580 비즈니스온
# 138610 나이벡
# 138690 엘아이에스
# 139050 데일리블록체인
# 139670 넥스트리밍
# 140070 서플러스글로벌
# 140410 메지온
# 140520 대창스틸
# 140670 알에스오토메이션
# 140860 파크시스템스
# 141000 비아트론
# 141020 포티스
# 141070 맥스로텍
# 141080 레고켐바이오
# 142210 유니트론텍
# 142280 녹십자엠에스
# 142760 바이오리더스
# 143160 아이디스
# 143240 사람인에이치알
# 143540 영우디에스피
# 144510 녹십자랩셀
# 144960 뉴파워프라즈마
# 145020 휴젤
# 147760 마이크로프랜드
# 147830 제룡산업
# 148140 비디아이
# 148250 알엔투테크놀로지
# 149940 모다
# 149950 아바텍
# 149980 하이로닉
# 150840 인트로메딕
# 150900 파수닷컴
# 151860 KG ETS
# 151910 나노스
# 153460 네이블
# 153490 우리이앤엘
# 153710 옵티팜
# 154030 아시아종묘
# 154040 솔루에타
# 155650 와이엠씨
# 156100 엘앤케이바이오
# 158310 인터불스
# 159580 제로투세븐
# 159910 스킨앤스킨
# 160550 NEW
# 160600 에스엔텍
# 160980 싸이맥스
# 161570 THE MIDONG
# 161580 필옵틱스
# 166090 하나머티리얼즈
# 166480 코아스템
# 168330 내츄럴엔도텍
# 170030 현대공업
# 170790 파이오링크
# 170920 엘티씨
# 171010 램테크놀러지
# 171090 선익시스템
# 171120 라이온켐텍
# 173130 오파스넷
# 173940 에프엔씨엔터
# 174880 장원테크
# 174900 앱클론
# 175140 인포마크
# 175250 아이큐어
# 176440 에이치엔티
# 177350 베셀
# 177830 파버나인
# 178320 서진시스템
# 178780 유테크
# 178920 SKC코오롱PI
# 179290 엠아이텍
# 179900 유티아이
# 180400 캔서롭
# 181340 이즈미디어
# 182360 큐브엔터
# 182400 에이티젠
# 182690 테라셈
# 183300 코미코
# 183490 엔지켐생명과학
# 184230 SGA솔루션즈
# 185490 아이진
# 187220 디티앤씨
# 187270 신화콘텍
# 187420 제노포커스
# 187790 나노
# 187870 디바이스이엔지
# 189300 인텔리안테크
# 189690 포시에스
# 189860 서전기전
# 189980 흥국에프엔비
# 190510 나무가
# 191410 육일씨엔에쓰
# 191420 테고사이언스
# 192080 더블유게임즈
# 192250 케이사인
# 192390 윈하이텍
# 192410 감마누
# 192440 슈피겐코리아
# 193250 와이제이엠게임즈
# 194480 데브시스터즈
# 194510 파티게임즈
# 194700 노바렉스
# 195440 퓨전데이타
# 195990 유지인트
# 196170 알테오젠
# 196300 애니젠
# 196450 텔루스
# 196490 디에이테크놀로지
# 196700 웹스
# 197140 디지캡
# 197210 리드
# 198440 고려시멘트
# 200130 콜마비앤에이치
# 200230 텔콘RF제약
# 200470 하이셈
# 200670 휴메딕스
# 200710 에이디테크놀로지
# 200780 비씨월드제약
# 201490 미투온
# 203450 유니온커뮤니티
# 203650 드림시큐리티
# 203690 프로스테믹스
# 204020 엠코르셋
# 204620 글로벌텍스프리
# 204630 화이브라더스코리아
# 204840 지엘팜텍
# 204990 현성바이탈
# 205100 엑셈
# 205470 휴마시스
# 205500 액션스퀘어
# 206400 엔터메이트
# 206560 덱스터
# 206640 바디텍메드
# 206650 유바이오로직스
# 207760 미스터블루
# 208140 정다운
# 208340 파멥신
# 208350 지란지교시큐리티
# 208370 셀바스헬스케어
# 208640 썸에이지
# 208710 바이오로그디바이스
# 208860 엔지스테크널러지
# 211270 AP위성
# 212560 네오오토
# 213090 미래테크놀로지
# 213420 덕산네오룩스
# 214150 클래시스
# 214180 민앤지
# 214270 퓨쳐스트림네트웍스
# 214310 세미콘라이트
# 214370 케어젠
# 214430 아이쓰리시스템
# 214450 파마리서치프로덕트
# 214680 디알텍
# 214870 에치디프로
# 215000 골프존
# 215090 한컴유니맥스
# 215100 로보로보
# 215200 메가스터디교육
# 215360 우리산업
# 215380 우정바이오
# 215480 토박스코리아
# 215600 신라젠
# 215790 이노인스트루먼트
# 216050 인크로스
# 217190 제너셈
# 217270 넵튠
# 217330 싸이토젠
# 217480 에스디생명공학
# 217500 러셀
# 217600 켐온
# 217620 디딤
# 217730 강스템바이오텍
# 217820 엔에스
# 218150 미래생명자원
# 218410 RFHIC
# 219130 타이거일렉
# 219420 링크제니시스
# 219550 MP한강
# 219750 지티지웰니스
# 220100 퓨쳐켐
# 220180 핸디소프트
# 220260 켐트로스
# 220630 해마로푸드서비스
# 221610 한솔씨앤피
# 221840 하이즈항공
# 221980 케이디켐
# 222040 뉴트리바이오텍
# 222080 씨아이에스
# 222110 팬젠
# 222420 쎄노텍
# 222800 심텍
# 222810 한류AI센터
# 222980 한국맥널티
# 223310 이에스브이
# 224060 코디엠
# 224110 에이텍티앤
# 225190 삼양옵틱스
# 225330 씨엠에스에듀
# 225430 케이엠제약
# 225530 보광산업
# 225570 넷게임즈
# 225590 패션플랫폼
# 225650 쿠첸
# 226340 본느
# 226350 아이엠텍
# 226360 이엑스티
# 226400 오스테오닉
# 226440 한송네오텍
# 226950 올릭스
# 227100 디자인
# 227610 아우딘퓨쳐스
# 227950 마이크로텍
# 228340 동양파일
# 228850 레이언스
# 230240 에치에프알
# 230360 에코마케팅
# 230980 솔트웍스
# 232140 와이아이케이
# 232330 SK3호스팩
# 234100 세원
# 234300 에스트래픽
# 234920 자이글
# 236200 슈프리마
# 237690 에스티팜
# 237750 피앤씨테크
# 237880 클리오
# 238090 앤디포스
# 238120 로고스바이오
# 238200 비피도
# 238490 힘스
# 239340 미래에셋제5호스팩
# 239610 에이치엘사이언스
# 240540 한국4호스팩
# 240810 원익IPS
# 241520 DSC인베스트먼트
# 241690 유니테크노
# 241710 코스메카코리아
# 241770 메카로
# 241790 오션브릿지
# 241820 피씨엘
# 242040 나무기술
# 243070 휴온스
# 243840 신흥에스이씨
# 245620 EDGC
# 246690 티에스인베스트먼트
# 246710 티앤알바이오팹
# 246720 아스타
# 250000 보라티알
# 250060 모비스
# 250930 케이비제10호스팩
# 251370 와이엠티
# 251630 브이원텍
# 252500 세화피앤씨
# 253450 스튜디오드래곤
# 253590 대신밸런스제3호스팩
# 254120 IBKS제5호스팩
# 255220 SG
# 255440 야스
# 256630 엔에이치스팩10호
# 256840 엔에이치스팩11호
# 256940 케이피에스
# 257370 명성티엔에스
# 257730 신한제3호스팩
# 258610 이더블유케이
# 258790 케이비제11호스팩
# 258830 세종메디칼
# 259630 엠플러스
# 260660 알리코제약
# 260930 씨티케이코스메틱스
# 261200 하나금융9호스팩
# 262830 대신밸런스제4호스팩
# 263020 디케이앤디
# 263050 유틸렉스
# 263540 샘코
# 263600 덕우전자
# 263690 디알젬
# 263700 케어랩스
# 263720 디앤씨미디어
# 263750 펄어비스
# 263770 유에스티
# 263800 데이타솔루션
# 263810 상신전자
# 263860 지니언스
# 263920 에스엔피월드
# 264290 한화에이스스팩3호
# 264450 유비쿼스
# 264660 씨앤지하이테크
# 264850 IBKS제6호스팩
# 265480 미래에셋대우스팩1호
# 265520 AP시스템
# 265560 영화테크
# 265920 한화수성스팩
# 267320 교보7호스팩
# 267790 배럴
# 267980 매일유업
# 268600 셀리버리
# 269620 시스웍
# 270520 하나금융10호스팩
# 270870 뉴트리
# 271740 한국제5호스팩
# 272290 이녹스첨단소재
# 273060 엔에이치스팩12호
# 275630 에스에스알
# 276920 IBKS제7호스팩
# 277070 린드먼아시아
# 277410 인산가
# 277480 신한제4호스팩
# 279410 한화에이스스팩4호
# 281410 한국제6호스팩
# 281740 동부스팩5호
# 284620 하나금융11호스팩
# 285490 노바텍
# 287410 유안타제3호스팩
# 288620 에스퓨얼셀
# 289080 SV인베스트먼트
# 290120 대유에이피
# 290270 휴네시온
# 290380 대유
# 290550 디케이티
# 290650 엘앤씨바이오
# 290660 네오펙트
# 290670 대보마그네틱
# 290720 푸드나무
# 290740 액트로
# 291210 한국제7호스팩
# 291230 삼성스팩2호
# 293580 나우아이비캐피탈
# 297570 IBKS제9호스팩
# 298380 에이비엘바이오
# 299170 IBKS제10호스팩
# 299900 위지윅스튜디오
# 299910 베스파
# 302430 이노메트리
# 303030 대신밸런스제5호스팩
# 306620 DB금융스팩6호
# 307070 SK4호스팩
# 307160 하나머스트제6호스팩
# 307180 신영스팩4호
# 307280 교보8호스팩
# 307750 대신밸런스제6호스팩
# 307870 골든브릿지이안5호
# 309930 삼성머스트스팩3호
# 310200 미래에셋대우스팩2호
# 310840 엔에이치스팩13호
# 310870 한국제8호스팩
# 311270 키움제5호스팩
# 900040 차이나그레이트
# 900070 글로벌에스엠
# 900080 에스앤씨엔진그룹
# 900100 뉴프라이드
# 900110 이스트아시아홀딩스
# 900120 씨케이에이치
# 900250 크리스탈신소재
# 900260 로스웰
# 900270 헝셩그룹
# 900280 골든센츄리
# 900290 GRT
# 900300 오가닉티코스메틱
# 900310 컬러레이
# 900340 윙입푸드
# 950110 SBI핀테크솔루션즈
# 950130 엑세스바이오
# 950140 잉글우드랩
# 950160 코오롱티슈진
# 950170 JTC

# %% [markdown]
# # DATABASE 생성 (Excel to MySQL)

# %%
import pandas as pd
from sqlalchemy import create_engine

connect = create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
df = pd.read_sql("SELECT * from market where Name = 'hrs' && Date > '2019-01-05'", connect)

print(len(df['Volume']))
# Out:
# 51

# %%
import pandas as pd
from sqlalchemy import create_engine

connect = create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
df = pd.read_sql("SELECT * from market where Name = 'hrs' && Date > '2019-01-05'", connect)

volume_average_5 = df['Volume'].rolling(window=5).mean()
volume_average_10 = df['Volume'].rolling(window=10).mean()
volume_average_20 = df['Volume'].rolling(window=20).mean()
volume_average_60 = df['Volume'].rolling(window=60).mean()
volume_average_120 = df['Volume'].rolling(window=120).mean()

close_average_5 = df['Close'].rolling(window=5).mean()
close_average_10 = df['Close'].rolling(window=10).mean()
close_average_20 = df['Close'].rolling(window=20).mean()
close_average_60 = df['Close'].rolling(window=60).mean()
close_average_120 = df['Close'].rolling(window=120).mean()

df.insert(len(df.columns), "Vol_MA5", volume_average_5)
df.insert(len(df.columns), "Vol_MA10", volume_average_10)
df.insert(len(df.columns), "Vol_MA20", volume_average_20)
df.insert(len(df.columns), "Vol_MA60", volume_average_60)
df.insert(len(df.columns), "Vol_MA120", volume_average_120)

df.insert(len(df.columns), "Close_MA5", close_average_5)
df.insert(len(df.columns), "Close_MA10", close_average_10)
df.insert(len(df.columns), "Close_MA20", close_average_20)
df.insert(len(df.columns), "Close_MA60", close_average_60)
df.insert(len(df.columns), "Close_MA120", close_average_120)

df1 = df[['Date','Name','Vol_MA5','Vol_MA10','Vol_MA20','Vol_MA60']]
df1
# Out:
#           Date Name   Vol_MA5  Vol_MA10   Vol_MA20  Vol_MA60
# 0   2019-01-07  HRS       NaN       NaN        NaN       NaN
# 1   2019-01-08  HRS       NaN       NaN        NaN       NaN
# 2   2019-01-09  HRS       NaN       NaN        NaN       NaN
# 3   2019-01-10  HRS       NaN       NaN        NaN       NaN
# 4   2019-01-11  HRS   28333.4       NaN        NaN       NaN
# 5   2019-01-14  HRS   30933.4       NaN        NaN       NaN
# 6   2019-01-15  HRS   30725.8       NaN        NaN       NaN
# 7   2019-01-16  HRS   31968.0       NaN        NaN       NaN
# 8   2019-01-17  HRS   38908.2       NaN        NaN       NaN
# 9   2019-01-18  HRS   42597.8   35465.6        NaN       NaN
# 10  2019-01-21  HRS   52730.2   41831.8        NaN       NaN
# 11  2019-01-22  HRS   67220.2   48973.0        NaN       NaN
# 12  2019-01-23  HRS   68954.6   50461.3        NaN       NaN
# 13  2019-01-24  HRS   67878.8   53393.5        NaN       NaN
# 14  2019-01-25  HRS   64654.2   53626.0        NaN       NaN
# 15  2019-01-28  HRS   60661.4   56695.8        NaN       NaN
# 16  2019-01-29  HRS   47822.0   57521.1        NaN       NaN
# 17  2019-01-30  HRS   46248.0   57601.3        NaN       NaN
# 18  2019-01-31  HRS   46618.6   57248.7        NaN       NaN
# 19  2019-02-01  HRS   48547.4   56600.8   46033.20       NaN
# 20  2019-02-07  HRS   46805.8   53733.6   47782.70       NaN
# 21  2019-02-08  HRS   53774.8   50798.4   49885.70       NaN
# 22  2019-02-11  HRS   50861.6   48554.8   49508.05       NaN
# 23  2019-02-12  HRS   55967.4   51293.0   52343.25       NaN
# 24  2019-02-13  HRS   58532.0   53539.7   53582.85       NaN
# 25  2019-02-14  HRS   62569.8   54687.8   55691.80       NaN
# 26  2019-02-15  HRS   60170.8   56972.8   57246.95       NaN
# 27  2019-02-18  HRS   57716.4   54289.0   55945.15       NaN
# 28  2019-02-19  HRS   44724.8   50346.1   53797.40       NaN
# 29  2019-02-20  HRS   42323.2   50427.6   53514.20       NaN
# 30  2019-02-21  HRS   30748.2   46659.0   50196.30       NaN
# 31  2019-02-22  HRS   27743.0   43956.9   47377.65       NaN
# 32  2019-02-25  HRS   25618.6   41667.5   45111.15       NaN
# 33  2019-02-26  HRS   37418.2   41071.5   46182.25       NaN
# 34  2019-02-27  HRS   41850.2   42086.7   47813.20       NaN
# 35  2019-02-28  HRS   50934.4   40841.3   47764.55       NaN
# 36  2019-03-04  HRS   49526.0   38634.5   47803.65       NaN
# 37  2019-03-05  HRS   50720.4   38169.5   46229.25       NaN
# 38  2019-03-06  HRS   38357.0   37887.6   44116.85       NaN
# 39  2019-03-07  HRS   36072.6   38961.4   44694.50       NaN
# 40  2019-03-08  HRS   31187.6   41061.0   43860.00       NaN
# 41  2019-03-11  HRS   34440.2   41983.1   42970.00       NaN
# 42  2019-03-12  HRS   36021.4   43370.9   42519.20       NaN
# 43  2019-03-13  HRS   37051.8   37704.4   39387.95       NaN
# 44  2019-03-14  HRS   34628.8   35350.7   38718.70       NaN
# 45  2019-03-15  HRS  389081.4  210134.5  125487.90       NaN
# 46  2019-03-18  HRS  425424.0  229932.1  134283.30       NaN
# 47  2019-03-19  HRS  441814.4  238917.9  138543.70       NaN
# 48  2019-03-20  HRS  504169.2  270610.5  154249.05       NaN
# 49  2019-03-21  HRS  516493.2  275561.0  157261.20       NaN
# 50  2019-03-22  HRS  178113.8  283597.6  162329.30       NaN

# %%
import pandas as pd
from sqlalchemy import create_engine

df = pd.read_excel('d:\\investortrend.xlsx')
connect = create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')

df.to_sql('investortrend', connect, index=False, if_exists='append')
#df.to_sql('kkang', connect, index=False, if_exists='replace')

# %% [markdown]
# # DATABASE 생성(DataFrame to MySQL)

# %%
# MySQL 접속방법 1
import pymysql as mysql

conn = mysql.connect(
  host="localhost",
  user="kkang",
  passwd="leaf2027",
  database="test"
)

cursor=conn.cursor()
cursor.execute("CREATE TABLE 한독 (Date VARCHAR(32), Code VARCHAR(10),Name VARCHAR(50), Open INT(10), High INT(10), Low INT(10), Volume INT(10), Close INT(10))")
# Out:
# 0

# %%
# MySQL 접속방법 2
import mysql.connector as mysql

mydb = mysql.connect(
  host="localhost",
  user="kkang",
  passwd="leaf2027",
  database="stock"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE customers (name VARCHAR(255), address VARCHAR(255))")

# %%
# MySQL 접속방법 3
import pandas as pd
from sqlalchemy import create_engine

df = pd.read_excel('d:\\data_set\\kospi\\한독.xlsx')
connect = create_engine('mysql+pymysql://kkang:leaf2027@localhost/test?charset=utf8',encoding='utf-8')

# %%
# KOSPI_STOCK PRICE TO MYSQL

import pandas as pd
import FinanceDataReader as fdr
import sqlalchemy 
import pymysql
pymysql.install_as_MySQLdb() # MySQLdb와 호환 
import MySQLdb

engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
conn = engine.connect()

data = pd.read_excel('d:\\market_list.xlsx')

code_list = data['종목코드'].tolist()
code_list = [str(item).zfill(6) for item in code_list]
name_list = data['종목명'].tolist()

# 코스피 상장종목 전체
stock_dic = dict(list(zip(code_list,name_list)))

for code in sorted(stock_dic.keys()):
    df  = fdr.DataReader(code,'2019-02-19')
    print(code,stock_dic[code])
    df['Code'],df['Name'] = code,stock_dic[code]
    df = df[['Code','Name','Open','High','Low','Volume','Close']]
    df.to_sql(name='market', con=engine, if_exists='append')
    #df.to_excel('d:\\data_set\\kospi\\'+ stock_dic[code] +'.xlsx',engine = 'xlsxwriter')

# %%
# KOSDAQ_STOCK PRICE TO MYSQL
import pandas as pd
import FinanceDataReader as fdr
import sqlalchemy 
import pymysql
pymysql.install_as_MySQLdb() # MySQLdb와 호환 
import MySQLdb

engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
conn = engine.connect()

data = pd.read_excel('d:\\kosdaq_list.xlsx')

code_list = data['종목코드'].tolist()
code_list = [str(item).zfill(6) for item in code_list]
name_list = data['종목명'].tolist()

# 코스닥상장종목 전체
stock_dic = dict(list(zip(code_list,name_list)))

for code in stock_dic.keys():
    df  = fdr.DataReader(code,'1995-05-01')
    print(code,stock_dic[code])
    df['Code'],df['Name'] = code,stock_dic[code]
    df = df[['Code','Name','Open','High','Low','Volume','Close']]
    df.to_sql(name='kosdsq', con=engine, if_exists='append')

# %% [markdown]
# # DATABASE READ (MySQL to DataFrame)

# %%
import pandas as pd
from sqlalchemy import create_engine

connect = create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
df = pd.read_sql("SELECT distinct Code,Name from market ", connect)
df.to_excel('d:\\makret_list.xlsx')

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

plt.figure(figsize=(14,6))
connect = create_engine('mysql+pymysql://kkang:leaf2027@localhost/test?charset=utf8',encoding='utf-8')
df = pd.read_sql("SELECT * from 한독 where Date > '2019-01-05'", connect)
plt.plot(df['Close'])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
import sqlalchemy 

## def money_trend_graph():
engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')

yesterday = input("어제날짜를 입력하세요 : sample: '2019-02-07'  ") 
today = input("오늘날짜를 입력하세요 : sample: '2019-02-07'  ")

select_query = "select * from market where Date >="
volume_query = "&& Volume >  500000"

var = select_query +"'"+yesterday+"'"+ volume_query
df = pd.read_sql(var ,engine)

df1 = df[df['Date'].astype(str) == yesterday]
df1 = df1[['Name','Volume','Close']]
df1.columns = ['Name','yester_Volume','yester_Close']
#display(df1)

df2 = df[df['Date'].astype(str) == today]
df2 = df2[['Name','Volume','Close']]
df2.columns = ['Name','today_Volume','today_Close']
#display(df2)

df3 = pd.merge(df1,df2,on='Name')
df3['Close']=df3['today_Close']/df3['yester_Close']
df3['Volume']=df3['today_Volume']/df3['yester_Volume']
df3 = df3.sort_values(by=['Volume','Close'],ascending=False)
df4 = df3.sort_values(by=['Close','Volume'],ascending=False)
df3 = df3.reset_index(drop=True)

df3 = df3[:15]
#df4 = df3.sort_values(by=['Close','Volume'],ascending=False)
df4 = df4.reset_index(drop=True)
df4 = df4[:15]
display(df3)
display(df4)
# Out:
# 어제날짜를 입력하세요 : sample: '2019-02-07'  2019-03-21
# 오늘날짜를 입력하세요 : sample: '2019-02-07'  2019-03-22
#       Name  yester_Volume  yester_Close  today_Volume  today_Close     Close  \
# 0   토박스코리아        2256965          1355      46296711         1590  1.173432
# 1       하츠        1575383          7780      17816102        10100  1.298201
# 2    대유위니아        2269213          3615      22074948         4520  1.250346
# 3      초록뱀         996350          1710       8713101         1595  0.932749
# 4      웰크론        1464148          4310      11321548         4660  1.081206
# 5      아난티        2156652         17550      16398162        14900  0.849003
# 6     와이엔텍         728348          6880       3935954         7880  1.145349
# 7   어보브반도체         654752          5870       3533409         6130  1.044293
# 8  에프앤리퍼블릭        1737510          2040       8923439         2220  1.088235
# 9     모나리자         721198          4420       3162880         4695  1.062217
#
#       Volume
# 0  20.512817
# 1  11.309061
# 2   9.728019
# 3   8.745020
# 4   7.732516
# 5   7.603527
# 6   5.403947
# 7   5.396561
# 8   5.135763
# 9   4.385592
#       Name  yester_Volume  yester_Close  today_Volume  today_Close     Close  \
# 0       하츠        1575383          7780      17816102        10100  1.298201
# 1     인터불스        1780049          1560       3532345         2025  1.298077
# 2     삼우엠스       10525125           487      13623016          620  1.273101
# 3    대유위니아        2269213          3615      22074948         4520  1.250346
# 4   토박스코리아        2256965          1355      46296711         1590  1.173432
# 5     와이엔텍         728348          6880       3935954         7880  1.145349
# 6     비에이치         860445         19450       3235752        21700  1.115681
# 7    에스에프씨        2469499          1905       4380217         2115  1.110236
# 8       코센        1365997          1965       1753137         2140  1.089059
# 9  에프앤리퍼블릭        1737510          2040       8923439         2220  1.088235
#
#       Volume
# 0  11.309061
# 1   1.984409
# 2   1.294333
# 3   9.728019
# 4  20.512817
# 5   5.403947
# 6   3.760556
# 7   1.773727
# 8   1.283412
# 9   5.135763

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
import sqlalchemy 

## def money_trend_graph():
engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
    
name = input("항목을 입력하세요: 선택항목: 'kpi200', '거래량', '고객예탁금', '신용잔고', '주식형펀드', '혼합형펀드', '채권형펀드' : ").split()
date = input("날짜를 입력하세요 sample: '2019-01-10':")
    
query = "select * from kpi_with_money where Date >"+"'"+date+"'"
    
tuple_name=tuple(name)
df1 = pd.DataFrame()
    
df = pd.read_sql(query ,engine)

df.columns=['Date','kpi200', '거래량', '고객예탁금', '신용잔고', '주식형펀드', '혼합형펀드', '채권형펀드']
df = df.set_index('Date')
df1=df[name]

plt.figure(figsize=(16,4))
colors = ['orange','green','blue','red']
for i in range(len(name)):
    plt.subplot(2,2,i+1)
    plt.plot(df1[name[i]]/df1[name[i]].loc[df.index[0]]*100,color=colors[i] )
    
    plt.legend(loc=0)
    plt.grid(True,color='0.7',linestyle=':',linewidth=1)
# Out:
# 항목을 입력하세요: 선택항목: 'kpi200', '거래량', '고객예탁금', '신용잔고', '주식형펀드', '혼합형펀드', '채권형펀드' : kpi200
# 날짜를 입력하세요 sample: '2019-01-10':2018=01-01

# %%
## 거래량 평균으로 일일 거래량 나눔

import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
import sqlalchemy 

font_dir = font_manager.win32FontDirectory()

engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
conn = engine.connect()


date = input("날짜를 입력하세요 sample: '2019-01-10':")
name = input('주식이름을 입력하세요:').split()
#date = input("날짜를 입력하세요 sample: '2019-01-10':")
        
select_query = "select Date,Volume,Close from market where Name= "
date_query = "Date > "
    

tuple_name=tuple(name)
df1 = pd.DataFrame()
    
for x in tuple_name:
    var = select_query +"'"+x+"'"+" "+"&&"+" "+date_query+"'"+date+"'"
    df = pd.read_sql(var ,engine)
    #print(df)
    df.columns=['Date',x+'거래량',x]
    if df1.empty:
        df1 = df
    else:
        df1 = pd.merge (df,df1,on='Date')
df1=df1.set_index('Date')
size = len(df1.index)

plt.figure(figsize=(16,4))
for i in range(len(name)):
    plt.plot(df1[name[i]]/df1[name[i]].loc[df['Date'][0]]*100)
    #plt.plot(df1[name[i]+'거래량']/df1[name[i]+'거래량'].loc[df['Date'][0]]*100, label =[name[i]+'거래량'] )
    plt.legend(loc=0)
    plt.grid(True,color='0.7',linestyle=':',linewidth=1)

plt.figure(figsize=(16,4))
for i in range(len(name)):
    volume_average = df1[name[i]+'거래량'].sum(axis=0)/size
    #plt.plot(df1[name[i]]/df1[name[i]].loc[df['Date'][0]]*100, label=name[i])
    plt.plot(df1[name[i]+'거래량']/volume_average)
    plt.legend(loc=0)
    plt.grid(True,color='0.7',linestyle=':',linewidth=1)
            
plt.show()
# Out:
# 날짜를 입력하세요 sample: '2019-01-10':2010-01-01
# 주식이름을 입력하세요:포스코엠텍 한국내화 hrs

# %%
# KOSPI_STOCK PRICE TO MYSQL

import pandas as pd
import FinanceDataReader as fdr
import sqlalchemy 
import pymysql
pymysql.install_as_MySQLdb() # MySQLdb와 호환 
import MySQLdb

engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/test?charset=utf8',encoding='utf-8')
conn = engine.connect()

import FinanceDataReader as fdr
df  = fdr.DataReader('002390','2019-01-01')
#print(code,stock_dic[code])
df['Code'],df['Name'] = '002390','한독'
df = df[['Code','Name','Open','High','Low','Volume','Close']]
df.to_sql(name='한독', con = engine, if_exists='replace')

# %%
# KOSPI_STOCK PRICE TO MYSQL

import pandas as pd
import FinanceDataReader as fdr
import sqlalchemy 
import pymysql
pymysql.install_as_MySQLdb() # MySQLdb와 호환 
import MySQLdb

engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/test?charset=utf8',encoding='utf-8')
conn = engine.connect()

data = pd.read_excel('d:\\kospi_list.xlsx')

code_list = data['종목코드'].tolist()
code_list = [str(item).zfill(6) for item in code_list]
name_list = data['종목명'].tolist()

# 코스피 상장종목 전체
stock_dic = dict(list(zip(code_list,name_list)))

for code in stock_dic.keys():
    df  = fdr.DataReader(code,'1995-05-01')
    print(code,stock_dic[code])
    df['Code'],df['Name'] = code,stock_dic[code]
    df = df[['Code','Name','Open','High','Low','Volume','Close']]
    df.to_sql(name='kospi', con=engine, if_exists='append')
    #df.to_excel('d:\\data_set\\kospi\\'+ stock_dic[code] +'.xlsx',engine = 'xlsxwriter')
# Out:
# 900140 엘브이엠씨홀딩스
# 002390 한독

# %% [markdown]
# # 증시자금동향 (Web Crawling to Excel)

# %%
import pandas as pd
from pandas import DataFrame, Series
import requests as re
from bs4 import BeautifulSoup
import datetime as date
from urllib.request import urlopen



def get_money_trend():
    
    url = 'http://finance.naver.com/sise/sise_deposit.nhn?&page='

    source = urlopen(url).read()   # 지정한 페이지에서 코드 읽기
    source = BeautifulSoup(source, 'lxml')   # 뷰티풀 스프로 태그별로 코드 분류

    last = source.find('td',class_='pgRR').find('a')['href']
    last = last.split('page')[1]
    last = last.split('=')[1]
    last = int(last)

    # 사용자의 PC내 폴더 주소를 입력하시면 됩니다.
    path = 'd:\\moneytrend.xlsx'   
    
    # 날짜를 받을 리스트
    date_list = []

    # 값을 받을 사전
    dictionary = {'고객예탁금': [],'신용잔고': [],'주식형 펀드': [],'혼합형 펀드': [],'채권형 펀드': []}

    # dictionary key 인덱싱을 위한 리스트
    name_list = ['고객예탁금','신용잔고','주식형 펀드','혼합형 펀드','채권형 펀드']


    # count mask
    mask = [1,3,5,7,9]
    
    for i in range(1,last+1):
        
        source = urlopen(url+ str(i)).read()
        source = BeautifulSoup(source,'lxml')

        #tbody = source.find('div',{'id':'wrap'}).find('div',{'class':'box_type_m'})
        #trs = tbody.find_all('tr')

        body = source.find('body')
        trs = body.find_all('tr')

        for tr in trs:
            tds = tr.find_all('td',{'class':['date','rate_down','rate_up']})
            count = 0
    
            for td in tds:
                if count == 0:
                    date_ = td.text.strip().replace('.','-')
                    date_list.append(date_)
                        
                      
                elif count in mask:
                    temp = int((count-1)/2)
                    dictionary[name_list[temp]].append(td.text.strip().replace(',',''))
        
                count += 1
            if len(dictionary[date_list]) != len(dictionary['채권형 펀드']):
                print(str(i)+ '번째 페이지에서 누락된 값 발생')
                print('누락된 데이터를 제거합니다')
                    
                date_list.pop(-1)
                dictionary['고객예탁금'].pop(-1)
                dictionary['신용잔고'].pop(-1)
                dictionary['주식형 펀드'].pop(-1)
                dictionary['혼합형 펀드'].pop(-1)
                
    # 개별 list 요소 갯수 파악 
    #print(len(date_list))
    #print(len(dictionary['고객예탁금']))
    #print(len(dictionary['신용잔고']))
    #print(len(dictionary['주식형 펀드']))
    #print(len(dictionary['혼합형 펀드']))
    #print(len(dictionary['채권형 펀드']))
    print(str(i) + '번째 페이지 크롤링 완료')
    df = pd.DataFrame(dictionary,index = date_list)
    df = df.sort_index()
    df.to_excel(path, encoding='utf-8')
    print(df)


get_money_trend()
# Out:
# 1번째 페이지 크롤링 완료
# 2번째 페이지 크롤링 완료
# 3번째 페이지 크롤링 완료
# 4번째 페이지 크롤링 완료
# 5번째 페이지 크롤링 완료
# 6번째 페이지 크롤링 완료
# 7번째 페이지 크롤링 완료
# 8번째 페이지 크롤링 완료
# 9번째 페이지 크롤링 완료
# 10번째 페이지 크롤링 완료
# 11번째 페이지 크롤링 완료
# 12번째 페이지 크롤링 완료
# 13번째 페이지 크롤링 완료
# 14번째 페이지 크롤링 완료
# 15번째 페이지 크롤링 완료
# 16번째 페이지 크롤링 완료
# 17번째 페이지 크롤링 완료
# 18번째 페이지 크롤링 완료
# 19번째 페이지 크롤링 완료
# 20번째 페이지 크롤링 완료
# 21번째 페이지 크롤링 완료
# 22번째 페이지 크롤링 완료
# 23번째 페이지 크롤링 완료
# 24번째 페이지 크롤링 완료
# 25번째 페이지 크롤링 완료
# 26번째 페이지 크롤링 완료
# 27번째 페이지 크롤링 완료
# 28번째 페이지 크롤링 완료
# 29번째 페이지 크롤링 완료
# 30번째 페이지 크롤링 완료
# 31번째 페이지 크롤링 완료
# 32번째 페이지 크롤링 완료
# 33번째 페이지 크롤링 완료
# 34번째 페이지 크롤링 완료
# 35번째 페이지 크롤링 완료
# 36번째 페이지 크롤링 완료
# 37번째 페이지 크롤링 완료
# 38번째 페이지 크롤링 완료
# 39번째 페이지 크롤링 완료
# 40번째 페이지 크롤링 완료
# 41번째 페이지 크롤링 완료
# 42번째 페이지 크롤링 완료
# 43번째 페이지 크롤링 완료
# 44번째 페이지 크롤링 완료
# 45번째 페이지 크롤링 완료
# 46번째 페이지 크롤링 완료
# 47번째 페이지 크롤링 완료
# 48번째 페이지 크롤링 완료
# 49번째 페이지 크롤링 완료
# 50번째 페이지 크롤링 완료
# 51번째 페이지 크롤링 완료
# 52번째 페이지 크롤링 완료
# 53번째 페이지 크롤링 완료
# 54번째 페이지 크롤링 완료
# 55번째 페이지 크롤링 완료
# 56번째 페이지 크롤링 완료
# 57번째 페이지 크롤링 완료
# 58번째 페이지 크롤링 완료
# 59번째 페이지 크롤링 완료
# 60번째 페이지 크롤링 완료
# 61번째 페이지 크롤링 완료
# 62번째 페이지 크롤링 완료
# 63번째 페이지 크롤링 완료
# 64번째 페이지 크롤링 완료
# 65번째 페이지 크롤링 완료
# 66번째 페이지 크롤링 완료
# 67번째 페이지 크롤링 완료
# 68번째 페이지 크롤링 완료
# 69번째 페이지 크롤링 완료
# 70번째 페이지 크롤링 완료
# 71번째 페이지 크롤링 완료
# 72번째 페이지 크롤링 완료
# 73번째 페이지 크롤링 완료
# 74번째 페이지 크롤링 완료
# 75번째 페이지 크롤링 완료
# 76번째 페이지 크롤링 완료
# 77번째 페이지 크롤링 완료
# 78번째 페이지 크롤링 완료
# 79번째 페이지 크롤링 완료
# 80번째 페이지 크롤링 완료
# 81번째 페이지 크롤링 완료
# 82번째 페이지 크롤링 완료
# 83번째 페이지 크롤링 완료
# 84번째 페이지 크롤링 완료
# 85번째 페이지 크롤링 완료
# 86번째 페이지 크롤링 완료
# 87번째 페이지 크롤링 완료
# 88번째 페이지 크롤링 완료
# 89번째 페이지 크롤링 완료
# 90번째 페이지 크롤링 완료
# 91번째 페이지 크롤링 완료
# 92번째 페이지 크롤링 완료
# 93번째 페이지 크롤링 완료
# 94번째 페이지 크롤링 완료
# 95번째 페이지 크롤링 완료
# 96번째 페이지 크롤링 완료
# 97번째 페이지 크롤링 완료
# 98번째 페이지 크롤링 완료
# 99번째 페이지 크롤링 완료
# 100번째 페이지 크롤링 완료
# 101번째 페이지 크롤링 완료
# 102번째 페이지 크롤링 완료
# 103번째 페이지 크롤링 완료
# 104번째 페이지 크롤링 완료
# 105번째 페이지 크롤링 완료
# 106번째 페이지 크롤링 완료
# 107번째 페이지 크롤링 완료
# 108번째 페이지 크롤링 완료
# 109번째 페이지 크롤링 완료
# 110번째 페이지 크롤링 완료
# 111번째 페이지 크롤링 완료
# 112번째 페이지 크롤링 완료
# 113번째 페이지 크롤링 완료
# 114번째 페이지 크롤링 완료
# 115번째 페이지 크롤링 완료
# 116번째 페이지 크롤링 완료
# 117번째 페이지 크롤링 완료
# 118번째 페이지 크롤링 완료
# 119번째 페이지 크롤링 완료
# 120번째 페이지 크롤링 완료
# 121번째 페이지 크롤링 완료
# 122번째 페이지 크롤링 완료
# 123번째 페이지에서 누락된 값 발생
# 누락된 데이터를 제거합니다
# 123번째 페이지 크롤링 완료
# 124번째 페이지 크롤링 완료
# 125번째 페이지 크롤링 완료
# 126번째 페이지 크롤링 완료
# 127번째 페이지 크롤링 완료
# 128번째 페이지 크롤링 완료
# 129번째 페이지 크롤링 완료
# 130번째 페이지 크롤링 완료
# 131번째 페이지 크롤링 완료
# 132번째 페이지 크롤링 완료
# 133번째 페이지 크롤링 완료
# 134번째 페이지 크롤링 완료
# 135번째 페이지 크롤링 완료
# 136번째 페이지 크롤링 완료
# 137번째 페이지 크롤링 완료
# 138번째 페이지 크롤링 완료
# 139번째 페이지 크롤링 완료
# 140번째 페이지 크롤링 완료
# 141번째 페이지 크롤링 완료
# 142번째 페이지 크롤링 완료
# 143번째 페이지 크롤링 완료
# 144번째 페이지 크롤링 완료
# 145번째 페이지 크롤링 완료
# 146번째 페이지 크롤링 완료
# 147번째 페이지 크롤링 완료
# 148번째 페이지 크롤링 완료
# 149번째 페이지 크롤링 완료
# 150번째 페이지 크롤링 완료
# 151번째 페이지 크롤링 완료
# 152번째 페이지 크롤링 완료
# 153번째 페이지 크롤링 완료
# 154번째 페이지 크롤링 완료
# 155번째 페이지 크롤링 완료
# 156번째 페이지 크롤링 완료
# 157번째 페이지 크롤링 완료
# 158번째 페이지 크롤링 완료
# 159번째 페이지 크롤링 완료
# 160번째 페이지 크롤링 완료
# 161번째 페이지 크롤링 완료
# 162번째 페이지 크롤링 완료
# 163번째 페이지 크롤링 완료
# 164번째 페이지 크롤링 완료
# 165번째 페이지 크롤링 완료
# 166번째 페이지 크롤링 완료
# 167번째 페이지 크롤링 완료
# 168번째 페이지 크롤링 완료
# 169번째 페이지 크롤링 완료
# 170번째 페이지 크롤링 완료
# 171번째 페이지 크롤링 완료
# 172번째 페이지 크롤링 완료
# 173번째 페이지 크롤링 완료
# 174번째 페이지 크롤링 완료
# 175번째 페이지 크롤링 완료
# 176번째 페이지 크롤링 완료
# 177번째 페이지 크롤링 완료
# 178번째 페이지 크롤링 완료
# 179번째 페이지 크롤링 완료
# 180번째 페이지 크롤링 완료
# 181번째 페이지 크롤링 완료
# 182번째 페이지 크롤링 완료
# 183번째 페이지 크롤링 완료
# 184번째 페이지 크롤링 완료
# 185번째 페이지 크롤링 완료
# 186번째 페이지 크롤링 완료
# 187번째 페이지 크롤링 완료
# 188번째 페이지 크롤링 완료
# 189번째 페이지 크롤링 완료
# 190번째 페이지 크롤링 완료
# 191번째 페이지 크롤링 완료
# 192번째 페이지 크롤링 완료
# 193번째 페이지 크롤링 완료
# 194번째 페이지 크롤링 완료
# 195번째 페이지 크롤링 완료
# 196번째 페이지 크롤링 완료
# 197번째 페이지 크롤링 완료
# 198번째 페이지 크롤링 완료
# 199번째 페이지 크롤링 완료
# 200번째 페이지 크롤링 완료
# 201번째 페이지 크롤링 완료
# 202번째 페이지 크롤링 완료
# 203번째 페이지 크롤링 완료
# 204번째 페이지 크롤링 완료
# 205번째 페이지 크롤링 완료
# 206번째 페이지 크롤링 완료
# 207번째 페이지 크롤링 완료
# 207번째 페이지에서 크롤링 종료

# %%
def get_money_trend_date():
    url = 'http://finance.naver.com/sise/sise_deposit.nhn?&page='

    source = urlopen(url).read()   # 지정한 페이지에서 코드 읽기
    source = BeautifulSoup(source, 'lxml')   # 뷰티풀 스프로 태그별로 코드 분류

    last = source.find('td',class_='pgRR').find('a')['href']
    last = last.split('page')[1]
    last = last.split('=')[1]
    last = int(last)

    # 사용자의 PC내 폴더 주소를 입력하시면 됩니다.
    path = 'd:\\money_trend.xlsx'

    
    until_date = input("날짜를 입력하세요 sample: '2019-01-10': ")
    
    year = until_date.split('-')[0]
    mm = until_date.split('-')[1]
    dd = until_date.split('-')[2]
    year=year[2:]
    until_date = year+'-'+mm+'-'+dd
    
    #df = DataFrame(columns = ['고객예탁금', '신용잔고','주식형 펀드','혼합형 펀드','채권형 펀드'])

    # 날짜를 받을 리스트
    date_list = []

    
    # 값을 받을 사전
    dictionary = {'고객예탁금': [],'신용잔고': [],'주식형 펀드': [],'혼합형 펀드': [],'채권형 펀드': []}

    # dictionary key 인덱싱을 위한 리스트
    name_list = ['고객예탁금','신용잔고','주식형 펀드','혼합형 펀드','채권형 펀드']


    # count mask
    mask = [1,3,5,7,9]
    
    for i in range(1,3):
        
        source = urlopen(url+ str(i)).read()
        source = BeautifulSoup(source,'lxml')

        #tbody = source.find('div',{'id':'wrap'}).find('div',{'class':'box_type_m'})
        #trs = tbody.find_all('tr')

        body = source.find('body')
        trs = body.find_all('tr')

        for tr in trs:
            tds = tr.find_all('td',{'class':['date','rate_down','rate_up']})
            count = 0
    
            for td in tds:
                if count == 0:
                    date_ = td.text.strip().replace('.','-')
                    if date_ <=  until_date :
                    #if date_ <=  '19-03-05' :
                            df = pd.DataFrame(dictionary,index = date_list)
                            df = df.sort_index()
                            return df
                    date_list.append(date_)
                    
                elif count in mask:
                    temp = int((count-1)/2)
                    dictionary[name_list[temp]].append(td.text.strip())
                
       
                count += 1

get_money_trend_date()
# Out:
# 날짜를 입력하세요 sample: '2019-01-10': 2019-03-05
#             고객예탁금     신용잔고   주식형 펀드   혼합형 펀드     채권형 펀드
# 19-03-06  247,923  102,065  872,328  275,484  1,071,527
# 19-03-07  247,796  102,702  868,665  275,411  1,073,283
# 19-03-08  245,048  103,279  861,405  275,408  1,074,245
# 19-03-11  249,915  103,175  861,947  275,543  1,076,049
# 19-03-12  241,209  103,111  864,535  275,569  1,072,923
# 19-03-13  248,093  103,310  861,124  275,556  1,073,121

# %% [markdown]
# # 투자자별 매매동향 ( Web Crawling to Excel)

# %%
def get_investor_trend():
    
    url = 'http://finance.naver.com/sise/investorDealTrendDay.nhn?bizdate=2020601&sosok=&page='

    source = urlopen(url).read()   # 지정한 페이지에서 코드 읽기
    source = BeautifulSoup(source, 'lxml')   # 뷰티풀 스프로 태그별로 코드 분류

    last = source.find('td',class_='pgRR').find('a')['href']
    last = last.split('page')[1]
    last = last.split('=')[1]
    last = int(last)
    print(last)

    # 사용자의 PC내 폴더 주소를 입력하시면 됩니다.
    path = 'd:\\investor_trend.xlsx'
    
    # 날짜를 받을 리스트
    date_list = []

    # 값을 받을 사전
    dictionary = {'개인': [],'외국인': [],'기관': []}

    # dictionary key 인덱싱을 위한 리스트
    name_list = ['개인','외국인','기관']


    # count mask
    mask = [1,2,3]
    
    for i in range(1,last+1):
        
        source = urlopen(url+ str(i)).read()
        source = BeautifulSoup(source,'lxml')

        #tbody = source.find('div',{'id':'wrap'}).find('div',{'class':'box_type_m'})
        #trs = tbody.find_all('tr')

        body = source.find('body')
        trs = body.find_all('tr')

        for tr in trs:
            tds = tr.find_all('td',{'class':['date2','rate_down3','rate_up3']})
            count = 0
    
            for td in tds:
                if count == 0:
                    date_ = td.text.strip().replace('.','-')
                    date_list.append(date_)
                        
                      
                elif count in mask:
                    temp = int(count-1)
                    dictionary[name_list[temp]].append(td.text.strip().replace(',',''))
        
                count += 1
            if len(date_list) != len(dictionary['개인']):
                print(str(i)+ '번째 페이지에서 누락된 값 발생')
                print('누락된 데이터를 제거합니다')
                    
                date_list.pop(-1)
                dictionary['개인'].pop(-1)
                dictionary['외국인'].pop(-1)
                dictionary['기관'].pop(-1)
                
    # 개별 list 요소 갯수 파악 
    #print(len(date_list))
    #print(len(dictionary['개인']))
    #print(len(dictionary['외국인']))
    #print(len(dictionary['기관']))

    print(str(i) + '번째 페이지 크롤링 완료')
    df = pd.DataFrame(dictionary,index = date_list)
    df = df.sort_index()
    df.to_excel(path, encoding='utf-8')
    print(df)

get_investor_trend()

# %%
def get_investor_trend_date():
    
    url = 'http://finance.naver.com/sise/investorDealTrendDay.nhn?bizdate=2020601&sosok=&page='

    source = urlopen(url).read()   # 지정한 페이지에서 코드 읽기
    source = BeautifulSoup(source, 'lxml')   # 뷰티풀 스프로 태그별로 코드 분류

    last = source.find('td',class_='pgRR').find('a')['href']
    last = last.split('page')[1]
    last = last.split('=')[1]
    last = int(last)
    print(last)

    # 사용자의 PC내 폴더 주소를 입력하시면 됩니다.
    path = 'd:\\investor_trend.xlsx'

    until_date = input("날짜를 입력하세요 sample: '2019-01-10': ")
    
    year = until_date.split('-')[0]
    mm = until_date.split('-')[1]
    dd = until_date.split('-')[2]
    year=year[2:]
    until_date = year+'-'+mm+'-'+dd
    
    # 날짜를 받을 리스트
    date_list = []

    # 값을 받을 사전
    dictionary = {'개인': [],'외국인': [],'기관': []}

    # dictionary key 인덱싱을 위한 리스트
    name_list = ['개인','외국인','기관']


    # count mask
    mask = [1,2,3]
    
    for i in range(1,2):
        
        source = urlopen(url+ str(i)).read()
        source = BeautifulSoup(source,'lxml')

        #tbody = source.find('div',{'id':'wrap'}).find('div',{'class':'box_type_m'})
        #trs = tbody.find_all('tr')

        body = source.find('body')
        trs = body.find_all('tr')

        for tr in trs:
            tds = tr.find_all('td',{'class':['date2','rate_down3','rate_up3']})
            count = 0
    
            for td in tds:
                if count == 0:
                    date_ = td.text.strip().replace('.','-')
                    if date_ <=  until_date :
                        df = pd.DataFrame(dictionary,index = date_list)
                        df = df.sort_index()
                        df.to_excel(path, encoding='utf-8')
                        return df   
                    date_list.append(date_)
                    #print(date_list)
                elif count in mask:
                    temp = int(count-1)
                    dictionary[name_list[temp]].append(td.text.strip().replace(',',''))
                    
                count += 1
get_investor_trend()

# %% [markdown]
# # KOSPI200  ( Web Crawling to Excel)

# %%
def get_kpi200():
    
    url = 'https://finance.naver.com/sise/sise_index_day.nhn?code=KPI200&page='

    source = urlopen(url).read()   # 지정한 페이지에서 코드 읽기
    source = BeautifulSoup(source, 'lxml')   # 뷰티풀 스프로 태그별로 코드 분류

    last = source.find('td',class_='pgRR').find('a')['href']
    last = last.split('page')[1]
    last = last.split('=')[1]
    last = int(last)
    print(last)

    # 사용자의 PC내 폴더 주소를 입력하시면 됩니다.
    path = 'd:\\kpi200.xlsx'
    
    # 날짜를 받을 리스트
    date_list = []

    # 값을 받을 사전
    dictionary = {'KPI200': [],'거래량': []}

    # dictionary key 인덱싱을 위한 리스트
    name_list = ['KPI200','거래량']


    # count mask
    mask = [1,3]
    
    for i in range(1,last+1):
        
        source = urlopen(url+ str(i)).read()
        source = BeautifulSoup(source,'lxml')

        #tbody = source.find('div',{'id':'wrap'}).find('div',{'class':'box_type_m'})
        #trs = tbody.find_all('tr')

        body = source.find('body')
        trs = body.find_all('tr')

        for tr in trs:
            tds = tr.find_all('td',{'class':['date','number_1']})
            count = 0
    
            for td in tds:
                if count == 0:
                    date_ = td.text.strip().replace('.','-')
                    date_list.append(date_)
                        
                      
                elif count in mask:
                    temp = int(count/3)
                    dictionary[name_list[temp]].append(td.text.strip().replace(',',''))
        
                count += 1
            if len(date_list) != len(dictionary['KPI200']):
                print(str(i)+ '번째 페이지에서 누락된 값 발생')
                print('누락된 데이터를 제거합니다')
                    
                date_list.pop(-1)
                dictionary['KPI200'].pop(-1)
                dictionary['거래량'].pop(-1)
                
    # 개별 list 요소 갯수 파악 
    #print(len(date_list))
    #print(len(dictionary['개인']))
    #print(len(dictionary['외국인']))
    #print(len(dictionary['기관']))

    print(str(i) + '번째 페이지 크롤링 완료')
    df = pd.DataFrame(dictionary,index = date_list)
    df = df.sort_index()
    df.to_excel(path, encoding='utf-8')
    print(df)

get_kpi200()

# %%
def get_kpi200_date():
    
    url = 'https://finance.naver.com/sise/sise_index_day.nhn?code=KPI200&page='

    source = urlopen(url).read()   # 지정한 페이지에서 코드 읽기
    source = BeautifulSoup(source, 'lxml')   # 뷰티풀 스프로 태그별로 코드 분류

    last = source.find('td',class_='pgRR').find('a')['href']
    last = last.split('page')[1]
    last = last.split('=')[1]
    last = int(last)
    print(last)

    # 사용자의 PC내 폴더 주소를 입력하시면 됩니다.
    path = 'd:\\kpi200.xlsx'

    until_date = input("날짜를 입력하세요 sample: '2019-01-10': ")
    
    year = until_date.split('-')[0]
    mm = until_date.split('-')[1]
    dd = until_date.split('-')[2]
    #year=year[2:]
    until_date = year+'-'+mm+'-'+dd
    
    # 날짜를 받을 리스트
    date_list = []

    # 값을 받을 사전
    dictionary = {'KPI200': [],'거래량': []}

    # dictionary key 인덱싱을 위한 리스트
    name_list = ['KPI200','거래량']


    # count mask
    mask = [1,3]
    
    for i in range(1,last+1):
        
        source = urlopen(url+ str(i)).read()
        source = BeautifulSoup(source,'lxml')

        #tbody = source.find('div',{'id':'wrap'}).find('div',{'class':'box_type_m'})
        #trs = tbody.find_all('tr')

        body = source.find('body')
        trs = body.find_all('tr')

        for tr in trs:
            tds = tr.find_all('td',{'class':['date','number_1']})
            count = 0
    
            for td in tds:
                if count == 0:
                    date_ = td.text.strip().replace('.','-')
                    if date_ <=  until_date :
                    #if date_ <=  '19-03-05' :
                        df = pd.DataFrame(dictionary,index = date_list)
                        df = df.sort_index()
                        df.to_excel(path, encoding='utf-8')
                        return df   
                    date_list.append(date_)
                    #print(date_list)
                elif count in mask:
                    temp = int(count/3)
                    dictionary[name_list[temp]].append(td.text.strip().replace(',',''))
                    #print(dictionary[name_list[temp]])
                count += 1
                
get_kpi200_date()

# %%
from urllib.request import urlopen
import datetime as dt
import pandas as pd
import bs4

def date_format(d):
    d = str(d).replace('-', '.')
    
    yyyy = int(d.split('.')[0]) 
    mm = int(d.split('.')[1])
    dd = int(d.split('.')[2])

    this_date= dt.date(yyyy,mm,dd)
    return this_date

def historical_index_naver(index_cd, start_date='', end_date='', page_n=1, last_page=0):
    
    if start_date:   # start_date가 있으면
        start_date = date_format(start_date)   # date 포맷으로 변환
    else:    # 없으면
        start_date = dt.date.today()   # 오늘 날짜를 지정
        
    if end_date:   
        end_date = date_format(end_date)   
    else:   
        end_date = dt.date.today()  
        
        
    naver_index = 'http://finance.naver.com/sise/sise_index_day.nhn?code=' + index_cd + '&page=' + str(page_n)
    
    source = urlopen(naver_index).read()   # 지정한 페이지에서 코드 읽기
    source = bs4.BeautifulSoup(source, 'lxml')   # 뷰티풀 스프로 태그별로 코드 분류
    
    dates = source.find_all('td', class_='date')   # <td class="date">태그에서 날짜 수집   
    prices = source.find_all('td', class_='number_1')   # <td class="number_1">태그에서 지수 수집
    
    for n in range(len(dates)):
    
        if dates[n].text.split('.')[0].isdigit():
            
            # 날짜 처리
            this_date = dates[n].text
            this_date= date_format(this_date)
            
            if this_date <= end_date and this_date >= start_date:   
            # start_date와 end_date 사이에서 데이터 저장
                # 종가 처리
                this_close = prices[n*4].text   # prices 중 종가지수인 0,4,8,...번째 데이터 추출
                this_close = this_close.replace(',', '')
                this_close = float(this_close)

                # 딕셔너리에 저장
                historical_prices[this_date] = this_close
                
            elif this_date < start_date:   
            # start_date 이전이면 함수 종료
                return historical_prices              
            
    # 페이지 네비게이션
    if last_page == 0:
        last_page = source.find('td', class_='pgRR').find('a')['href']
        # 마지막페이지 주소 추출
        last_page = last_page.split('&')[1]   # & 뒤의 page=506 부분 추출
        last_page = last_page.split('=')[1]   # = 뒤의 페이지번호만 추출
        last_page = int(last_page)   # 숫자형 변수로 변환
        
    # 다음 페이지 호출
    if page_n < last_page:   
        page_n = page_n + 1   
        historical_index_naver(index_cd, start_date, end_date, page_n, last_page)   
        
    return historical_prices  

index_cd = 'KPI200'
historical_prices = dict()
historical_index_naver(index_cd,'2006-1-1')
historical_prices

historical_prices = {'KOSPI200':historical_prices}
df = pd.DataFrame(historical_prices)
df.to_excel('d:\\kospi200.xlsx')

# %% [markdown]
# # Test

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
import sqlalchemy 

engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
conn = engine.connect()

# %%
def get_graph(date = '2018-01-01'):
    graph = input("그래프종류를 입력하세요 sample: 'money' or 'program': ")
    date = input("날짜를 입력하세요 sample: '2019-01-10':")
    
    if graph == 'money' :
        money_name = ['kpi200', '거래량', '고객예탁금', '신용잔고']
        money_query = "select * from kpi_with_money where Date >"+"'"+date+"'"
        money_df = pd.read_sql(money_query ,engine)
        
        money_df.columns=['Date','kpi200', '거래량', '고객예탁금', '신용잔고', '주식형펀드', '혼합형펀드', '채권형펀드']
        money_df = money_df.set_index('Date')
        df1 = money_df[money_name]
        #return df1

        plt.figure(figsize=(16,4))         
        colors = ['red','green','blue','black']
        for i in range(len(money_name)):

            plt.subplot(2,2,i+1)
            plt.plot(df1[money_name[i]]/df1[money_name[i]].loc[money_df.index[0]]*100,color=colors[i])
    
            plt.legend(loc=0)
            plt.grid(True,color='0.7',linestyle=':',linewidth=1)
            #plt.show()
        
    elif graph == 'program' :
        program_name = ['차익', '비차익', '전체']
        program_query = "select * from programtrend where Date >"+"'"+date+"'"
        program_df = pd.read_sql(program_query ,engine)
    
        program_df.columns=['Date','차익', '비차익', '전체']
        program_df = program_df.set_index('Date')
        df1=program_df[program_name]
        #return df1

        plt.figure(figsize=(16,4))        
        colors = ['red','green','blue','black']
        for i in range(len(program_name)):

            plt.subplot(2,2,i+1)
            plt.plot(df1[program_name[i]],color=colors[i])
        
            plt.legend(loc=0)
            plt.grid(True,color='0.7',linestyle=':',linewidth=1)
            #plt.show()

get_graph()
# Out:
# 그래프종류를 입력하세요 sample: 'money' or 'program': program
# 날짜를 입력하세요 sample: '2019-01-10':2019-03-11

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
import sqlalchemy 

def get_graph(date = '2018-01-01'):
    graph = input("그래프종류를 입력하세요 sample: 'money' or 'program' or 'stock': ")
    date = input("날짜를 입력하세요 sample: '2019-01-10':")
    
    if graph == 'money' :
        money_name = ['kpi200', '거래량', '고객예탁금', '신용잔고']
        money_query = "select * from kpi_with_money where Date >"+"'"+date+"'"
        money_df = pd.read_sql(money_query ,engine)
        
        money_df.columns=['Date','kpi200', '거래량', '고객예탁금', '신용잔고', '주식형펀드', '혼합형펀드', '채권형펀드']
        money_df = money_df.set_index('Date')
        df1 = money_df[money_name]
        #return df1

        plt.figure(figsize=(16,4))         
        colors = ['red','green','blue','black']
        for i in range(len(money_name)):

            plt.subplot(2,2,i+1)
            plt.plot(df1[money_name[i]]/df1[money_name[i]].loc[money_df.index[0]]*100,color=colors[i])
    
            plt.legend(loc=0)
            plt.grid(True,color='0.7',linestyle=':',linewidth=1)
            #plt.show()
        
    elif graph == 'program' :
        program_name = ['차익', '비차익', '전체']
        program_query = "select * from programtrend where Date >"+"'"+date+"'"
        program_df = pd.read_sql(program_query ,engine)
    
        program_df.columns=['Date','차익', '비차익', '전체']
        program_df = program_df.set_index('Date')
        df1=program_df[program_name]
        #return df1

        plt.figure(figsize=(16,4))        
        colors = ['red','green','blue','black']
        for i in range(len(program_name)):

            plt.subplot(2,2,i+1)
            plt.plot(df1[program_name[i]],color=colors[i])
        
            plt.legend(loc=0)
            plt.grid(True,color='0.7',linestyle=':',linewidth=1)
            #plt.show()
            
    elif graph == 'stock' :
        name = input('주식이름을 입력하세요:').split()
        #date = input("날짜를 입력하세요 sample: '2019-01-10':")
        
        select_query = "select Date,Close from market where Name= "
        date_query = "Date > "
    

        tuple_name=tuple(name)
        df1 = pd.DataFrame()
    
        for x in tuple_name:
            var = select_query +"'"+x+"'"+" "+"&&"+" "+date_query+"'"+date+"'"
            df = pd.read_sql(var ,engine)
            df.columns=['Date',x]
            if df1.empty:
                df1 = df
            else:
                df1 = pd.merge (df,df1,on='Date')
        df1=df1.set_index('Date')
        plt.figure(figsize=(16,4))
        for i in range(len(name)):
            plt.plot(df1[name[i]]/df1[name[i]].loc[df['Date'][0]]*100)
        
        plt.legend(loc=0)
        plt.grid(True,color='0.7',linestyle=':',linewidth=1)
            
get_graph()
# Out:
# 그래프종류를 입력하세요 sample: 'money' or 'program' or 'stock': stock
# 날짜를 입력하세요 sample: '2019-01-10':2019-01-01
# 주식이름을 입력하세요:삼성전자

# %%
def money_trend_graph_1():
    graph = input("그래프종류를 입력하세요 sample: 'money' or 'program': ")
    date = '2019-01-01'
    
    if graph == 'money' :
        money_name = ['kpi200', '거래량', '고객예탁금', '신용잔고']
        money_query = "select * from kpi_with_money where Date >"+"'"+date+"'"
        money_df = pd.read_sql(money_query ,engine)
        
        money_df.columns=['Date','kpi200', '거래량', '고객예탁금', '신용잔고', '주식형펀드', '혼합형펀드', '채권형펀드']
        money_df = money_df.set_index('Date')
        df1=money_df[money_name]
        #return df1

        plt.figure(figsize=(16,4))
        colors = ['red','green','blue','black']
        for i in range(len(money_name)):
            plt.subplot(2,2,i+1)
            plt.plot(df1[money_name[i]]/df1[money_name[i]].loc[df.index[0]]*100,color=colors[i])
    
            plt.legend(loc=0)
            plt.grid(True,color='0.7',linestyle=':',linewidth=1)
            plt.show()
        

money_trend_graph_1()
# Out:
# 그래프종류를 입력하세요 sample: 'money' or 'program': money
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\gpu\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: Timestamp('2019-01-02 00:00:00')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-5430e587e08f> in <module>
#      24
#      25
# ---> 26 money_trend_graph_1()
#
# <ipython-input-41-5430e587e08f> in money_trend_graph_1()
#      17         for i in range(len(money_name)):
#      18             plt.subplot(2,2,i+1)
# ---> 19             plt.plot(df1[money_name[i]]/df1[money_name[i]].loc[df.index[0]]*100,color=colors[i])
#      20
#      21             plt.legend(loc=0)
#
# C:\ProgramData\Anaconda3\envs\gpu\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# C:\ProgramData\Anaconda3\envs\gpu\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1911         # fall thru to straight lookup
#    1912         self._validate_key(key, axis)
# -> 1913         return self._get_label(key, axis=axis)
#    1914
#    1915
#
# C:\ProgramData\Anaconda3\envs\gpu\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     135             # but will fail when the index is not present
#     136             # see GH5667
# --> 137             return self.obj._xs(label, axis=axis)
#     138         elif isinstance(label, tuple) and isinstance(label[axis], slice):
#     139             raise IndexingError('no slices here, handle elsewhere')
#
# C:\ProgramData\Anaconda3\envs\gpu\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3583                                                       drop_level=drop_level)
#    3584         else:
# -> 3585             loc = self.index.get_loc(key)
#    3586
#    3587             if isinstance(loc, np.ndarray):
#
# C:\ProgramData\Anaconda3\envs\gpu\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
# -> 2658                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2659         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2660         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: Timestamp('2019-01-02 00:00:00')

# %%
def money_trend_graph():
    
    name = ['차익', '비차익', '전체']
    
    date = '2019-01-01'
    
    query = "select * from programtrend where Date >"+"'"+date+"'"
    
    tuple_name=tuple(name)
    df1 = pd.DataFrame()
    
    df = pd.read_sql(query ,engine)

    df.columns=['Date','차익', '비차익', '전체']
    df = df.set_index('Date')
    df1=df[name]

    plt.figure(figsize=(16,4))
    for i in range(len(name)):
        plt.plot(df1[name[i]])
        
    plt.legend(loc=0)
    plt.grid(True,color='0.7',linestyle=':',linewidth=1)
plt.show()

money_trend_graph()

# %%
def money_trend_graph_1():
    
    name = ['kpi200']
    
    date = '2019-01-01'
    
    query = "select * from kpi_with_money where Date >"+"'"+date+"'"
    
    tuple_name=tuple(name)
    df1 = pd.DataFrame()
    
    df = pd.read_sql(query ,engine)

    df.columns=['Date','kpi200', '거래량', '고객예탁금', '신용잔고', '주식형펀드', '혼합형펀드', '채권형펀드']
    df = df.set_index('Date')
    df1=df[name]

    plt.figure(figsize=(16,4))
    for i in range(len(name)):
        plt.plot(df1[name[i]])
        
    plt.legend(loc=0)
    plt.grid(True,color='0.7',linestyle=':',linewidth=1)
plt.show()
        
money_trend_graph_1()

# %%
from urllib.request import urlopen  
source = urlopen(naver_index).read()
import datetime as dt

index_cd = 'KPI200'
page_number = 1
naver_index = 'http://finance.naver.com/sise/sise_index_day.nhn?code=' + index_cd + '&page=' + str(page_number)

import bs4
source = bs4.BeautifulSoup(source, 'lxml')

def date_format(d):
    d = str(d).replace('-', '.')
    
    yyyy = int(d.split('.')[0]) 
    mm = int(d.split('.')[1])
    dd = int(d.split('.')[2])

    this_date= dt.date(yyyy, mm, dd)
    return this_date

# %%
def date_format(d):
    #d = str(d).replace('-', '.')
    
    #yyyy = int(d.split('.')[0]) 
    #mm = int(d.split('.')[1])
    #dd = int(d.split('.')[2])

    this_date = dt.datetime.strptime(d, '%Y-%m-%d')
    #this_date= dt.date(yyyy,mm,dd)
    return this_date

date_format('2019-04-17')
# Out:
# datetime.datetime(2019, 4, 17, 0, 0)

# %%
#### OK

from urllib.request import urlopen
import datetime as dt
import pandas as pd
import bs4

def date_format(d):
    d = str(d).replace('-', '.')
    
    yyyy = int(d.split('.')[0]) 
    mm = int(d.split('.')[1])
    dd = int(d.split('.')[2])

    this_date= dt.date(yyyy,mm,dd)
    return this_date

def historical_index_naver(index_cd, start_date='', end_date='', page_n=1, last_page=0):
    
    if start_date:   # start_date가 있으면
        start_date = date_format(start_date)   # date 포맷으로 변환
    else:    # 없으면
        start_date = dt.date.today()   # 오늘 날짜를 지정
        
    if end_date:   
        end_date = date_format(end_date)   
    else:   
        end_date = dt.date.today()  
        
        
    naver_index = 'http://finance.naver.com/sise/sise_index_day.nhn?code=' + index_cd + '&page=' + str(page_n)
    
    source = urlopen(naver_index).read()   # 지정한 페이지에서 코드 읽기
    source = bs4.BeautifulSoup(source, 'lxml')   # 뷰티풀 스프로 태그별로 코드 분류
    
    dates = source.find_all('td', class_='date')   # <td class="date">태그에서 날짜 수집   
    prices = source.find_all('td', class_='number_1')   # <td class="number_1">태그에서 지수 수집
    
    for n in range(len(dates)):
    
        if dates[n].text.split('.')[0].isdigit():
            
            # 날짜 처리
            this_date = dates[n].text
            this_date= date_format(this_date)
            
            if this_date <= end_date and this_date >= start_date:   
            # start_date와 end_date 사이에서 데이터 저장
                # 종가 처리
                this_close = prices[n*4].text   # prices 중 종가지수인 0,4,8,...번째 데이터 추출
                this_close = this_close.replace(',', '')
                this_close = float(this_close)

                # 딕셔너리에 저장
                historical_prices[this_date] = this_close
                
            elif this_date < start_date:   
            # start_date 이전이면 함수 종료
                return historical_prices              
            
    # 페이지 네비게이션
    if last_page == 0:
        last_page = source.find('td', class_='pgRR').find('a')['href']
        # 마지막페이지 주소 추출
        last_page = last_page.split('&')[1]   # & 뒤의 page=506 부분 추출
        last_page = last_page.split('=')[1]   # = 뒤의 페이지번호만 추출
        last_page = int(last_page)   # 숫자형 변수로 변환
        
    # 다음 페이지 호출
    if page_n < last_page:   
        page_n = page_n + 1   
        historical_index_naver(index_cd, start_date, end_date, page_n, last_page)   
        
    return historical_prices  

index_cd = 'KPI200'
historical_prices = dict()
historical_index_naver(index_cd,'2006-1-1')
historical_prices

historical_prices = {'KOSPI200':historical_prices}
df = pd.DataFrame(historical_prices)
df.to_excel('d:\\kospi200.xlsx')
# Out:
# {datetime.date(2019, 1, 24): 276.61,
#  datetime.date(2019, 1, 23): 273.87,
#  datetime.date(2019, 1, 22): 272.71,
#  datetime.date(2019, 1, 21): 274.0,
#  datetime.date(2019, 1, 18): 273.88,
#  datetime.date(2019, 1, 17): 271.88,
#  datetime.date(2019, 1, 16): 271.23,
#  datetime.date(2019, 1, 15): 269.93,
#  datetime.date(2019, 1, 14): 264.99,
#  datetime.date(2019, 1, 11): 267.13,
#  datetime.date(2019, 1, 10): 265.55,
#  datetime.date(2019, 1, 9): 265.6,
#  datetime.date(2019, 1, 8): 259.65,
#  datetime.date(2019, 1, 7): 261.57,
#  datetime.date(2019, 1, 4): 257.89,
#  datetime.date(2019, 1, 3): 255.77,
#  datetime.date(2019, 1, 2): 258.23,
#  datetime.date(2018, 12, 28): 261.98,
#  datetime.date(2018, 12, 27): 260.57,
#  datetime.date(2018, 12, 26): 260.98,
#  datetime.date(2018, 12, 24): 264.45,
#  datetime.date(2018, 12, 21): 265.06,
#  datetime.date(2018, 12, 20): 264.81,
#  datetime.date(2018, 12, 19): 267.31,
#  datetime.date(2018, 12, 18): 265.18,
#  datetime.date(2018, 12, 17): 266.33,
#  datetime.date(2018, 12, 14): 265.55,
#  datetime.date(2018, 12, 13): 269.41,
#  datetime.date(2018, 12, 12): 268.47,
#  datetime.date(2018, 12, 11): 264.69,
#  datetime.date(2018, 12, 10): 265.35,
#  datetime.date(2018, 12, 7): 268.28,
#  datetime.date(2018, 12, 6): 267.18,
#  datetime.date(2018, 12, 5): 271.49,
#  datetime.date(2018, 12, 4): 273.29,
#  datetime.date(2018, 12, 3): 276.18,
#  datetime.date(2018, 11, 30): 271.35,
#  datetime.date(2018, 11, 29): 274.16,
#  datetime.date(2018, 11, 28): 273.45,
#  datetime.date(2018, 11, 27): 272.08,
#  datetime.date(2018, 11, 26): 269.79,
#  datetime.date(2018, 11, 23): 266.33,
#  datetime.date(2018, 11, 22): 267.76,
#  datetime.date(2018, 11, 21): 268.27,
#  datetime.date(2018, 11, 20): 269.58,
#  datetime.date(2018, 11, 19): 272.31,
#  datetime.date(2018, 11, 16): 271.65,
#  datetime.date(2018, 11, 15): 271.54,
#  datetime.date(2018, 11, 14): 268.88,
#  datetime.date(2018, 11, 13): 269.7,
#  datetime.date(2018, 11, 12): 271.57,
#  datetime.date(2018, 11, 9): 271.33,
#  datetime.date(2018, 11, 8): 272.11,
#  datetime.date(2018, 11, 7): 270.45,
#  datetime.date(2018, 11, 6): 271.57,
#  datetime.date(2018, 11, 5): 270.07,
#  datetime.date(2018, 11, 2): 272.56,
#  datetime.date(2018, 11, 1): 262.95,
#  datetime.date(2018, 10, 31): 264.01,
#  datetime.date(2018, 10, 30): 262.47,
#  datetime.date(2018, 10, 29): 260.19,
#  datetime.date(2018, 10, 26): 262.69,
#  datetime.date(2018, 10, 25): 266.72,
#  datetime.date(2018, 10, 24): 271.36,
#  datetime.date(2018, 10, 23): 272.54,
#  datetime.date(2018, 10, 22): 279.4,
#  datetime.date(2018, 10, 19): 278.63,
#  datetime.date(2018, 10, 18): 277.48,
#  datetime.date(2018, 10, 17): 280.05,
#  datetime.date(2018, 10, 16): 276.9,
#  datetime.date(2018, 10, 15): 277.19,
#  datetime.date(2018, 10, 12): 279.37,
#  datetime.date(2018, 10, 11): 275.15,
#  datetime.date(2018, 10, 10): 287.85,
#  datetime.date(2018, 10, 8): 289.91,
#  datetime.date(2018, 10, 5): 291.28,
#  datetime.date(2018, 10, 4): 291.78,
#  datetime.date(2018, 10, 2): 296.53,
#  datetime.date(2018, 10, 1): 300.17,
#  datetime.date(2018, 9, 28): 300.51,
#  datetime.date(2018, 9, 27): 302.59,
#  datetime.date(2018, 9, 21): 300.81,
#  datetime.date(2018, 9, 20): 299.04,
#  datetime.date(2018, 9, 19): 296.64,
#  datetime.date(2018, 9, 18): 296.1,
#  datetime.date(2018, 9, 17): 295.23,
#  datetime.date(2018, 9, 14): 297.29,
#  datetime.date(2018, 9, 13): 292.42,
#  datetime.date(2018, 9, 12): 292.35,
#  datetime.date(2018, 9, 11): 292.46,
#  datetime.date(2018, 9, 10): 293.7,
#  datetime.date(2018, 9, 7): 292.86,
#  datetime.date(2018, 9, 6): 294.28,
#  datetime.date(2018, 9, 5): 294.96,
#  datetime.date(2018, 9, 4): 298.8,
#  datetime.date(2018, 9, 3): 297.49,
#  datetime.date(2018, 8, 31): 300.07,
#  datetime.date(2018, 8, 30): 298.05,
#  datetime.date(2018, 8, 29): 298.05,
#  datetime.date(2018, 8, 28): 297.22,
#  datetime.date(2018, 8, 27): 296.83,
#  datetime.date(2018, 8, 24): 295.54,
#  datetime.date(2018, 8, 23): 294.29,
#  datetime.date(2018, 8, 22): 293.0,
#  datetime.date(2018, 8, 21): 291.93,
#  datetime.date(2018, 8, 20): 288.61,
#  datetime.date(2018, 8, 17): 288.57,
#  datetime.date(2018, 8, 16): 288.24,
#  datetime.date(2018, 8, 14): 291.08,
#  datetime.date(2018, 8, 13): 289.85,
#  datetime.date(2018, 8, 10): 293.64,
#  datetime.date(2018, 8, 9): 297.41,
#  datetime.date(2018, 8, 8): 297.19,
#  datetime.date(2018, 8, 7): 297.18,
#  datetime.date(2018, 8, 6): 295.24,
#  datetime.date(2018, 8, 3): 295.61,
#  datetime.date(2018, 8, 2): 293.55,
#  datetime.date(2018, 8, 1): 298.69,
#  datetime.date(2018, 7, 31): 297.45,
#  datetime.date(2018, 7, 30): 297.29,
#  datetime.date(2018, 7, 27): 297.78,
#  datetime.date(2018, 7, 26): 296.95,
#  datetime.date(2018, 7, 25): 294.85,
#  datetime.date(2018, 7, 24): 295.49,
#  datetime.date(2018, 7, 23): 294.56,
#  datetime.date(2018, 7, 20): 296.95,
#  datetime.date(2018, 7, 19): 295.9,
#  datetime.date(2018, 7, 18): 296.47,
#  datetime.date(2018, 7, 17): 296.88,
#  datetime.date(2018, 7, 16): 297.37,
#  datetime.date(2018, 7, 13): 298.65,
#  datetime.date(2018, 7, 12): 294.41,
#  datetime.date(2018, 7, 11): 294.43,
#  datetime.date(2018, 7, 10): 296.19,
#  datetime.date(2018, 7, 9): 295.2,
#  datetime.date(2018, 7, 6): 293.11,
#  datetime.date(2018, 7, 5): 291.63,
#  datetime.date(2018, 7, 4): 292.26,
#  datetime.date(2018, 7, 3): 293.35,
#  datetime.date(2018, 7, 2): 292.93,
#  datetime.date(2018, 6, 29): 299.66,
#  datetime.date(2018, 6, 28): 298.26,
#  datetime.date(2018, 6, 27): 302.25,
#  datetime.date(2018, 6, 26): 302.76,
#  datetime.date(2018, 6, 25): 303.37,
#  datetime.date(2018, 6, 22): 303.69,
#  datetime.date(2018, 6, 21): 301.02,
#  datetime.date(2018, 6, 20): 304.02,
#  datetime.date(2018, 6, 19): 301.35,
#  datetime.date(2018, 6, 18): 305.35,
#  datetime.date(2018, 6, 15): 308.73,
#  datetime.date(2018, 6, 14): 311.2,
#  datetime.date(2018, 6, 12): 316.84,
#  datetime.date(2018, 6, 11): 317.22,
#  datetime.date(2018, 6, 8): 314.97,
#  datetime.date(2018, 6, 7): 317.67,
#  datetime.date(2018, 6, 5): 315.76,
#  datetime.date(2018, 6, 4): 314.84,
#  datetime.date(2018, 6, 1): 313.22,
#  datetime.date(2018, 5, 31): 310.92,
#  datetime.date(2018, 5, 30): 309.26,
#  datetime.date(2018, 5, 29): 316.2,
#  datetime.date(2018, 5, 28): 318.99,
#  datetime.date(2018, 5, 25): 318.05,
#  datetime.date(2018, 5, 24): 317.48,
#  datetime.date(2018, 5, 23): 318.31,
#  datetime.date(2018, 5, 21): 316.25,
#  datetime.date(2018, 5, 18): 315.37,
#  datetime.date(2018, 5, 17): 314.29,
#  datetime.date(2018, 5, 16): 315.97,
#  datetime.date(2018, 5, 15): 314.94,
#  datetime.date(2018, 5, 14): 317.72,
#  datetime.date(2018, 5, 11): 318.51,
#  datetime.date(2018, 5, 10): 317.31,
#  datetime.date(2018, 5, 9): 314.42,
#  datetime.date(2018, 5, 8): 315.87,
#  datetime.date(2018, 5, 4): 316.75,
#  datetime.date(2018, 5, 3): 320.55,
#  datetime.date(2018, 5, 2): 322.53,
#  datetime.date(2018, 4, 30): 323.56,
#  datetime.date(2018, 4, 27): 320.8,
#  datetime.date(2018, 4, 26): 318.08,
#  datetime.date(2018, 4, 25): 313.99,
#  datetime.date(2018, 4, 24): 315.86,
#  datetime.date(2018, 4, 23): 317.89,
#  datetime.date(2018, 4, 20): 317.89,
#  datetime.date(2018, 4, 19): 320.12,
#  datetime.date(2018, 4, 18): 318.64,
#  datetime.date(2018, 4, 17): 314.64,
#  datetime.date(2018, 4, 16): 315.17,
#  datetime.date(2018, 4, 13): 314.86,
#  datetime.date(2018, 4, 12): 313.22,
#  datetime.date(2018, 4, 11): 312.94,
#  datetime.date(2018, 4, 10): 313.94,
#  datetime.date(2018, 4, 9): 313.45,
#  datetime.date(2018, 4, 6): 311.61,
#  datetime.date(2018, 4, 5): 313.04,
#  datetime.date(2018, 4, 4): 308.54,
#  datetime.date(2018, 4, 3): 313.38,
#  datetime.date(2018, 4, 2): 314.0,
#  datetime.date(2018, 3, 30): 314.61,
#  datetime.date(2018, 3, 29): 313.82,
#  datetime.date(2018, 3, 28): 311.81,
#  datetime.date(2018, 3, 27): 316.34,
#  datetime.date(2018, 3, 26): 314.89,
#  datetime.date(2018, 3, 23): 312.42,
#  datetime.date(2018, 3, 22): 323.32,
#  datetime.date(2018, 3, 21): 321.6,
#  datetime.date(2018, 3, 20): 321.79,
#  datetime.date(2018, 3, 19): 320.35,
#  datetime.date(2018, 3, 16): 322.88,
#  datetime.date(2018, 3, 15): 322.74,
#  datetime.date(2018, 3, 14): 321.99,
#  datetime.date(2018, 3, 13): 322.98,
#  datetime.date(2018, 3, 12): 320.7,
#  datetime.date(2018, 3, 9): 317.67,
#  datetime.date(2018, 3, 8): 314.78,
#  datetime.date(2018, 3, 7): 311.14,
#  datetime.date(2018, 3, 6): 310.46,
#  datetime.date(2018, 3, 5): 304.58,
#  datetime.date(2018, 3, 2): 308.35,
#  datetime.date(2018, 2, 28): 312.86,
#  datetime.date(2018, 2, 27): 316.83,
#  datetime.date(2018, 2, 26): 317.34,
#  datetime.date(2018, 2, 23): 316.81,
#  datetime.date(2018, 2, 22): 312.17,
#  datetime.date(2018, 2, 21): 314.47,
#  datetime.date(2018, 2, 20): 312.83,
#  datetime.date(2018, 2, 19): 316.61,
#  datetime.date(2018, 2, 14): 314.4,
#  datetime.date(2018, 2, 13): 310.87,
#  datetime.date(2018, 2, 12): 308.13,
#  datetime.date(2018, 2, 9): 304.83,
#  datetime.date(2018, 2, 8): 311.62,
#  datetime.date(2018, 2, 7): 310.48,
#  datetime.date(2018, 2, 6): 318.01,
#  datetime.date(2018, 2, 5): 323.29,
#  datetime.date(2018, 2, 2): 327.01,
#  datetime.date(2018, 2, 1): 333.36,
#  datetime.date(2018, 1, 31): 333.38,
#  datetime.date(2018, 1, 30): 333.4,
#  datetime.date(2018, 1, 29): 338.05,
#  datetime.date(2018, 1, 26): 335.38,
#  datetime.date(2018, 1, 25): 334.08,
#  datetime.date(2018, 1, 24): 330.91,
#  datetime.date(2018, 1, 23): 330.93,
#  datetime.date(2018, 1, 22): 326.27,
#  datetime.date(2018, 1, 19): 329.52,
#  datetime.date(2018, 1, 18): 329.13,
#  datetime.date(2018, 1, 17): 329.19,
#  datetime.date(2018, 1, 16): 330.02,
#  datetime.date(2018, 1, 15): 327.39,
#  datetime.date(2018, 1, 12): 326.72,
#  datetime.date(2018, 1, 11): 325.67,
#  datetime.date(2018, 1, 10): 327.61,
#  datetime.date(2018, 1, 9): 330.25,
#  datetime.date(2018, 1, 8): 331.28,
#  datetime.date(2018, 1, 5): 328.97,
#  datetime.date(2018, 1, 4): 324.58,
#  datetime.date(2018, 1, 3): 327.13,
#  datetime.date(2018, 1, 2): 326.0,
#  datetime.date(2017, 12, 28): 324.74,
#  datetime.date(2017, 12, 27): 320.25,
#  datetime.date(2017, 12, 26): 318.89,
#  datetime.date(2017, 12, 22): 321.21,
#  datetime.date(2017, 12, 21): 319.72,
#  datetime.date(2017, 12, 20): 325.79,
#  datetime.date(2017, 12, 19): 326.76,
#  datetime.date(2017, 12, 18): 326.6,
#  datetime.date(2017, 12, 15): 326.23,
#  datetime.date(2017, 12, 14): 324.74,
#  datetime.date(2017, 12, 13): 326.18,
#  datetime.date(2017, 12, 12): 324.07,
#  datetime.date(2017, 12, 11): 325.09,
#  datetime.date(2017, 12, 8): 324.68,
#  datetime.date(2017, 12, 7): 323.59,
#  datetime.date(2017, 12, 6): 324.52,
#  datetime.date(2017, 12, 5): 329.61,
#  datetime.date(2017, 12, 4): 328.77,
#  datetime.date(2017, 12, 1): 324.78,
#  datetime.date(2017, 11, 30): 325.25,
#  datetime.date(2017, 11, 29): 330.68,
#  datetime.date(2017, 11, 28): 330.99,
#  datetime.date(2017, 11, 27): 329.53,
#  datetime.date(2017, 11, 24): 335.44,
#  datetime.date(2017, 11, 23): 334.51,
#  datetime.date(2017, 11, 22): 335.49,
#  datetime.date(2017, 11, 21): 333.51,
#  datetime.date(2017, 11, 20): 332.92,
#  datetime.date(2017, 11, 17): 334.18,
#  datetime.date(2017, 11, 16): 334.36,
#  datetime.date(2017, 11, 15): 332.17,
#  datetime.date(2017, 11, 14): 333.62,
#  datetime.date(2017, 11, 13): 334.33,
#  datetime.date(2017, 11, 10): 335.96,
#  datetime.date(2017, 11, 9): 337.14,
#  datetime.date(2017, 11, 8): 337.8,
#  datetime.date(2017, 11, 7): 336.76,
#  datetime.date(2017, 11, 6): 337.4,
#  datetime.date(2017, 11, 3): 338.83,
#  datetime.date(2017, 11, 2): 337.53,
#  datetime.date(2017, 11, 1): 338.76,
#  datetime.date(2017, 10, 31): 333.57,
#  datetime.date(2017, 10, 30): 330.38,
#  datetime.date(2017, 10, 27): 329.23,
#  datetime.date(2017, 10, 26): 326.99,
#  datetime.date(2017, 10, 25): 329.31,
#  datetime.date(2017, 10, 24): 328.96,
#  datetime.date(2017, 10, 23): 329.45,
#  datetime.date(2017, 10, 20): 328.89,
#  datetime.date(2017, 10, 19): 326.47,
#  datetime.date(2017, 10, 18): 328.4,
#  datetime.date(2017, 10, 17): 328.51,
#  datetime.date(2017, 10, 16): 327.82,
#  datetime.date(2017, 10, 13): 327.35,
#  datetime.date(2017, 10, 12): 328.11,
#  datetime.date(2017, 10, 11): 326.12,
#  datetime.date(2017, 10, 10): 322.49,
#  datetime.date(2017, 9, 29): 316.27,
#  datetime.date(2017, 9, 28): 313.85,
#  datetime.date(2017, 9, 27): 313.82,
#  datetime.date(2017, 9, 26): 314.29,
#  datetime.date(2017, 9, 25): 316.4,
#  datetime.date(2017, 9, 22): 316.71,
#  datetime.date(2017, 9, 21): 318.25,
#  datetime.date(2017, 9, 20): 318.48,
#  datetime.date(2017, 9, 19): 318.51,
#  datetime.date(2017, 9, 18): 318.93,
#  datetime.date(2017, 9, 15): 313.69,
#  datetime.date(2017, 9, 14): 312.52,
#  datetime.date(2017, 9, 13): 310.0,
#  datetime.date(2017, 9, 12): 310.42,
#  datetime.date(2017, 9, 11): 309.83,
#  datetime.date(2017, 9, 8): 307.43,
#  datetime.date(2017, 9, 7): 306.97,
#  datetime.date(2017, 9, 6): 303.18,
#  datetime.date(2017, 9, 5): 304.06,
#  datetime.date(2017, 9, 4): 304.19,
#  datetime.date(2017, 9, 1): 307.78,
#  datetime.date(2017, 8, 31): 308.28,
#  datetime.date(2017, 8, 30): 309.65,
#  datetime.date(2017, 8, 29): 308.64,
#  datetime.date(2017, 8, 28): 309.53,
#  datetime.date(2017, 8, 25): 311.21,
#  datetime.date(2017, 8, 24): 310.73,
#  datetime.date(2017, 8, 23): 309.71,
#  datetime.date(2017, 8, 22): 309.34,
#  datetime.date(2017, 8, 21): 308.14,
#  datetime.date(2017, 8, 18): 308.39,
#  datetime.date(2017, 8, 17): 309.02,
#  datetime.date(2017, 8, 16): 307.16,
#  datetime.date(2017, 8, 14): 304.93,
#  datetime.date(2017, 8, 11): 302.72,
#  datetime.date(2017, 8, 10): 308.37,
#  datetime.date(2017, 8, 9): 309.52,
#  datetime.date(2017, 8, 8): 313.4,
#  datetime.date(2017, 8, 7): 313.96,
#  datetime.date(2017, 8, 4): 313.46,
#  datetime.date(2017, 8, 3): 312.29,
#  datetime.date(2017, 8, 2): 317.69,
#  datetime.date(2017, 8, 1): 317.04,
#  datetime.date(2017, 7, 31): 314.6,
#  datetime.date(2017, 7, 28): 314.13,
#  datetime.date(2017, 7, 27): 320.51,
#  datetime.date(2017, 7, 26): 319.46,
#  datetime.date(2017, 7, 25): 320.15,
#  datetime.date(2017, 7, 24): 322.01,
#  datetime.date(2017, 7, 21): 321.79,
#  datetime.date(2017, 7, 20): 320.61,
#  datetime.date(2017, 7, 19): 318.91,
#  datetime.date(2017, 7, 18): 318.65,
#  datetime.date(2017, 7, 17): 318.52,
#  datetime.date(2017, 7, 14): 317.35,
#  datetime.date(2017, 7, 13): 316.35,
#  datetime.date(2017, 7, 12): 313.58,
#  datetime.date(2017, 7, 11): 313.59,
#  datetime.date(2017, 7, 10): 311.46,
#  datetime.date(2017, 7, 7): 310.66,
#  datetime.date(2017, 7, 6): 311.88,
#  datetime.date(2017, 7, 5): 311.77,
#  datetime.date(2017, 7, 4): 310.46,
#  datetime.date(2017, 7, 3): 312.39,
#  datetime.date(2017, 6, 30): 311.76,
#  datetime.date(2017, 6, 29): 312.56,
#  datetime.date(2017, 6, 28): 310.84,
#  datetime.date(2017, 6, 27): 312.12,
#  datetime.date(2017, 6, 26): 311.89,
#  datetime.date(2017, 6, 23): 310.26,
#  datetime.date(2017, 6, 22): 309.47,
#  datetime.date(2017, 6, 21): 307.52,
#  datetime.date(2017, 6, 20): 309.31,
#  datetime.date(2017, 6, 19): 308.61,
#  datetime.date(2017, 6, 16): 306.79,
#  datetime.date(2017, 6, 15): 306.69,
#  datetime.date(2017, 6, 14): 307.95,
#  datetime.date(2017, 6, 13): 308.02,
#  datetime.date(2017, 6, 12): 306.24,
#  datetime.date(2017, 6, 9): 309.38,
#  datetime.date(2017, 6, 8): 306.25,
#  datetime.date(2017, 6, 7): 305.68,
#  datetime.date(2017, 6, 5): 307.33,
#  datetime.date(2017, 6, 2): 307.83,
#  datetime.date(2017, 6, 1): 304.03,
#  datetime.date(2017, 5, 31): 304.67,
#  datetime.date(2017, 5, 30): 304.59,
#  datetime.date(2017, 5, 29): 306.52,
#  datetime.date(2017, 5, 26): 306.96,
#  datetime.date(2017, 5, 25): 305.22,
#  datetime.date(2017, 5, 24): 301.71,
#  datetime.date(2017, 5, 23): 301.36,
#  datetime.date(2017, 5, 22): 300.63,
#  datetime.date(2017, 5, 19): 298.08,
#  datetime.date(2017, 5, 18): 298.47,
#  datetime.date(2017, 5, 17): 299.34,
#  datetime.date(2017, 5, 16): 299.67,
#  datetime.date(2017, 5, 15): 298.87,
#  datetime.date(2017, 5, 12): 298.25,
#  datetime.date(2017, 5, 11): 299.75,
#  datetime.date(2017, 5, 10): 296.19,
#  datetime.date(2017, 5, 8): 299.86,
#  datetime.date(2017, 5, 4): 292.47,
#  datetime.date(2017, 5, 2): 289.65,
#  datetime.date(2017, 4, 28): 287.21,
#  datetime.date(2017, 4, 27): 287.34,
#  datetime.date(2017, 4, 26): 286.78,
#  datetime.date(2017, 4, 25): 285.41,
#  datetime.date(2017, 4, 24): 281.96,
#  datetime.date(2017, 4, 21): 280.05,
#  datetime.date(2017, 4, 20): 277.76,
#  datetime.date(2017, 4, 19): 276.49,
#  datetime.date(2017, 4, 18): 278.23,
#  datetime.date(2017, 4, 17): 278.1,
#  datetime.date(2017, 4, 14): 277.31,
#  datetime.date(2017, 4, 13): 279.12,
#  datetime.date(2017, 4, 12): 276.21,
#  datetime.date(2017, 4, 11): 275.49,
#  datetime.date(2017, 4, 10): 277.21,
#  datetime.date(2017, 4, 7): 279.01,
#  datetime.date(2017, 4, 6): 279.47,
#  datetime.date(2017, 4, 5): 280.74,
#  datetime.date(2017, 4, 4): 280.92,
#  datetime.date(2017, 4, 3): 281.6,
#  datetime.date(2017, 3, 31): 280.64,
#  datetime.date(2017, 3, 30): 281.66,
#  datetime.date(2017, 3, 29): 281.86,
#  datetime.date(2017, 3, 28): 281.25,
#  datetime.date(2017, 3, 27): 280.36,
#  datetime.date(2017, 3, 24): 282.31,
#  datetime.date(2017, 3, 23): 282.81,
#  datetime.date(2017, 3, 22): 282.63,
#  datetime.date(2017, 3, 21): 283.84,
#  datetime.date(2017, 3, 20): 280.75,
#  datetime.date(2017, 3, 17): 281.86,
#  datetime.date(2017, 3, 16): 280.11,
#  datetime.date(2017, 3, 15): 277.89,
#  datetime.date(2017, 3, 14): 277.89,
#  datetime.date(2017, 3, 13): 275.41,
#  datetime.date(2017, 3, 10): 272.29,
#  datetime.date(2017, 3, 9): 271.62,
#  datetime.date(2017, 3, 8): 272.29,
#  datetime.date(2017, 3, 7): 271.87,
#  datetime.date(2017, 3, 6): 270.41,
#  datetime.date(2017, 3, 3): 269.77,
#  datetime.date(2017, 3, 2): 272.65,
#  datetime.date(2017, 2, 28): 270.06,
#  datetime.date(2017, 2, 27): 268.97,
#  datetime.date(2017, 2, 24): 270.38,
#  datetime.date(2017, 2, 23): 272.89,
#  datetime.date(2017, 2, 22): 272.85,
#  datetime.date(2017, 2, 21): 272.11,
#  datetime.date(2017, 2, 20): 269.73,
#  datetime.date(2017, 2, 17): 268.84,
#  datetime.date(2017, 2, 16): 268.93,
#  datetime.date(2017, 2, 15): 268.81,
#  datetime.date(2017, 2, 14): 267.9,
#  datetime.date(2017, 2, 13): 268.81,
#  datetime.date(2017, 2, 10): 268.66,
#  datetime.date(2017, 2, 9): 267.69,
#  datetime.date(2017, 2, 8): 267.72,
#  datetime.date(2017, 2, 7): 268.97,
#  datetime.date(2017, 2, 6): 269.49,
#  datetime.date(2017, 2, 3): 268.85,
#  datetime.date(2017, 2, 2): 268.49,
#  datetime.date(2017, 2, 1): 269.56,
#  datetime.date(2017, 1, 31): 268.09,
#  datetime.date(2017, 1, 26): 270.48,
#  datetime.date(2017, 1, 25): 268.15,
#  datetime.date(2017, 1, 24): 267.3,
#  datetime.date(2017, 1, 23): 267.12,
#  datetime.date(2017, 1, 20): 266.52,
#  datetime.date(2017, 1, 19): 267.7,
#  datetime.date(2017, 1, 18): 267.08,
#  datetime.date(2017, 1, 17): 267.37,
#  datetime.date(2017, 1, 16): 266.15,
#  datetime.date(2017, 1, 13): 267.91,
#  datetime.date(2017, 1, 12): 269.95,
#  datetime.date(2017, 1, 11): 268.15,
#  datetime.date(2017, 1, 10): 263.73,
#  datetime.date(2017, 1, 9): 263.74,
#  datetime.date(2017, 1, 6): 263.2,
#  datetime.date(2017, 1, 5): 261.98,
#  datetime.date(2017, 1, 4): 263.12,
#  datetime.date(2017, 1, 3): 262.97,
#  datetime.date(2017, 1, 2): 260.36,
#  datetime.date(2016, 12, 29): 260.01,
#  datetime.date(2016, 12, 28): 259.7,
#  datetime.date(2016, 12, 27): 262.49,
#  datetime.date(2016, 12, 26): 261.9,
#  datetime.date(2016, 12, 23): 261.61,
#  datetime.date(2016, 12, 22): 261.97,
#  datetime.date(2016, 12, 21): 262.1,
#  datetime.date(2016, 12, 20): 262.59,
#  datetime.date(2016, 12, 19): 261.93,
#  datetime.date(2016, 12, 16): 262.56,
#  datetime.date(2016, 12, 15): 261.45,
#  datetime.date(2016, 12, 14): 262.0,
#  datetime.date(2016, 12, 13): 261.63,
#  datetime.date(2016, 12, 12): 260.72,
#  datetime.date(2016, 12, 9): 260.91,
#  datetime.date(2016, 12, 8): 262.0,
#  datetime.date(2016, 12, 7): 256.34,
#  datetime.date(2016, 12, 6): 255.63,
#  datetime.date(2016, 12, 5): 252.14,
#  datetime.date(2016, 12, 2): 252.88,
#  datetime.date(2016, 12, 1): 254.48,
#  datetime.date(2016, 11, 30): 254.26,
#  datetime.date(2016, 11, 29): 252.91,
#  datetime.date(2016, 11, 28): 252.96,
#  datetime.date(2016, 11, 25): 252.26,
#  datetime.date(2016, 11, 24): 252.03,
#  datetime.date(2016, 11, 23): 253.66,
#  datetime.date(2016, 11, 22): 252.37,
#  datetime.date(2016, 11, 21): 249.51,
#  datetime.date(2016, 11, 18): 250.21,
#  datetime.date(2016, 11, 17): 250.46,
#  datetime.date(2016, 11, 16): 250.32,
#  datetime.date(2016, 11, 15): 249.2,
#  datetime.date(2016, 11, 14): 250.01,
#  datetime.date(2016, 11, 11): 251.99,
#  datetime.date(2016, 11, 10): 255.31,
#  datetime.date(2016, 11, 9): 249.67,
#  datetime.date(2016, 11, 8): 255.26,
#  datetime.date(2016, 11, 7): 254.6,
#  datetime.date(2016, 11, 4): 252.57,
#  datetime.date(2016, 11, 3): 252.9,
#  datetime.date(2016, 11, 2): 252.83,
#  datetime.date(2016, 11, 1): 255.99,
#  datetime.date(2016, 10, 31): 255.93,
#  datetime.date(2016, 10, 28): 256.53,
#  datetime.date(2016, 10, 27): 256.66,
#  datetime.date(2016, 10, 26): 255.52,
#  datetime.date(2016, 10, 25): 258.57,
#  datetime.date(2016, 10, 24): 259.48,
#  datetime.date(2016, 10, 21): 257.26,
#  datetime.date(2016, 10, 20): 258.41,
#  datetime.date(2016, 10, 19): 258.21,
#  datetime.date(2016, 10, 18): 257.98,
#  datetime.date(2016, 10, 17): 256.19,
#  datetime.date(2016, 10, 14): 255.09,
#  datetime.date(2016, 10, 13): 253.93,
#  datetime.date(2016, 10, 12): 256.2,
#  datetime.date(2016, 10, 11): 256.15,
#  datetime.date(2016, 10, 10): 260.31,
#  datetime.date(2016, 10, 7): 260.06,
#  datetime.date(2016, 10, 6): 261.13,
#  datetime.date(2016, 10, 5): 258.99,
#  datetime.date(2016, 10, 4): 259.18,
#  datetime.date(2016, 9, 30): 257.49,
#  datetime.date(2016, 9, 29): 260.35,
#  datetime.date(2016, 9, 28): 258.21,
#  datetime.date(2016, 9, 27): 259.57,
#  datetime.date(2016, 9, 26): 257.48,
#  datetime.date(2016, 9, 23): 258.37,
#  datetime.date(2016, 9, 22): 258.34,
#  datetime.date(2016, 9, 21): 256.52,
#  datetime.date(2016, 9, 20): 255.09,
#  datetime.date(2016, 9, 19): 253.93,
#  datetime.date(2016, 9, 13): 251.77,
#  datetime.date(2016, 9, 12): 250.53,
#  datetime.date(2016, 9, 9): 257.31,
#  datetime.date(2016, 9, 8): 260.86,
#  datetime.date(2016, 9, 7): 260.31,
#  datetime.date(2016, 9, 6): 260.93,
#  datetime.date(2016, 9, 5): 259.64,
#  datetime.date(2016, 9, 2): 256.5,
#  datetime.date(2016, 9, 1): 256.03,
#  datetime.date(2016, 8, 31): 256.87,
#  datetime.date(2016, 8, 30): 257.49,
#  datetime.date(2016, 8, 29): 256.49,
#  datetime.date(2016, 8, 26): 256.23,
#  datetime.date(2016, 8, 25): 257.26,
#  datetime.date(2016, 8, 24): 257.3,
#  datetime.date(2016, 8, 23): 258.42,
#  datetime.date(2016, 8, 22): 257.27,
#  datetime.date(2016, 8, 19): 258.69,
#  datetime.date(2016, 8, 18): 258.11,
#  datetime.date(2016, 8, 17): 256.04,
#  datetime.date(2016, 8, 16): 256.15,
#  datetime.date(2016, 8, 12): 256.17,
#  datetime.date(2016, 8, 11): 256.18,
#  datetime.date(2016, 8, 10): 255.43,
#  datetime.date(2016, 8, 9): 255.85,
#  datetime.date(2016, 8, 8): 254.11,
#  datetime.date(2016, 8, 5): 252.36,
#  datetime.date(2016, 8, 4): 249.24,
#  datetime.date(2016, 8, 3): 248.65,
#  datetime.date(2016, 8, 2): 251.93,
#  datetime.date(2016, 8, 1): 253.81,
#  datetime.date(2016, 7, 29): 251.48,
#  datetime.date(2016, 7, 28): 251.86,
#  datetime.date(2016, 7, 27): 252.73,
#  datetime.date(2016, 7, 26): 252.72,
#  datetime.date(2016, 7, 25): 250.65,
#  datetime.date(2016, 7, 22): 250.04,
#  datetime.date(2016, 7, 21): 250.44,
#  datetime.date(2016, 7, 20): 250.66,
#  datetime.date(2016, 7, 19): 250.97,
#  datetime.date(2016, 7, 18): 251.52,
#  datetime.date(2016, 7, 15): 251.02,
#  datetime.date(2016, 7, 14): 249.8,
#  datetime.date(2016, 7, 13): 249.25,
#  datetime.date(2016, 7, 12): 247.14,
#  datetime.date(2016, 7, 11): 246.99,
#  datetime.date(2016, 7, 8): 243.43,
#  datetime.date(2016, 7, 7): 244.6,
#  datetime.date(2016, 7, 6): 241.86,
#  datetime.date(2016, 7, 5): 246.91,
#  datetime.date(2016, 7, 4): 247.62,
#  datetime.date(2016, 7, 1): 246.52,
#  datetime.date(2016, 6, 30): 244.14,
#  datetime.date(2016, 6, 29): 242.32,
#  datetime.date(2016, 6, 28): 240.08,
#  datetime.date(2016, 6, 27): 239.28,
#  datetime.date(2016, 6, 24): 239.21,
#  datetime.date(2016, 6, 23): 246.31,
#  datetime.date(2016, 6, 22): 246.75,
#  datetime.date(2016, 6, 21): 245.34,
#  datetime.date(2016, 6, 20): 245.17,
#  datetime.date(2016, 6, 17): 241.63,
#  datetime.date(2016, 6, 16): 241.61,
#  datetime.date(2016, 6, 15): 243.3,
#  datetime.date(2016, 6, 14): 243.35,
#  datetime.date(2016, 6, 13): 244.05,
#  datetime.date(2016, 6, 10): 248.96,
#  datetime.date(2016, 6, 9): 250.19,
#  datetime.date(2016, 6, 8): 250.04,
#  datetime.date(2016, 6, 7): 247.85,
#  datetime.date(2016, 6, 3): 244.39,
#  datetime.date(2016, 6, 2): 244.18,
#  datetime.date(2016, 6, 1): 243.58,
#  datetime.date(2016, 5, 31): 243.63,
#  datetime.date(2016, 5, 30): 241.73,
#  datetime.date(2016, 5, 27): 241.85,
#  datetime.date(2016, 5, 26): 240.58,
#  datetime.date(2016, 5, 25): 240.91,
#  datetime.date(2016, 5, 24): 237.65,
#  datetime.date(2016, 5, 23): 239.85,
#  datetime.date(2016, 5, 20): 238.74,
#  datetime.date(2016, 5, 19): 239.04,
#  datetime.date(2016, 5, 18): 239.82,
#  datetime.date(2016, 5, 17): 241.03,
#  datetime.date(2016, 5, 16): 240.82,
#  datetime.date(2016, 5, 13): 240.6,
#  datetime.date(2016, 5, 12): 242.34,
#  datetime.date(2016, 5, 11): 243.07,
#  datetime.date(2016, 5, 10): 243.68,
#  datetime.date(2016, 5, 9): 242.23,
#  datetime.date(2016, 5, 4): 243.31,
#  datetime.date(2016, 5, 3): 244.29,
#  datetime.date(2016, 5, 2): 243.47,
#  datetime.date(2016, 4, 29): 245.2,
#  datetime.date(2016, 4, 28): 246.27,
#  datetime.date(2016, 4, 27): 248.69,
#  datetime.date(2016, 4, 26): 248.92,
#  datetime.date(2016, 4, 25): 248.13,
#  datetime.date(2016, 4, 22): 248.32,
#  datetime.date(2016, 4, 21): 249.39,
#  datetime.date(2016, 4, 20): 247.26,
#  datetime.date(2016, 4, 19): 247.88,
#  datetime.date(2016, 4, 18): 248.0,
#  datetime.date(2016, 4, 15): 248.53,
#  datetime.date(2016, 4, 14): 248.89,
#  datetime.date(2016, 4, 12): 243.71,
#  datetime.date(2016, 4, 11): 242.06,
#  datetime.date(2016, 4, 8): 241.77,
#  datetime.date(2016, 4, 7): 242.29,
#  datetime.date(2016, 4, 6): 241.99,
#  datetime.date(2016, 4, 5): 240.58,
#  datetime.date(2016, 4, 4): 243.05,
#  datetime.date(2016, 4, 1): 242.36,
#  datetime.date(2016, 3, 31): 245.86,
#  datetime.date(2016, 3, 30): 246.54,
#  datetime.date(2016, 3, 29): 245.53,
#  datetime.date(2016, 3, 28): 243.95,
#  datetime.date(2016, 3, 25): 243.79,
#  datetime.date(2016, 3, 24): 244.08,
#  datetime.date(2016, 3, 23): 245.23,
#  datetime.date(2016, 3, 22): 245.41,
#  datetime.date(2016, 3, 21): 244.28,
#  datetime.date(2016, 3, 18): 244.63,
#  datetime.date(2016, 3, 17): 244.09,
#  datetime.date(2016, 3, 16): 242.35,
#  datetime.date(2016, 3, 15): 241.83,
#  datetime.date(2016, 3, 14): 242.15,
#  datetime.date(2016, 3, 11): 241.97,
#  datetime.date(2016, 3, 10): 241.43,
#  datetime.date(2016, 3, 9): 239.13,
#  datetime.date(2016, 3, 8): 238.44,
#  datetime.date(2016, 3, 7): 240.21,
#  datetime.date(2016, 3, 4): 239.74,
#  datetime.date(2016, 3, 3): 240.09,
#  datetime.date(2016, 3, 2): 238.63,
#  datetime.date(2016, 2, 29): 234.63,
#  datetime.date(2016, 2, 26): 235.22,
#  datetime.date(2016, 2, 25): 235.37,
#  datetime.date(2016, 2, 24): 234.91,
#  datetime.date(2016, 2, 23): 235.03,
#  datetime.date(2016, 2, 22): 234.95,
#  datetime.date(2016, 2, 19): 235.27,
#  datetime.date(2016, 2, 18): 234.74,
#  datetime.date(2016, 2, 17): 231.94,
#  datetime.date(2016, 2, 16): 231.52,
#  datetime.date(2016, 2, 15): 228.4,
#  datetime.date(2016, 2, 12): 224.98,
#  datetime.date(2016, 2, 11): 226.7,
#  datetime.date(2016, 2, 5): 233.3,
#  datetime.date(2016, 2, 4): 232.91,
#  datetime.date(2016, 2, 3): 228.97,
#  datetime.date(2016, 2, 2): 231.1,
#  datetime.date(2016, 2, 1): 233.67,
#  datetime.date(2016, 1, 29): 232.1,
#  datetime.date(2016, 1, 28): 231.51,
#  datetime.date(2016, 1, 27): 230.96,
#  datetime.date(2016, 1, 26): 227.19,
#  datetime.date(2016, 1, 25): 230.21,
#  datetime.date(2016, 1, 22): 228.79,
#  datetime.date(2016, 1, 21): 223.81,
#  datetime.date(2016, 1, 20): 224.54,
#  datetime.date(2016, 1, 19): 230.08,
#  datetime.date(2016, 1, 18): 228.59,
#  datetime.date(2016, 1, 15): 228.78,
#  datetime.date(2016, 1, 14): 231.38,
#  datetime.date(2016, 1, 13): 233.52,
#  datetime.date(2016, 1, 12): 230.55,
#  datetime.date(2016, 1, 11): 230.83,
#  datetime.date(2016, 1, 8): 233.68,
#  datetime.date(2016, 1, 7): 231.93,
#  datetime.date(2016, 1, 6): 234.6,
#  datetime.date(2016, 1, 5): 236.13,
#  datetime.date(2016, 1, 4): 234.63,
#  datetime.date(2015, 12, 30): 240.38,
#  datetime.date(2015, 12, 29): 241.22,
#  datetime.date(2015, 12, 28): 241.79,
#  datetime.date(2015, 12, 24): 245.33,
#  datetime.date(2015, 12, 23): 246.53,
#  datetime.date(2015, 12, 22): 245.48,
#  datetime.date(2015, 12, 21): 243.76,
#  datetime.date(2015, 12, 18): 243.0,
#  datetime.date(2015, 12, 17): 244.17,
#  datetime.date(2015, 12, 16): 243.49,
#  datetime.date(2015, 12, 15): 238.8,
#  datetime.date(2015, 12, 14): 238.17,
#  datetime.date(2015, 12, 11): 240.35,
#  datetime.date(2015, 12, 10): 240.6,
#  datetime.date(2015, 12, 9): 239.4,
#  datetime.date(2015, 12, 8): 239.23,
#  datetime.date(2015, 12, 7): 240.68,
#  datetime.date(2015, 12, 4): 242.15,
#  datetime.date(2015, 12, 3): 244.68,
#  datetime.date(2015, 12, 2): 246.6,
#  datetime.date(2015, 12, 1): 248.7,
#  datetime.date(2015, 11, 30): 244.24,
#  datetime.date(2015, 11, 27): 249.07,
#  datetime.date(2015, 11, 26): 249.43,
#  datetime.date(2015, 11, 25): 246.58,
#  datetime.date(2015, 11, 24): 247.51,
#  datetime.date(2015, 11, 23): 245.92,
#  datetime.date(2015, 11, 20): 244.8,
#  datetime.date(2015, 11, 19): 244.79,
#  datetime.date(2015, 11, 18): 241.44,
#  datetime.date(2015, 11, 17): 241.26,
#  datetime.date(2015, 11, 16): 238.87,
#  datetime.date(2015, 11, 13): 242.71,
#  datetime.date(2015, 11, 12): 245.14,
#  datetime.date(2015, 11, 11): 245.86,
#  datetime.date(2015, 11, 10): 245.86,
#  datetime.date(2015, 11, 9): 249.21,
#  datetime.date(2015, 11, 6): 250.25,
#  datetime.date(2015, 11, 5): 251.79,
#  datetime.date(2015, 11, 4): 252.33,
#  datetime.date(2015, 11, 3): 252.12,
#  datetime.date(2015, 11, 2): 250.6,
#  datetime.date(2015, 10, 30): 249.41,
#  datetime.date(2015, 10, 29): 248.93,
#  datetime.date(2015, 10, 28): 249.79,
#  datetime.date(2015, 10, 27): 250.04,
#  datetime.date(2015, 10, 26): 250.36,
#  datetime.date(2015, 10, 23): 249.41,
#  datetime.date(2015, 10, 22): 247.22,
#  datetime.date(2015, 10, 21): 249.25,
#  datetime.date(2015, 10, 20): 248.53,
#  datetime.date(2015, 10, 19): 247.47,
#  datetime.date(2015, 10, 16): 247.37,
#  datetime.date(2015, 10, 15): 247.89,
#  datetime.date(2015, 10, 14): 244.94,
#  datetime.date(2015, 10, 13): 246.04,
#  datetime.date(2015, 10, 12): 246.49,
#  datetime.date(2015, 10, 8): 246.02,
#  datetime.date(2015, 10, 7): 243.52,
#  datetime.date(2015, 10, 6): 240.18,
#  datetime.date(2015, 10, 5): 237.98,
#  datetime.date(2015, 10, 2): 237.15,
#  datetime.date(2015, 10, 1): 238.62,
#  datetime.date(2015, 9, 30): 236.71,
#  datetime.date(2015, 9, 25): 233.79,
#  datetime.date(2015, 9, 24): 234.26,
#  datetime.date(2015, 9, 23): 234.26,
#  datetime.date(2015, 9, 22): 238.68,
#  datetime.date(2015, 9, 21): 236.72,
#  datetime.date(2015, 9, 18): 241.12,
#  datetime.date(2015, 9, 17): 239.29,
#  datetime.date(2015, 9, 16): 238.78,
#  datetime.date(2015, 9, 15): 233.59,
#  datetime.date(2015, 9, 14): 233.06,
#  datetime.date(2015, 9, 11): 233.74,
#  datetime.date(2015, 9, 10): 237.18,
#  datetime.date(2015, 9, 9): 234.4,
#  datetime.date(2015, 9, 8): 227.76,
#  datetime.date(2015, 9, 7): 227.31,
#  datetime.date(2015, 9, 4): 227.9,
#  datetime.date(2015, 9, 3): 230.4,
#  datetime.date(2015, 9, 2): 229.91,
#  datetime.date(2015, 9, 1): 229.55,
#  datetime.date(2015, 8, 31): 232.8,
#  datetime.date(2015, 8, 28): 232.35,
#  datetime.date(2015, 8, 27): 228.94,
#  datetime.date(2015, 8, 26): 227.71,
#  datetime.date(2015, 8, 25): 223.07,
#  datetime.date(2015, 8, 24): 221.53,
#  datetime.date(2015, 8, 21): 227.14,
#  datetime.date(2015, 8, 20): 231.59,
#  datetime.date(2015, 8, 19): 234.27,
#  datetime.date(2015, 8, 18): 235.2,
#  datetime.date(2015, 8, 17): 235.37,
#  datetime.date(2015, 8, 13): 237.32,
#  datetime.date(2015, 8, 12): 237.24,
#  datetime.date(2015, 8, 11): 237.91,
#  datetime.date(2015, 8, 10): 239.18,
#  datetime.date(2015, 8, 7): 239.79,
#  datetime.date(2015, 8, 6): 240.04,
#  datetime.date(2015, 8, 5): 243.12,
#  datetime.date(2015, 8, 4): 243.55,
#  datetime.date(2015, 8, 3): 241.48,
#  datetime.date(2015, 7, 31): 244.3,
#  datetime.date(2015, 7, 30): 243.61,
#  datetime.date(2015, 7, 29): 245.97,
#  datetime.date(2015, 7, 28): 245.21,
#  datetime.date(2015, 7, 27): 244.98,
#  datetime.date(2015, 7, 24): 244.91,
#  datetime.date(2015, 7, 23): 247.31,
#  datetime.date(2015, 7, 22): 247.88,
#  datetime.date(2015, 7, 21): 250.35,
#  datetime.date(2015, 7, 20): 248.91,
#  datetime.date(2015, 7, 17): 250.23,
#  datetime.date(2015, 7, 16): 251.47,
#  datetime.date(2015, 7, 15): 249.65,
#  datetime.date(2015, 7, 14): 248.64,
#  datetime.date(2015, 7, 13): 249.84,
#  datetime.date(2015, 7, 10): 246.83,
#  datetime.date(2015, 7, 9): 246.77,
#  datetime.date(2015, 7, 8): 244.94,
#  datetime.date(2015, 7, 7): 248.05,
#  datetime.date(2015, 7, 6): 248.3,
#  datetime.date(2015, 7, 3): 254.66,
#  datetime.date(2015, 7, 2): 255.5,
#  datetime.date(2015, 7, 1): 255.07,
#  datetime.date(2015, 6, 30): 252.27,
#  datetime.date(2015, 6, 29): 251.26,
#  datetime.date(2015, 6, 26): 254.48,
#  datetime.date(2015, 6, 25): 253.8,
#  datetime.date(2015, 6, 24): 254.94,
#  datetime.date(2015, 6, 23): 254.52,
#  datetime.date(2015, 6, 22): 250.99,
#  datetime.date(2015, 6, 19): 249.84,
#  datetime.date(2015, 6, 18): 249.67,
#  datetime.date(2015, 6, 17): 249.08,
#  datetime.date(2015, 6, 16): 248.49,
#  datetime.date(2015, 6, 15): 250.74,
#  datetime.date(2015, 6, 12): 251.66,
#  datetime.date(2015, 6, 11): 252.32,
#  datetime.date(2015, 6, 10): 252.11,
#  datetime.date(2015, 6, 9): 253.51,
#  datetime.date(2015, 6, 8): 254.21,
#  datetime.date(2015, 6, 5): 254.94,
#  datetime.date(2015, 6, 4): 255.47,
#  datetime.date(2015, 6, 3): 254.11,
#  datetime.date(2015, 6, 2): 256.29,
#  datetime.date(2015, 6, 1): 258.74,
#  datetime.date(2015, 5, 29): 260.39,
#  datetime.date(2015, 5, 28): 260.06,
#  datetime.date(2015, 5, 27): 260.16,
#  datetime.date(2015, 5, 26): 265.41,
#  datetime.date(2015, 5, 22): 266.03,
#  datetime.date(2015, 5, 21): 262.66,
#  datetime.date(2015, 5, 20): 265.36,
#  datetime.date(2015, 5, 19): 262.92,
#  datetime.date(2015, 5, 18): 261.97,
#  datetime.date(2015, 5, 15): 261.33,
#  datetime.date(2015, 5, 14): 263.69,
#  datetime.date(2015, 5, 13): 263.25,
#  datetime.date(2015, 5, 12): 261.42,
#  datetime.date(2015, 5, 11): 261.49,
#  datetime.date(2015, 5, 8): 260.81,
#  datetime.date(2015, 5, 7): 262.47,
#  datetime.date(2015, 5, 6): 264.03,
#  datetime.date(2015, 5, 4): 267.33,
#  datetime.date(2015, 4, 30): 266.42,
#  datetime.date(2015, 4, 29): 268.03,
#  datetime.date(2015, 4, 28): 268.55,
#  datetime.date(2015, 4, 27): 270.05,
#  datetime.date(2015, 4, 24): 271.05,
#  datetime.date(2015, 4, 23): 272.59,
#  datetime.date(2015, 4, 22): 268.64,
#  datetime.date(2015, 4, 21): 268.17,
#  datetime.date(2015, 4, 20): 268.55,
#  datetime.date(2015, 4, 17): 268.28,
#  datetime.date(2015, 4, 16): 268.45,
#  datetime.date(2015, 4, 15): 265.77,
#  datetime.date(2015, 4, 14): 265.57,
#  datetime.date(2015, 4, 13): 263.48,
#  datetime.date(2015, 4, 10): 261.95,
#  datetime.date(2015, 4, 9): 258.33,
#  datetime.date(2015, 4, 8): 258.51,
#  datetime.date(2015, 4, 7): 256.88,
#  datetime.date(2015, 4, 6): 256.93,
#  datetime.date(2015, 4, 3): 256.75,
#  datetime.date(2015, 4, 2): 254.99,
#  datetime.date(2015, 4, 1): 254.97,
#  datetime.date(2015, 3, 31): 257.28,
#  datetime.date(2015, 3, 30): 256.1,
#  datetime.date(2015, 3, 27): 255.54,
#  datetime.date(2015, 3, 26): 255.99,
#  datetime.date(2015, 3, 25): 258.94,
#  datetime.date(2015, 3, 24): 259.16,
#  datetime.date(2015, 3, 23): 258.95,
#  datetime.date(2015, 3, 20): 258.7,
#  datetime.date(2015, 3, 19): 258.99,
#  datetime.date(2015, 3, 18): 258.22,
#  datetime.date(2015, 3, 17): 258.18,
#  datetime.date(2015, 3, 16): 252.44,
#  datetime.date(2015, 3, 13): 252.18,
#  datetime.date(2015, 3, 12): 250.28,
#  datetime.date(2015, 3, 11): 252.16,
#  datetime.date(2015, 3, 10): 251.75,
#  datetime.date(2015, 3, 9): 252.77,
#  datetime.date(2015, 3, 6): 255.96,
#  datetime.date(2015, 3, 5): 254.16,
#  datetime.date(2015, 3, 4): 254.31,
#  datetime.date(2015, 3, 3): 254.5,
#  datetime.date(2015, 3, 2): 253.65,
#  datetime.date(2015, 2, 27): 251.46,
#  datetime.date(2015, 2, 26): 252.93,
#  datetime.date(2015, 2, 25): 252.96,
#  datetime.date(2015, 2, 24): 251.28,
#  datetime.date(2015, 2, 23): 250.8,
#  datetime.date(2015, 2, 17): 250.37,
#  datetime.date(2015, 2, 16): 249.81,
#  datetime.date(2015, 2, 13): 249.76,
#  datetime.date(2015, 2, 12): 247.71,
#  datetime.date(2015, 2, 11): 248.4,
#  datetime.date(2015, 2, 10): 247.66,
#  datetime.date(2015, 2, 9): 249.26,
#  datetime.date(2015, 2, 6): 250.16,
#  datetime.date(2015, 2, 5): 249.78,
#  datetime.date(2015, 2, 4): 251.6,
#  datetime.date(2015, 2, 3): 250.38,
#  datetime.date(2015, 2, 2): 250.61,
#  datetime.date(2015, 1, 30): 249.88,
#  datetime.date(2015, 1, 29): 250.46,
#  datetime.date(2015, 1, 28): 252.21,
#  datetime.date(2015, 1, 27): 252.2,
#  datetime.date(2015, 1, 26): 250.14,
#  datetime.date(2015, 1, 23): 250.32,
#  datetime.date(2015, 1, 22): 248.47,
#  datetime.date(2015, 1, 21): 248.59,
#  datetime.date(2015, 1, 20): 247.24,
#  datetime.date(2015, 1, 19): 244.78,
#  datetime.date(2015, 1, 16): 242.22,
#  datetime.date(2015, 1, 15): 245.76,
#  datetime.date(2015, 1, 14): 245.99,
#  datetime.date(2015, 1, 13): 246.29,
#  datetime.date(2015, 1, 12): 245.7,
#  datetime.date(2015, 1, 9): 246.05,
#  datetime.date(2015, 1, 8): 243.94,
#  datetime.date(2015, 1, 7): 240.53,
#  datetime.date(2015, 1, 6): 239.93,
#  datetime.date(2015, 1, 5): 244.26,
#  datetime.date(2015, 1, 2): 244.79,
#  datetime.date(2014, 12, 30): 244.05,
#  datetime.date(2014, 12, 29): 246.3,
#  ...}

# %%
# KOSPI_STOCK PRICE TO MYSQL

import pandas as pd
import FinanceDataReader as fdr
import sqlalchemy 
import pymysql
pymysql.install_as_MySQLdb() # MySQLdb와 호환 
import MySQLdb

engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
conn = engine.connect()

data = pd.read_excel('d:\\market_list.xlsx')

code_list = data['종목코드'].tolist()
code_list = [str(item).zfill(6) for item in code_list]
name_list = data['종목명'].tolist()

# 코스피 상장종목 전체
stock_dic = dict(list(zip(code_list,name_list)))

for code in sorted(stock_dic.keys()):
    df  = fdr.DataReader(code,'2019-02-13')
    print(code,stock_dic[code])
    df['Code'],df['Name'] = code,stock_dic[code]
    df = df[['Code','Name','Open','High','Low','Volume','Close']]
    df.to_sql(name='market', con=engine, if_exists='append')
    #df.to_excel('d:\\data_set\\kospi\\'+ stock_dic[code] +'.xlsx',engine = 'xlsxwriter')
# Out:
# 085620 미래에셋생명
# 085660 차바이오텍
# 085670 뉴프렉스
# 085810 알티캐스트
# 085910 네오티스
# 086040 바이오톡스텍
# 086060 진바이오텍
# 086250 화신테크
# 086280 현대글로비스
# 086390 유니테스트
# 086450 동국제약
# 086520 에코프로
# 086670 비엠티
# 086790 하나금융지주
# 086820 바이오솔루션
# 086890 이수앱지스
# 086900 메디톡스
# 086960 한컴MDS
# 086980 쇼박스
# 087010 펩트론
# 087260 모바일어플라이언스
# 087600 픽셀플러스
# 087730 네패스신소재
# 088130 동아엘텍
# 088260 이리츠코크렙
# 088290 이원컴포텍
# 088350 한화생명
# 088390 이녹스
# 088790 진도
# 088800 에이스테크
# 088910 동우팜투테이블
# 088980 맥쿼리인프라
# 089010 켐트로닉스
# 089030 테크윙
# 089140 넥스턴
# 089150 케이씨티
# 089230 THE E&M
# 089470 HDC현대EP
# 089530 에이티세미콘
# 089590 제주항공
# 089600 나스미디어
# 089790 제이티
# 089850 유비벨록스
# 089890 코세스
# 089970 에이피티씨
# 089980 상아프론테크
# 090080 평화산업
# 090150 광진윈텍
# 090350 노루페인트
# 090355 노루페인트우
# 090360 로보스타
# 090370 메타랩스
# 090410 덕신하우징
# 090430 아모레퍼시픽
# 090435 아모레퍼시픽우
# 090460 비에이치
# 090470 제이스텍
# 090710 디에스티로봇
# 090740 연이정보통신
# 090850 이지웰페어
# 091090 세원셀론텍
# 091120 이엠텍
# 091340 S&K폴리텍
# 091440 텔레필드
# 091580 상신이디피
# 091590 남화토건
# 091700 파트론
# 091810 티웨이항공
# 091970 나노캠텍
# 091990 셀트리온헬스케어
# 092040 아미코젠
# 092070 디엔에프
# 092130 이크레더블
# 092200 디아이씨
# 092220 KEC
# 092230 KPX홀딩스
# 092300 현우산업
# 092440 기신정기
# 092460 한라IMS
# 092600 넥스트칩
# 092730 네오팜
# 092780 동양피스톤
# 092870 엑시콘
# 093050 LF
# 093190 빅솔론
# 093230 이아이디
# 093240 형지엘리트
# 093320 케이아이엔엑스
# 093370 후성
# 093380 풍강
# 093520 매커스
# 093640 다믈멀티미디어
# 093920 서원인텍
# 094170 동운아나텍
# 094190 이엘케이
# 094280 효성ITX
# 094360 칩스앤미디어
# 094480 갤럭시아컴즈
# 094800 맵스리얼티1
# 094820 일진파워
# 094840 슈프리마에이치큐
# 094850 참좋은여행
# 094860 코닉글로리
# 094940 푸른기술
# 094970 제이엠티
# 095190 이엠코리아
# 095270 웨이브일렉트로
# 095340 ISC
# 095500 미래나노텍
# 095570 AJ네트웍스
# 095610 테스
# 095660 네오위즈
# 095700 제넥신
# 095720 웅진씽크빅
# 095910 에스에너지
# 096040 이트론
# 096240 청담러닝
# 096300 베트남개발1
# 096350 대창솔루션
# 096530 씨젠
# 096610 알에프세미
# 096630 에스코넥
# 096640 멜파스
# 096690 제이스테판
# 096760 JW홀딩스
# 096770 SK이노베이션
# 096775 SK이노베이션우
# 096870 엘디티
# 097230 한진중공업
# 097520 엠씨넥스
# 097780 에스맥
# 097800 윈팩
# 097870 효성오앤비
# 097950 CJ제일제당
# 097955 CJ제일제당 우
# 098120 마이크로컨텍솔
# 098460 고영
# 098660 에스티오
# 099190 아이센스
# 099220 SDN
# 099320 쎄트렉아이
# 099340 하나니켈1호
# 099350 하나니켈2호
# 099410 동방선기
# 099440 스맥
# 099520 ITX엠투엠
# 100030 모바일리더
# 100090 삼강엠앤티
# 100120 뷰웍스
# 100130 동국S&C
# 100220 비상교육
# 100250 진양홀딩스
# 100590 머큐리
# 100660 서암기계공업
# 100700 세운메디칼
# 100840 S&TC
# 101000 디엠씨
# 101060 SBS미디어홀딩스
# 101140 아티스
# 101160 월덱스
# 101170 우림기계
# 101240 씨큐브
# 101330 모베이스
# 101390 아이엠
# 101400 엔시트론
# 101490 에스앤에스텍
# 101530 해태제과식품
# 101670 코리아에스이
# 101680 한국정밀기계
# 101730 조이맥스
# 101930 인화정공
# 102120 어보브반도체
# 102210 해덕파워웨이
# 102260 동성코퍼레이션
# 102280 쌍방울
# 102460 이연제약
# 102710 이엔에프테크놀로지
# 102940 코오롱생명과학
# 103130 웅진에너지
# 103140 풍산
# 103230 에스앤더블류
# 103590 일진전기
# 104040 대성파인텍
# 104200 NHN벅스
# 104460 동양피엔에프
# 104480 티케이케미칼
# 104540 코렌텍
# 104700 한국철강
# 104830 원익머트리얼즈
# 105330 케이엔더블유
# 105550 트루윈
# 105560 KB금융
# 105630 한세실업
# 105740 디케이락
# 105840 우진
# 106080 지투하이소닉
# 106190 하이텍팜
# 106240 파인테크닉스
# 106520 디지탈옵틱
# 107590 미원홀딩스
# 108230 톱텍
# 108320 실리콘웍스
# 108380 대양전기공업
# 108490 로보티즈
# 108670 LG하우시스
# 108675 LG하우시스우
# 108790 인터파크
# 108860 셀바스AI
# 109070 컨버즈
# 109080 옵티시스
# 109610 에스와이패널
# 109740 디에스케이
# 109820 진매트릭스
# 109860 동일금속
# 109960 에이프로젠 H&G
# 110020 전진바이오팜
# 110790 크리스에프앤씨
# 110990 디아이티
# 111110 호전실업
# 111710 남화산업
# 111770 영원무역
# 111820 지와이커머스
# 111870 삼본정밀전자
# 112040 위메이드
# 112240 에스에프씨
# 112610 씨에스윈드
# 113810 디젠스
# 114090 GKL
# 114120 크루셜텍
# 114190 웰크론강원
# 114450 KPX생명과학
# 114570 지스마트글로벌
# 114630 우노앤컴퍼니
# 114810 아이원스
# 115160 휴맥스
# 115180 큐리언트
# 115310 인포바인
# 115390 락앤락
# 115440 우리넷
# 115450 지트리비앤티
# 115480 씨유메디칼
# 115500 케이씨에스
# 115530 씨엔플러스
# 115570 스타플렉스
# 115610 이미지스
# 115960 연우
# 117580 대성에너지
# 117670 알파홀딩스
# 117730 티로보틱스
# 118000 우리들휴브레인
# 118990 모트렉스
# 119500 포메탈
# 119610 인터로조
# 119650 KC코트렐
# 119830 아이텍반도체
# 119850 지엔씨에너지
# 119860 다나와
# 120030 조선선재
# 120110 코오롱인더
# 120115 코오롱인더우
# 120240 대정화금
# 121440 골프존뉴딘홀딩스
# 121600 나노신소재
# 121800 비덴트
# 121850 코이즈
# 121890 에스디시스템
# 122310 제노레이
# 122350 삼기오토모티브
# 122450 KMH
# 122640 예스티
# 122690 서진오토모티브
# 122800 썬텍
# 122870 와이지엔터테인먼트
# 122900 아이마켓코리아
# 122990 와이솔
# 123010 옵토팩
# 123040 엠에스오토텍
# 123100 원익테라세미콘
# 123260 STC
# 123330 제닉
# 123410 코리아에프티
# 123420 선데이토즈
# 123570 이엠넷
# 123690 한국화장품
# 123700 SJM
# 123750 알톤스포츠
# 123840 한일진공
# 123860 아나패스
# 123890 한국자산신탁
# 124500 아이티센
# 126560 현대에이치씨엔
# 126600 코프라
# 126640 화신정공
# 126700 하이비젼시스템
# 126870 뉴로스
# 126880 제이엔케이히터
# 127120 디엔에이링크
# 127160 매직마이크로
# 127710 아시아경제
# 128540 에코캡
# 128660 피제이메탈
# 128820 대성산업
# 128940 한미약품
# 129260 인터지스
# 130500 GH신소재
# 130580 나이스디앤비
# 130660 한전산업
# 130740 티피씨글로벌
# 131030 디에이치피코리아
# 131090 시큐브
# 131100 리켐
# 131180 딜리
# 131220 대한과학
# 131290 티에스이
# 131370 알서포트
# 131390 피앤이솔루션
# 131400 액트
# 131760 파인텍
# 131970 테스나
# 133750 메가엠디
# 133820 화인베스틸
# 134060 이퓨쳐
# 134380 미원화학
# 134580 디엠티
# 134780 화진
# 134790 시디즈
# 136480 하림
# 136490 선진
# 136510 쎄미시스코
# 136540 윈스
# 137400 피엔티
# 137940 넥스트아이
# 137950 제이씨케미칼
# 138040 메리츠금융지주
# 138070 신진에스엠
# 138080 오이솔루션
# 138250 엔에스쇼핑
# 138360 에이씨티
# 138490 코오롱플라스틱
# 138580 비즈니스온
# 138610 나이벡
# 138690 엘아이에스
# 138930 BNK금융지주
# 139050 데일리블록체인
# 139130 DGB금융지주
# 139480 이마트
# 139670 넥스트리밍
# 140070 서플러스글로벌
# 140410 메지온
# 140520 대창스틸
# 140670 알에스오토메이션
# 140860 파크시스템스
# 140890 트러스제7호
# 140910 에이리츠
# 141000 비아트론
# 141020 포티스
# 141070 맥스로텍
# 141080 레고켐바이오
# 142210 유니트론텍
# 142280 녹십자엠에스
# 142760 바이오리더스
# 143160 아이디스
# 143210 핸즈코퍼레이션
# 143240 사람인에이치알
# 143540 영우디에스피
# 144510 녹십자랩셀
# 144620 코오롱머티리얼
# 144960 뉴파워프라즈마
# 145020 휴젤
# 145210 세화아이엠씨
# 145270 케이탑리츠
# 145720 덴티움
# 145990 삼양사
# 145995 삼양사우
# 147760 마이크로프랜드
# 147830 제룡산업
# 148140 비디아이
# 148250 알엔투테크놀로지
# 149940 모다
# 149950 아바텍
# 149980 하이로닉
# 150840 인트로메딕
# 150900 파수닷컴
# 151860 KG ETS
# 151910 나노스
# 152330 코리아오토글라스
# 152550 한국ANKOR유전
# 153360 하이골드3호
# 153460 네이블
# 153490 우리이앤엘
# 153710 옵티팜
# 154030 아시아종묘
# 154040 솔루에타
# 155650 와이엠씨
# 155660 DSR
# 155900 바다로19호
# 156100 엘앤케이바이오
# 158310 인터불스
# 159580 제로투세븐
# 159650 하이골드8호
# 159910 스킨앤스킨
# 160550 NEW
# 160600 에스엔텍
# 160980 싸이맥스
# 161000 애경유화
# 161390 한국타이어
# 161570 THE MIDONG
# 161580 필옵틱스
# 161890 한국콜마
# 163560 동일고무벨트
# 166090 하나머티리얼즈
# 166480 코아스템
# 168330 내츄럴엔도텍
# 168490 한국패러랠
# 170030 현대공업
# 170790 파이오링크
# 170900 동아에스티
# 170920 엘티씨
# 171010 램테크놀러지
# 171090 선익시스템
# 171120 라이온켐텍
# 172580 하이골드12호
# 173130 오파스넷
# 173940 에프엔씨엔터
# 174880 장원테크
# 174900 앱클론
# 175140 인포마크
# 175250 아이큐어
# 175330 JB금융지주
# 176440 에이치엔티
# 177350 베셀
# 177830 파버나인
# 178320 서진시스템
# 178780 유테크
# 178920 SKC코오롱PI
# 179290 엠아이텍
# 179900 유티아이
# 180400 캔서롭
# 180640 한진칼
# 181340 이즈미디어
# 181710 NHN엔터테인먼트
# 182360 큐브엔터
# 182400 에이티젠
# 182690 테라셈
# 183190 아세아시멘트
# 183300 코미코
# 183490 엔지켐생명과학
# 184230 SGA솔루션즈
# 185490 아이진
# 185750 종근당
# 187220 디티앤씨
# 187270 신화콘텍
# 187420 제노포커스
# 187790 나노
# 187870 디바이스이엔지
# 189300 인텔리안테크
# 189690 포시에스
# 189860 서전기전
# 189980 흥국에프엔비
# 190510 나무가
# 191410 육일씨엔에쓰
# 191420 테고사이언스
# 192080 더블유게임즈
# 192250 케이사인
# 192390 윈하이텍
# 192400 쿠쿠홀딩스
# 192410 감마누
# 192440 슈피겐코리아
# 192820 코스맥스
# 193250 와이제이엠게임즈
# 194370 제이에스코퍼레이션
# 194480 데브시스터즈
# 194510 파티게임즈
# 194700 노바렉스
# 195440 퓨전데이타
# 195870 해성디에스
# 195990 유지인트
# 196170 알테오젠
# 196300 애니젠
# 196450 텔루스
# 196490 디에이테크놀로지
# 196700 웹스
# 197140 디지캡
# 197210 리드
# 198440 고려시멘트
# 200130 콜마비앤에이치
# 200230 텔콘RF제약
# 200470 하이셈
# 200670 휴메딕스
# 200710 에이디테크놀로지
# 200780 비씨월드제약
# 200880 서연이화
# 201490 미투온
# 203450 유니온커뮤니티
# 203650 드림시큐리티
# 203690 프로스테믹스
# 204020 엠코르셋
# 204210 모두투어리츠
# 204320 만도
# 204620 글로벌텍스프리
# 204630 화이브라더스코리아
# 204840 지엘팜텍
# 204990 현성바이탈
# 205100 엑셈
# 205470 휴마시스
# 205500 액션스퀘어
# 206400 엔터메이트
# 206560 덱스터
# 206640 바디텍메드
# 206650 유바이오로직스
# 207760 미스터블루
# 207940 삼성바이오로직스
# 208140 정다운
# 208340 파멥신
# 208350 지란지교시큐리티
# 208370 셀바스헬스케어
# 208640 썸에이지
# 208710 바이오로그디바이스
# 208860 엔지스테크널러지
# 210540 디와이파워
# 210980 SK디앤디
# 211270 AP위성
# 212560 네오오토
# 213090 미래테크놀로지
# 213420 덕산네오룩스
# 213500 한솔제지
# 214150 클래시스
# 214180 민앤지
# 214270 퓨쳐스트림네트웍스
# 214310 세미콘라이트
# 214320 이노션
# 214330 금호에이치티
# 214370 케어젠
# 214390 경보제약
# 214420 토니모리
# 214430 아이쓰리시스템
# 214450 파마리서치프로덕트
# 214680 디알텍
# 214870 에치디프로
# 215000 골프존
# 215090 한컴유니맥스
# 215100 로보로보
# 215200 메가스터디교육
# 215360 우리산업
# 215380 우정바이오
# 215480 토박스코리아
# 215600 신라젠
# 215790 이노인스트루먼트
# 216050 인크로스
# 217190 제너셈
# 217270 넵튠
# 217330 싸이토젠
# 217480 에스디생명공학
# 217500 러셀
# 217600 켐온
# 217620 디딤
# 217730 강스템바이오텍
# 217820 엔에스
# 218150 미래생명자원
# 218410 RFHIC
# 219130 타이거일렉
# 219420 링크제니시스
# 219550 MP한강
# 219750 지티지웰니스
# 220100 퓨쳐켐
# 220180 핸디소프트
# 220260 켐트로스
# 220630 해마로푸드서비스
# 221610 한솔씨앤피
# 221840 하이즈항공
# 221980 케이디켐
# 222040 뉴트리바이오텍
# 222080 씨아이에스
# 222110 팬젠
# 222420 쎄노텍
# 222800 심텍
# 222810 한류AI센터
# 222980 한국맥널티
# 223310 이에스브이
# 224060 코디엠
# 224110 에이텍티앤
# 225190 삼양옵틱스
# 225330 씨엠에스에듀
# 225430 케이엠제약
# 225530 보광산업
# 225570 넷게임즈
# 225590 패션플랫폼
# 225650 쿠첸
# 226320 잇츠한불
# 226340 본느
# 226350 아이엠텍
# 226360 이엑스티
# 226400 오스테오닉
# 226440 한송네오텍
# 226950 올릭스
# 227100 디자인
# 227610 아우딘퓨쳐스
# 227840 현대코퍼레이션홀딩스
# 227950 마이크로텍
# 228340 동양파일
# 228850 레이언스
# 229640 LS전선아시아
# 230240 에치에프알
# 230360 에코마케팅
# 230980 솔트웍스
# 232140 와이아이케이
# 232330 SK3호스팩
# 234080 JW생명과학
# 234100 세원
# 234300 에스트래픽
# 234920 자이글
# 236200 슈프리마
# 237690 에스티팜
# 237750 피앤씨테크
# 237880 클리오
# 238090 앤디포스
# 238120 로고스바이오
# 238200 비피도
# 238490 힘스
# 239340 미래에셋제5호스팩
# 239610 에이치엘사이언스
# 240540 한국4호스팩
# 240810 원익IPS
# 241520 DSC인베스트먼트
# 241560 두산밥캣
# 241590 화승엔터프라이즈
# 241690 유니테크노
# 241710 코스메카코리아
# 241770 메카로
# 241790 오션브릿지
# 241820 피씨엘
# 242040 나무기술
# 243070 휴온스
# 243840 신흥에스이씨
# 245620 EDGC
# 246690 티에스인베스트먼트
# 246710 티앤알바이오팹
# 246720 아스타
# 248170 샘표식품
# 249420 일동제약
# 250000 보라티알
# 250060 모비스
# 250930 케이비제10호스팩
# 251270 넷마블
# 251370 와이엠티
# 251630 브이원텍
# 252500 세화피앤씨
# 253450 스튜디오드래곤
# 253590 대신밸런스제3호스팩
# 254120 IBKS제5호스팩
# 255220 SG
# 255440 야스
# 256630 엔에이치스팩10호
# 256840 엔에이치스팩11호
# 256940 케이피에스
# 257370 명성티엔에스
# 257730 신한제3호스팩
# 258610 이더블유케이
# 258790 케이비제11호스팩
# 258830 세종메디칼
# 259630 엠플러스
# 260660 알리코제약
# 260930 씨티케이코스메틱스
# 261200 하나금융9호스팩
# 262830 대신밸런스제4호스팩
# 263020 디케이앤디
# 263050 유틸렉스
# 263540 샘코
# 263600 덕우전자
# 263690 디알젬
# 263700 케어랩스
# 263720 디앤씨미디어
# 263750 펄어비스
# 263770 유에스티
# 263800 데이타솔루션
# 263810 상신전자
# 263860 지니언스
# 263920 에스엔피월드
# 264290 한화에이스스팩3호
# 264450 유비쿼스
# 264660 씨앤지하이테크
# 264850 IBKS제6호스팩
# 264900 크라운제과
# 265480 미래에셋대우스팩1호
# 265520 AP시스템
# 265560 영화테크
# 265920 한화수성스팩
# 267250 현대중공업지주
# 267260 현대일렉트릭
# 267270 현대건설기계
# 267290 경동도시가스
# 267320 교보7호스팩
# 267790 배럴
# 267850 아시아나IDT
# 267980 매일유업
# 268280 미원에스씨
# 268600 셀리버리
# 269620 시스웍
# 270520 하나금융10호스팩
# 270870 뉴트리
# 271560 오리온
# 271740 한국제5호스팩
# 271980 제일약품
# 272290 이녹스첨단소재
# 272450 진에어
# 272550 삼양패키징
# 273060 엔에이치스팩12호
# 275630 에스에스알
# 276920 IBKS제7호스팩
# 277070 린드먼아시아
# 277410 인산가
# 277480 신한제4호스팩
# 279410 한화에이스스팩4호
# 280360 롯데제과
# 281410 한국제6호스팩
# 281740 동부스팩5호
# 281820 케이씨텍
# 282330 BGF리테일
# 282690 동아타이어
# 284620 하나금융11호스팩
# 284740 쿠쿠홈시스
# 285130 SK케미칼
# 285490 노바텍
# 286940 롯데정보통신
# 287410 유안타제3호스팩
# 288620 에스퓨얼셀
# 289080 SV인베스트먼트
# 290120 대유에이피
# 290270 휴네시온
# 290380 대유
# 290550 디케이티
# 290650 엘앤씨바이오
# 290660 네오펙트
# 290670 대보마그네틱
# 290720 푸드나무
# 290740 액트로
# 291210 한국제7호스팩
# 291230 삼성스팩2호
# 293480 하나제약
# 293580 나우아이비캐피탈
# 293940 신한알파리츠
# 294870 HDC현대산업개발
# 297570 IBKS제9호스팩
# 298000 효성화학
# 298020 효성티앤씨
# 298040 효성중공업
# 298050 효성첨단소재
# 298380 에이비엘바이오
# 298690 에어부산
# 299170 IBKS제10호스팩
# 299900 위지윅스튜디오
# 299910 베스파
# 300720 한일시멘트
# 302430 이노메트리
# 303030 대신밸런스제5호스팩
# 306200 세아제강
# 306620 DB금융스팩6호
# 307070 SK4호스팩
# 307160 하나머스트제6호스팩
# 307180 신영스팩4호
# 307280 교보8호스팩
# 307750 대신밸런스제6호스팩
# 307870 골든브릿지이안5호
# 309930 삼성머스트스팩3호
# 310200 미래에셋대우스팩2호
# 310840 엔에이치스팩13호
# 310870 한국제8호스팩
# 311270 키움제5호스팩
# 900040 차이나그레이트
# 900070 글로벌에스엠
# 900080 에스앤씨엔진그룹
# 900100 뉴프라이드
# 900110 이스트아시아홀딩스
# 900120 씨케이에이치
# 900140 엘브이엠씨홀딩스
# 900250 크리스탈신소재
# 900260 로스웰
# 900270 헝셩그룹
# 900280 골든센츄리
# 900290 GRT
# 900300 오가닉티코스메틱
# 900310 컬러레이
# 900340 윙입푸드
# 950110 SBI핀테크솔루션즈
# 950130 엑세스바이오
# 950140 잉글우드랩
# 950160 코오롱티슈진
# 950170 JTC

# %%
# KOSPI_STOCK PRICE TO MYSQL

import pandas as pd
import FinanceDataReader as fdr
import sqlalchemy 
import pymysql
pymysql.install_as_MySQLdb() # MySQLdb와 호환 
import MySQLdb

engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
conn = engine.connect()

data = pd.read_excel('d:\\market_list.xlsx')

code_list = data['종목코드'].tolist()
code_list = [str(item).zfill(6) for item in code_list]
name_list = data['종목명'].tolist()

# 코스피 상장종목 전체
stock_dic = dict(list(zip(code_list,name_list)))

for code in sorted(stock_dic.keys()):
    #df  = fdr.DataReader(code, '')
    print(code,stock_dic[code])
    df['Code'],df['Name'] = code,stock_dic[code]
    df = df[['Code','Name','Open','High','Low','Volume','Close']]
    df.to_sql(name='market', con=engine, if_exists='append')
    #df.to_excel('d:\\data_set\\kospi\\'+ stock_dic[code] +'.xlsx',engine = 'xlsxwriter')
# Out:
# 000250 삼천당제약
# 000440 중앙에너비스
# 001000 신라섬유
# 001540 안국약품
# 001810 무림SP
# 001840 이화공영
# 002230 피에스텍
# 002290 삼일기업공사
# 002680 한탑
# 002800 신신제약
# 003100 선광
# 003310 대주산업
# 003380 하림지주
# 003670 포스코켐텍
# 003800 에이스침대
# 004590 한국가구
# 004650 창해에탄올
# 004780 대륙제관
# 005160 동국산업
# 005290 동진쎄미켐
# 005670 푸드웰
# 005710 대원산업
# 005860 한일사료
# 005990 매일홀딩스
# 006050 국영지앤엠
# 006140 피제이전자
# 006580 대양제지
# 006620 동구바이오제약
# 006730 서부T&D
# 006910 보성파워텍
# 006920 모헨즈
# 007330 푸른저축은행
# 007370 진양제약
# 007390 네이처셀
# 007530 영신금속
# 007680 대원
# 007720 대명코퍼레이션
# 007770 한일화학
# 007820 에스엠코어
# 008290 원풍물산
# 008370 원풍
# 008470 부스타
# 008800 행남사
# 008830 대동기어
# 009300 삼아제약
# 009520 포스코엠텍
# 009620 삼보산업
# 009730 코센
# 009780 엠에스씨
# 010040 한국내화
# 010050 우리종금
# 010060 OCI
# 010100 한국프랜지
# 010120 LS산전
# 010130 고려아연
# 010140 삼성중공업
# 010145 삼성중공우
# 010170 대한광통신
# 010240 흥국
# 010280 쌍용정보통신
# 010400 우진아이엔에스
# 010420 한솔PNS
# 010470 오리콤
# 010580 지코
# 010600 웰바이오텍
# 010620 현대미포조선
# 010640 진양폴리
# 010660 화천기계
# 010690 화신
# 010770 평화홀딩스
# 010780 아이에스동서
# 010820 퍼스텍
# 010950 S-Oil
# 010955 S-Oil우
# 010960 삼호개발
# 011000 진원생명과학
# 011040 경동제약
# 011070 LG이노텍
# 011080 형지I&C
# 011090 에넥스
# 011150 CJ씨푸드
# 011155 CJ씨푸드1우
# 011160 두산건설
# 011170 롯데케미칼
# 011200 현대상선
# 011210 현대위아
# 011230 삼화전자
# 011280 태림포장
# 011300 성안
# 011320 유니크
# 011330 유니켐
# 011370 서한
# 011390 부산산업
# 011420 갤럭시아에스엠
# 011500 한농화성
# 011560 세보엠이씨
# 011690 유양디앤유
# 011700 한신기계
# 011760 현대상사
# 011780 금호석유
# 011785 금호석유우
# 011790 SKC
# 011810 STX
# 011930 신성이엔지
# 012030 DB
# 012160 영흥철강
# 012170 키위미디어그룹
# 012200 계양전기
# 012205 계양전기우
# 012280 영화금속
# 012320 경동인베스트
# 012330 현대모비스
# 012340 뉴인텍
# 012450 한화에어로스페이스
# 012510 더존비즈온
# 012600 청호컴넷
# 012610 경인양행
# 012620 원일특강
# 012630 HDC
# 012690 모나리자
# 012700 리드코프
# 012750 에스원
# 012790 신일제약
# 012800 대창
# 012860 서연전자
# 013000 세우글로벌
# 013030 하이록코리아
# 013120 동원개발
# 013310 아진산업
# 013360 일성건설
# 013520 화승알앤에이
# 013570 디와이
# 013580 계룡건설
# 013700 까뮤이앤씨
# 013720 청보산업
# 013810 스페코
# 013870 지엠비코리아
# 013990 아가방컴퍼니
# 014100 보령메디앙스
# 014130 한익스프레스
# 014160 대영포장
# 014190 원익큐브
# 014200 광림
# 014280 금강공업
# 014285 금강공업우
# 014440 영보화학
# 014470 부방
# 014530 극동유화
# 014570 고려제약
# 014580 백광소재
# 014620 성광벤드
# 014680 한솔케미칼
# 014710 사조씨푸드
# 014790 한라
# 014820 동원시스템즈
# 014825 동원시스템즈우
# 014830 유니드
# 014910 성문전자
# 014915 성문전자우
# 014940 오리엔탈정공
# 014970 삼륭물산
# 014990 인디에프
# 015020 이스타코
# 015230 대창단조
# 015260 에이엔피
# 015350 부산가스
# 015360 예스코홀딩스
# 015540 메디플란트
# 015590 큐로
# 015710 코콤
# 015750 성우하이텍
# 015760 한국전력
# 015860 일진홀딩스
# 015890 태경산업
# 016090 대현
# 016100 리더스코스메틱
# 016250 이테크건설
# 016360 삼성증권
# 016380 동부제철
# 016385 동부제철우
# 016450 한세예스24홀딩스
# 016580 환인제약
# 016590 신대양제지
# 016600 큐캐피탈
# 016610 DB금융투자
# 016670 포비스티앤씨
# 016710 대성홀딩스
# 016740 두올
# 016790 현대사료
# 016800 퍼시스
# 016880 웅진
# 016920 카스
# 017000 신원종합개발
# 017040 광명전기
# 017180 명문제약
# 017250 인터엠
# 017370 우신시스템
# 017390 서울가스
# 017480 삼현철강
# 017510 세명전기
# 017550 수산중공업
# 017650 대림제지
# 017670 SK텔레콤
# 017680 데코앤이
# 017800 현대엘리베이
# 017810 풀무원
# 017890 한국알콜
# 017900 광전자
# 017940 E1
# 017960 한국카본
# 018000 유니슨
# 018120 진로발효
# 018250 애경산업
# 018260 삼성에스디에스
# 018290 지엠피
# 018310 삼목에스폼
# 018470 조일알미늄
# 018500 동원금속
# 018620 우진비앤지
# 018670 SK가스
# 018680 서울제약
# 018700 바른손
# 018880 한온시스템
# 019010 그랜드백화점
# 019170 신풍제약
# 019175 신풍제약우
# 019180 티에이치엔
# 019210 와이지-원
# 019440 세아특수강
# 019490 하이트론
# 019540 일지테크
# 019550 SBI인베스트먼트
# 019570 제미니투자
# 019590 엠벤처투자
# 019660 글로본
# 019680 대교
# 019685 대교우B
# 019770 서연탑메탈
# 019990 에너토크
# 020000 한섬
# 020120 키다리스튜디오
# 020150 일진머티리얼즈
# 020180 대신정보통신
# 020400 대동금속
# 020560 아시아나항공
# 020710 시공테크
# 020760 일진디스플
# 021040 대호피앤씨
# 021045 대호피앤씨우
# 021050 서원
# 021080 에이티넘인베스트
# 021240 코웨이
# 021320 KCC건설
# 021650 한국큐빅
# 021820 세원정공
# 021880 메이슨캐피탈
# 022100 포스코 ICT
# 022220 정산애강
# 023000 삼원강재
# 023150 MH에탄올
# 023160 태광
# 023350 한국종합기술
# 023410 유진기업
# 023440 제일제강
# 023450 동남합성
# 023460 CNH
# 023530 롯데쇼핑
# 023590 다우기술
# 023600 삼보판지
# 023760 한국캐피탈
# 023770 플레이위드
# 023790 동일철강
# 023800 인지컨트롤스
# 023810 인팩
# 023890 아트라스BX
# 023900 풍국주정
# 023910 대한약품
# 023960 에쓰씨엔지니어링
# 024060 흥구석유
# 024070 WISCOM
# 024090 디씨엠
# 024110 기업은행
# 024120 KB오토시스
# 024720 한국콜마홀딩스
# 024740 한일단조
# 024800 유성티엔에스
# 024810 이화전기
# 024830 세원물산
# 024840 갑을메탈
# 024850 피에스엠씨
# 024880 케이피에프
# 024890 대원화성
# 024900 덕양산업
# 024910 경창산업
# 024940 PN풍년
# 024950 삼천리자전거
# 025000 KPX케미칼
# 025320 시노펙스
# 025440 대성엘텍
# 025530 SJM홀딩스
# 025540 한국단자
# 025550 한국선재
# 025560 미래산업
# 025620 제이준코스메틱
# 025750 한솔홈데코
# 025770 한국정보통신
# 025820 이구산업
# 025860 남해화학
# 025870 신라에스지
# 025880 케이씨피드
# 025890 한국주강
# 025900 동화기업
# 025950 동신건설
# 025980 아난티
# 026040 제이에스티나
# 026150 특수건설
# 026180 현대정보기술
# 026890 디피씨
# 026910 광진실업
# 026940 부국철강
# 026960 동서
# 027040 서울전자통신
# 027050 코리아나
# 027360 아주IB투자
# 027390 한화갤러리아타임월드
# 027410 BGF
# 027580 상보
# 027710 팜스토리
# 027740 마니커
# 027830 대성창투
# 027970 세하
# 028040 미래SCI
# 028050 삼성엔지니어링
# 028080 휴맥스홀딩스
# 028100 동아지질
# 028150 GS홈쇼핑
# 028260 삼성물산
# 028300 에이치엘비
# 028670 팬오션
# 029460 케이씨
# 029480 바른테크놀로지
# 029530 신도리코
# 029780 삼성카드
# 029960 코엔텍
# 030000 제일기획
# 030190 NICE평가정보
# 030200 KT
# 030210 KTB투자증권
# 030270 에스마크
# 030350 드래곤플라이
# 030520 한글과컴퓨터
# 030530 원익홀딩스
# 030610 교보증권
# 030720 동원수산
# 030790 동양네트웍스
# 030960 양지사
# 031310 아이즈비전
# 031330 에스에이엠티
# 031390 녹십자셀
# 031430 신세계인터내셔날
# 031440 신세계푸드
# 031510 오스템
# 031820 콤텍시스템
# 031860 엔에스엔
# 031980 피에스케이
# 032080 아즈텍WB
# 032190 다우데이타
# 032280 삼일
# 032350 롯데관광개발
# 032500 케이엠더블유
# 032540 TJ미디어
# 032560 황금에스티
# 032580 피델릭스
# 032620 유비케어
# 032640 LG유플러스
# 032680 소프트센
# 032685 소프트센우
# 032750 삼진
# 032790 엠젠플러스
# 032800 판타지오
# 032820 우리기술
# 032830 삼성생명
# 032850 비트컴퓨터
# 032860 GMR 머티리얼즈
# 032940 원익
# 032960 동일기연
# 032980 바이온
# 033050 제이엠아이
# 033100 제룡전기
# 033110 이디
# 033130 디지틀조선
# 033160 엠케이전자
# 033170 시그네틱스
# 033180 필룩스
# 033200 모아텍
# 033230 인성정보
# 033240 자화전자
# 033250 체시스
# 033270 유나이티드제약
# 033290 코웰패션
# 033310 디케이디앤아이
# 033320 제이씨현시스템
# 033340 좋은사람들
# 033430 디에스티
# 033500 동성화인텍
# 033530 세종공업
# 033540 파라텍
# 033560 블루콤
# 033600 에이코넬
# 033640 네패스
# 033660 아주캐피탈
# 033780 KT&G
# 033790 스카이문스테크놀로지
# 033830 티비씨
# 033920 무학
# 034020 두산중공업
# 034120 SBS
# 034220 LG디스플레이
# 034230 파라다이스
# 034300 신세계건설
# 034310 NICE
# 034590 인천도시가스
# 034730 SK
# 034810 해성산업
# 034830 한국토지신탁
# 034940 조아제약
# 034950 한국기업평가
# 035000 지투알
# 035080 인터파크홀딩스
# 035150 백산
# 035200 프럼파스트
# 035250 강원랜드
# 035290 더블유에프엠
# 035420 NAVER
# 035460 기산텔레콤
# 035480 마제스타
# 035510 신세계 I&C
# 035600 KG이니시스
# 035610 솔본
# 035620 바른손이앤에이
# 035720 카카오
# 035760 CJ ENM
# 035810 이지바이오
# 035890 서희건설
# 035900 JYP Ent.
# 036000 예림당
# 036010 아비코전자
# 036030 KTH
# 036090 위지트
# 036120 SCI평가정보
# 036170 씨티젠
# 036180 영인프런티어
# 036190 금화피에스시
# 036200 유니셈
# 036260 이매진아시아
# 036420 제이콘텐트리
# 036460 한국가스공사
# 036480 대성미생물
# 036490 SK머티리얼즈
# 036530 S&T홀딩스
# 036540 SFA반도체
# 036560 영풍정밀
# 036570 엔씨소프트
# 036580 팜스코
# 036620 버추얼텍
# 036630 세종텔레콤
# 036640 HRS
# 036670 KCI
# 036690 코맥스
# 036710 심텍홀딩스
# 036800 나이스정보통신
# 036810 에프에스티
# 036830 솔브레인
# 036890 진성티이씨
# 036930 주성엔지니어링
# 037030 파워넷
# 037070 파세코
# 037230 한국팩키지
# 037270 YG PLUS
# 037330 인지디스플레
# 037350 성도이엔지
# 037370 EG
# 037400 우리조명
# 037440 희림
# 037460 삼지전자
# 037560 CJ헬로
# 037710 광주신세계
# 037760 쎄니트
# 037950 엘컴텍
# 038010 제일테크노스
# 038060 루멘스
# 038070 서린바이오
# 038110 에코플라스틱
# 038160 팍스넷
# 038290 마크로젠
# 038340 UCI
# 038390 레드캡투어
# 038460 바이오스마트
# 038500 삼표시멘트
# 038530 골드퍼시픽
# 038540 상상인
# 038620 위즈코프
# 038680 에스넷
# 038870 에코바이오
# 038880 아이에이
# 038950 파인디지털
# 039010 현대통신
# 039020 이건홀딩스
# 039030 이오테크닉스
# 039130 하나투어
# 039200 오스코텍
# 039230 에이아이비트
# 039240 경남스틸
# 039290 인포뱅크
# 039310 세중
# 039340 한국경제TV
# 039420 케이엘넷
# 039440 에스티아이
# 039490 키움증권
# 039560 다산네트웍스
# 039570 HDC아이콘트롤스
# 039610 화성밸브
# 039670 스포츠서울
# 039740 한국정보공학
# 039830 오로라
# 039840 디오
# 039860 나노엔텍
# 039980 리노스
# 040160 누리텔레콤
# 040300 YTN
# 040350 큐로컴
# 040420 정상제이엘에스
# 040610 SG&G
# 040910 아이씨디
# 041020 인프라웨어
# 041140 넥슨지티
# 041190 우리기술투자
# 041440 에버다임
# 041460 한국전자인증
# 041510 에스엠
# 041520 이라이콤
# 041590 에너전트
# 041650 상신브레이크
# 041830 인바디
# 041910 에스텍파마
# 041920 메디아나
# 041930 동아화성
# 041960 코미팜
# 042000 카페24
# 042040 케이피엠테크
# 042110 에스씨디
# 042370 비츠로테크
# 042420 네오위즈홀딩스
# 042500 링네트
# 042510 라온시큐어
# 042520 한스바이오메드
# 042600 새로닉스
# 042660 대우조선해양
# 042670 두산인프라코어
# 042700 한미반도체
# 042940 상지카일룸
# 043090 팜스웰바이오
# 043100 솔고바이오
# 043150 바텍
# 043200 파루
# 043220 에이치엘비파워
# 043260 성호전자
# 043290 케이맥
# 043340 에쎈테크
# 043360 디지아이
# 043370 평화정공
# 043590 크로바하이텍
# 043610 지니뮤직
# 043650 국순당
# 043710 서울리거
# 043910 자연과환경
# 044060 조광ILI
# 044180 KD건설
# 044340 위닉스
# 044380 주연테크
# 044450 KSS해운
# 044480 바이오제네틱스
# 044490 태웅
# 044780 에이치케이
# 044820 코스맥스비티아이
# 044960 이글벳
# 045060 오공
# 045100 한양이엔지
# 045300 성우테크론
# 045340 토탈소프트
# 045390 대아티아이
# 045510 정원엔시스
# 045520 크린앤사이언스
# 045660 에이텍
# 045890 GV
# 045970 코아시아홀딩스
# 046070 코다코
# 046110 한일네트웍스
# 046120 오르비텍
# 046140 SBS콘텐츠허브
# 046210 파나진
# 046310 백금T&A
# 046390 삼화네트웍스
# 046440 KG모빌리언스
# 046890 서울반도체
# 046940 우원개발
# 046970 우리로
# 047040 대우건설
# 047050 포스코대우
# 047080 한빛소프트
# 047310 파워로직스
# 047400 유니온머티리얼
# 047560 이스트소프트
# 047770 코데즈컴바인
# 047810 한국항공우주
# 047820 초록뱀
# 047920 씨트리
# 048260 오스템임플란트
# 048410 현대바이오
# 048430 유라테크
# 048470 대동스틸
# 048530 인트론바이오
# 048550 SM C&C
# 048770 TPC
# 048830 엔피케이
# 048870 시너지이노베이션
# 048910 대원미디어
# 049070 인탑스
# 049080 기가레인
# 049120 파인디앤씨
# 049180 셀루메드
# 049430 코메론
# 049470 SGA
# 049480 오픈베이스
# 049520 유아이엘
# 049550 잉크테크
# 049630 재영솔루텍
# 049720 고려신용정보
# 049770 동원F&B
# 049800 우진플라임
# 049830 승일
# 049950 미래컴퍼니
# 049960 쎌바이오텍
# 050090 휘닉스소재
# 050110 캠시스
# 050120 라이브플렉스
# 050320 에이앤티앤
# 050540 한국코퍼레이션
# 050760 에스폴리텍
# 050860 아세아텍
# 050890 쏠리드
# 050960 수산아이앤티
# 051160 지어소프트
# 051360 토비스
# 051370 인터플렉스
# 051380 피씨디렉트
# 051390 YW
# 051490 나라엠앤디
# 051500 CJ프레시웨이
# 051600 한전KPS
# 051630 진양화학
# 051780 큐로홀딩스
# 051900 LG생활건강
# 051905 LG생활건강우
# 051910 LG화학
# 051915 LG화학우
# 051980 중앙리빙테크
# 052020 에스티큐브
# 052190 이에스에이
# 052220 iMBC
# 052260 SK바이오랜드
# 052300 W홀딩컴퍼니
# 052330 코텍
# 052400 코나아이
# 052420 오성첨단소재
# 052460 아이크래프트
# 052600 한네트
# 052670 제일바이오
# 052690 한전기술
# 052710 아모텍
# 052770 와이디온라인
# 052790 액토즈소프트
# 052860 아이앤씨
# 052900 KMH하이텍
# 053030 바이넥스
# 053050 지에스이
# 053060 세동
# 053110 소리바다
# 053160 프리엠스
# 053210 스카이라이프
# 053260 금강철강
# 053270 구영테크
# 053280 예스24
# 053290 NE능률
# 053300 한국정보인증
# 053350 이니텍
# 053450 세코닉스
# 053590 한국테크놀로지
# 053610 프로텍
# 053620 태양
# 053660 현진소재
# 053690 한미글로벌
# 053700 삼보모터스
# 053800 안랩
# 053950 경남제약
# 053980 오상자이엘
# 054040 한국컴퓨터
# 054050 농우바이오
# 054090 삼진엘앤디
# 054180 중앙오션
# 054210 이랜텍
# 054220 비츠로시스
# 054300 팬스타엔터프라이즈
# 054340 피앤텔
# 054410 케이피티유
# 054450 텔레칩스
# 054540 삼영엠텍
# 054620 APS홀딩스
# 054630 에이디칩스
# 054670 대한뉴팜
# 054780 키이스트
# 054800 아이디스홀딩스
# 054920 한컴시큐어
# 054930 유신
# 054940 엑사이엔씨
# 054950 제이브이엠
# 055490 테이팩스
# 055550 신한지주
# 056000 신스타임즈
# 056080 유진로봇
# 056090 유앤아이
# 056190 에스에프에이
# 056360 코위버
# 056700 신화인터텍
# 056730 포스링크
# 057030 와이비엠넷
# 057050 현대홈쇼핑
# 057500 SKC 솔믹스
# 057540 옴니시스템
# 057680 옴니텔
# 057880 토필드
# 058110 멕아이씨에스
# 058220 아리온
# 058400 KNN
# 058420 제이웨이
# 058430 포스코강판
# 058450 일야
# 058470 리노공업
# 058530 슈펙스비앤피
# 058610 에스피지
# 058630 엠게임
# 058650 세아홀딩스
# 058730 다스코
# 058820 CMG제약
# 058850 KTcs
# 058860 케이티스
# 059090 미코
# 059100 아이컴포넌트
# 059120 아진엑스텍
# 059210 메타바이오메드
# 060150 인선이엔티
# 060230 이그잭스
# 060240 룽투코리아
# 060250 NHN한국사이버결제
# 060260 뉴보텍
# 060280 큐렉소
# 060300 레드로버
# 060310 3S
# 060370 KT서브마린
# 060380 동양에스텍
# 060480 국일신동
# 060540 에스에이티
# 060560 홈센타홀딩스
# 060570 아이리버
# 060590 씨티씨바이오
# 060720 KH바텍
# 060900 퍼시픽바이오
# 060980 한라홀딩스
# 061040 알에프텍
# 061250 화일약품
# 061970 엘비세미콘
# 062860 티엘아이
# 063080 게임빌
# 063160 종근당바이오
# 063170 서울옥션
# 063440 SM Life Design
# 063570 한국전자금융
# 063760 이엘피
# 064090 에프앤리퍼블릭
# 064240 홈캐스트
# 064260 다날
# 064290 인텍플러스
# 064350 현대로템
# 064480 브리지텍
# 064510 에코마이스터
# 064520 바른전자
# 064550 바이오니아
# 064760 티씨케이
# 064800 필링크
# 064820 케이프
# 064960 S&T모티브
# 065060 지엔코
# 065130 탑엔지니어링
# 065150 MP그룹
# 065160 에프티이앤이
# 065170 넥스트BT
# 065350 신성델타테크
# 065420 에스아이리소스
# 065440 이루온
# 065450 빅텍
# 065500 오리엔트정공
# 065510 휴비츠
# 065530 전파기지국
# 065560 녹원씨엔아이
# 065570 삼영이엔씨
# 065620 제낙스
# 065650 메디프론
# 065660 안트로젠
# 065680 우주일렉트로
# 065690 대진디엠피
# 065710 서호전기
# 065770 CS
# 065940 바이오빌
# 065950 웰크론
# 066110 한프
# 066130 하츠
# 066310 큐에스아이
# 066360 체리부로
# 066410 버킷스튜디오
# 066430 와이오엠
# 066570 LG전자
# 066575 LG전자우
# 066590 우수AMS
# 066620 국보디자인
# 066670 디스플레이텍
# 066700 테라젠이텍스
# 066790 씨씨에스
# 066900 디에이피
# 066910 손오공
# 066970 엘앤에프
# 066980 브레인콘텐츠
# 067000 조이시티
# 067010 이씨에스
# 067080 대화제약
# 067160 아프리카TV
# 067170 오텍
# 067280 멀티캠퍼스
# 067290 JW신약
# 067310 하나마이크론
# 067390 아스트
# 067570 엔브이에이치코리아
# 067630 에이치엘비생명과학
# 067730 로지시스
# 067770 세진티에스
# 067830 세이브존I&C
# 067900 와이엔텍
# 067920 이글루시큐리티
# 067990 도이치모터스
# 068050 팬엔터테인먼트
# 068240 다원시스
# 068270 셀트리온
# 068290 삼성출판사
# 068330 일신바이오
# 068400 AJ렌터카
# 068760 셀트리온제약
# 068790 DMS
# 068930 디지털대성
# 068940 아이씨케이
# 069080 웹젠
# 069110 코스온
# 069140 누리플랜
# 069260 휴켐스
# 069330 유아이디
# 069410 엔텔스
# 069460 대호에이엘
# 069510 에스텍
# 069540 라이트론
# 069620 대웅제약
# 069640 한세엠케이
# 069730 DSR제강
# 069920 아이에스이커머스
# 069960 현대백화점
# 070300 한솔시큐어
# 070590 한솔인티큐브
# 070960 용평리조트
# 071050 한국금융지주
# 071055 한국금융지주우
# 071090 하이스틸
# 071200 인피니트헬스케어
# 071280 로체시스템즈
# 071320 지역난방공사
# 071460 대유위니아
# 071670 에이테크솔루션
# 071840 롯데하이마트
# 071850 캐스텍코리아
# 071950 코아스
# 071970 STX중공업
# 072020 중앙백신
# 072130 유엔젤
# 072470 우리산업홀딩스
# 072520 제넨바이오
# 072710 농심홀딩스
# 072770 네오디안테크놀로지
# 072870 메가스터디
# 072950 빛샘전자
# 072990 에이치시티
# 073010 케이에스피
# 073070 에스모
# 073110 엘엠에스
# 073190 듀오백
# 073240 금호타이어
# 073490 이노와이어리스
# 073540 에프알텍
# 073560 우리손에프앤지
# 073570 피엠지파마
# 073640 삼원테크
# 074430 아미노로직스
# 074600 원익QnC
# 074610 나노메딕스
# 075130 플랜티넷
# 075180 새론오토모티브
# 075580 세진중공업
# 075970 동국알앤에스
# 076080 웰크론한텍
# 076610 해성옵틱스
# 077280 한컴지엠디
# 077360 덕산하이메탈
# 077500 유니퀘스트
# 077970 STX엔진
# 078000 텔코웨어
# 078020 이베스트투자증권
# 078070 유비쿼스홀딩스
# 078130 국일제지
# 078140 대봉엘에스
# 078150 HB테크놀러지
# 078160 메디포스트
# 078340 컴투스
# 078350 한양디지텍
# 078520 에이블씨엔씨
# 078590 두올산업
# 078600 대주전자재료
# 078650 코렌
# 078860 아이오케이
# 078890 가온미디어
# 078930 GS
# 078935 GS우
# 078940 일경산업개발
# 079000 와토스코리아
# 079160 CJ CGV
# 079170 한창산업
# 079190 EMW
# 079370 제우스
# 079430 현대리바트
# 079440 오렌지라이프
# 079550 LIG넥스원
# 079650 서산
# 079660 사조해표
# 079810 디이엔티
# 079940 가비아
# 079950 인베니아
# 079960 동양이엔피
# 079970 투비소프트
# 079980 휴비스
# 080000 에스엔유
# 080010 이상네트웍스
# 080160 모두투어
# 080220 제주반도체
# 080420 모다이노칩
# 080440 에스제이케이
# 080470 성창오토텍
# 080520 오디텍
# 080530 코디
# 080580 오킨스전자
# 080720 한국유니온제약
# 081000 일진다이아
# 081150 티플랙스
# 081580 성우전자
# 081660 휠라코리아
# 082210 옵트론텍
# 082270 젬백스
# 082640 동양생명
# 082660 삼우엠스
# 082740 HSD엔진
# 082800 루미마이크로
# 082850 우리이티아이
# 082920 비츠로셀
# 083310 엘오티베큠
# 083370 동북아12호
# 083380 동북아13호
# 083420 그린케미칼
# 083450 GST
# 083470 KJ프리텍
# 083500 에프엔에스테크
# 083550 케이엠
# 083640 인콘
# 083650 비에이치아이
# 083660 CSA 코스믹
# 083790 크리스탈
# 083930 아바코
# 084010 대한제강
# 084110 휴온스글로벌
# 084180 수성
# 084370 유진테크
# 084650 랩지노믹스
# 084670 동양고속
# 084680 이월드
# 084690 대상홀딩스
# 084695 대상홀딩스우
# 084730 팅크웨어
# 084870 TBH글로벌
# 084990 바이로메드
# 085310 엔케이
# 085370 루트로닉
# 08537M 루트로닉3우C
# 085620 미래에셋생명
# 085660 차바이오텍
# 085670 뉴프렉스
# 085810 알티캐스트
# 085910 네오티스
# 086040 바이오톡스텍
# 086060 진바이오텍
# 086250 화신테크
# 086280 현대글로비스
# 086390 유니테스트
# 086450 동국제약
# 086520 에코프로
# 086670 비엠티
# 086790 하나금융지주
# 086820 바이오솔루션
# 086890 이수앱지스
# 086900 메디톡스
# 086960 한컴MDS
# 086980 쇼박스
# 087010 펩트론
# 087260 모바일어플라이언스
# 087600 픽셀플러스
# 087730 네패스신소재
# 088130 동아엘텍
# 088260 이리츠코크렙
# 088290 이원컴포텍
# 088350 한화생명
# 088390 이녹스
# 088790 진도
# 088800 에이스테크
# 088910 동우팜투테이블
# 088980 맥쿼리인프라
# 089010 켐트로닉스
# 089030 테크윙
# 089140 넥스턴
# 089150 케이씨티
# 089230 THE E&M
# 089470 HDC현대EP
# 089530 에이티세미콘
# 089590 제주항공
# 089600 나스미디어
# 089790 제이티
# 089850 유비벨록스
# 089890 코세스
# 089970 에이피티씨
# 089980 상아프론테크
# 090080 평화산업
# 090150 광진윈텍
# 090350 노루페인트
# 090355 노루페인트우
# 090360 로보스타
# 090370 메타랩스
# 090410 덕신하우징
# 090430 아모레퍼시픽
# 090435 아모레퍼시픽우
# 090460 비에이치
# 090470 제이스텍
# 090710 디에스티로봇
# 090740 연이정보통신
# 090850 이지웰페어
# 091090 세원셀론텍
# 091120 이엠텍
# 091340 S&K폴리텍
# 091440 텔레필드
# 091580 상신이디피
# 091590 남화토건
# 091700 파트론
# 091810 티웨이항공
# 091970 나노캠텍
# 091990 셀트리온헬스케어
# 092040 아미코젠
# 092070 디엔에프
# 092130 이크레더블
# 092200 디아이씨
# 092220 KEC
# 092230 KPX홀딩스
# 092300 현우산업
# 092440 기신정기
# 092460 한라IMS
# 092600 넥스트칩
# 092730 네오팜
# 092780 동양피스톤
# 092870 엑시콘
# 093050 LF
# 093190 빅솔론
# 093230 이아이디
# 093240 형지엘리트
# 093320 케이아이엔엑스
# 093370 후성
# 093380 풍강
# 093520 매커스
# 093640 다믈멀티미디어
# 093920 서원인텍
# 094170 동운아나텍
# 094190 이엘케이
# 094280 효성ITX
# 094360 칩스앤미디어
# 094480 갤럭시아컴즈
# 094800 맵스리얼티1
# 094820 일진파워
# 094840 슈프리마에이치큐
# 094850 참좋은여행
# 094860 코닉글로리
# 094940 푸른기술
# 094970 제이엠티
# 095190 이엠코리아
# 095270 웨이브일렉트로
# 095340 ISC
# 095500 미래나노텍
# 095570 AJ네트웍스
# 095610 테스
# 095660 네오위즈
# 095700 제넥신
# 095720 웅진씽크빅
# 095910 에스에너지
# 096040 이트론
# 096240 청담러닝
# 096300 베트남개발1
# 096350 대창솔루션
# 096530 씨젠
# 096610 알에프세미
# 096630 에스코넥
# 096640 멜파스
# 096690 제이스테판
# 096760 JW홀딩스
# 096770 SK이노베이션
# 096775 SK이노베이션우
# 096870 엘디티
# 097230 한진중공업
# 097520 엠씨넥스
# 097780 에스맥
# 097800 윈팩
# 097870 효성오앤비
# 097950 CJ제일제당
# 097955 CJ제일제당 우
# 098120 마이크로컨텍솔
# 098460 고영
# 098660 에스티오
# 099190 아이센스
# 099220 SDN
# 099320 쎄트렉아이
# 099340 하나니켈1호
# 099350 하나니켈2호
# 099410 동방선기
# 099440 스맥
# 099520 ITX엠투엠
# 100030 모바일리더
# 100090 삼강엠앤티
# 100120 뷰웍스
# 100130 동국S&C
# 100220 비상교육
# 100250 진양홀딩스
# 100590 머큐리
# 100660 서암기계공업
# 100700 세운메디칼
# 100840 S&TC
# 101000 디엠씨
# 101060 SBS미디어홀딩스
# 101140 아티스
# 101160 월덱스
# 101170 우림기계
# 101240 씨큐브
# 101330 모베이스
# 101390 아이엠
# 101400 엔시트론
# 101490 에스앤에스텍
# 101530 해태제과식품
# 101670 코리아에스이
# 101680 한국정밀기계
# 101730 조이맥스
# 101930 인화정공
# 102120 어보브반도체
# 102210 해덕파워웨이
# 102260 동성코퍼레이션
# 102280 쌍방울
# 102460 이연제약
# 102710 이엔에프테크놀로지
# 102940 코오롱생명과학
# 103130 웅진에너지
# 103140 풍산
# 103230 에스앤더블류
# 103590 일진전기
# 104040 대성파인텍
# 104200 NHN벅스
# 104460 동양피엔에프
# 104480 티케이케미칼
# 104540 코렌텍
# 104700 한국철강
# 104830 원익머트리얼즈
# 105330 케이엔더블유
# 105550 트루윈
# 105560 KB금융
# 105630 한세실업
# 105740 디케이락
# 105840 우진
# 106080 지투하이소닉
# 106190 하이텍팜
# 106240 파인테크닉스
# 106520 디지탈옵틱
# 107590 미원홀딩스
# 108230 톱텍
# 108320 실리콘웍스
# 108380 대양전기공업
# 108490 로보티즈
# 108670 LG하우시스
# 108675 LG하우시스우
# 108790 인터파크
# 108860 셀바스AI
# 109070 컨버즈
# 109080 옵티시스
# 109610 에스와이패널
# 109740 디에스케이
# 109820 진매트릭스
# 109860 동일금속
# 109960 에이프로젠 H&G
# 110020 전진바이오팜
# 110790 크리스에프앤씨
# 110990 디아이티
# 111110 호전실업
# 111710 남화산업
# 111770 영원무역
# 111820 지와이커머스
# 111870 삼본정밀전자
# 112040 위메이드
# 112240 에스에프씨
# 112610 씨에스윈드
# 113810 디젠스
# 114090 GKL
# 114120 크루셜텍
# 114190 웰크론강원
# 114450 KPX생명과학
# 114570 지스마트글로벌
# 114630 우노앤컴퍼니
# 114810 아이원스
# 115160 휴맥스
# 115180 큐리언트
# 115310 인포바인
# 115390 락앤락
# 115440 우리넷
# 115450 지트리비앤티
# 115480 씨유메디칼
# 115500 케이씨에스
# 115530 씨엔플러스
# 115570 스타플렉스
# 115610 이미지스
# 115960 연우
# 117580 대성에너지
# 117670 알파홀딩스
# 117730 티로보틱스
# 118000 우리들휴브레인
# 118990 모트렉스
# 119500 포메탈
# 119610 인터로조
# 119650 KC코트렐
# 119830 아이텍반도체
# 119850 지엔씨에너지
# 119860 다나와
# 120030 조선선재
# 120110 코오롱인더
# 120115 코오롱인더우
# 120240 대정화금
# 121440 골프존뉴딘홀딩스
# 121600 나노신소재
# 121800 비덴트
# 121850 코이즈
# 121890 에스디시스템
# 122310 제노레이
# 122350 삼기오토모티브
# 122450 KMH
# 122640 예스티
# 122690 서진오토모티브
# 122800 썬텍
# 122870 와이지엔터테인먼트
# 122900 아이마켓코리아
# 122990 와이솔
# 123010 옵토팩
# 123040 엠에스오토텍
# 123100 원익테라세미콘
# 123260 STC
# 123330 제닉
# 123410 코리아에프티
# 123420 선데이토즈
# 123570 이엠넷
# 123690 한국화장품
# 123700 SJM
# 123750 알톤스포츠
# 123840 한일진공
# 123860 아나패스
# 123890 한국자산신탁
# 124500 아이티센
# 126560 현대에이치씨엔
# 126600 코프라
# 126640 화신정공
# 126700 하이비젼시스템
# 126870 뉴로스
# 126880 제이엔케이히터
# 127120 디엔에이링크
# 127160 매직마이크로
# 127710 아시아경제
# 128540 에코캡
# 128660 피제이메탈
# 128820 대성산업
# 128940 한미약품
# 129260 인터지스
# 130500 GH신소재
# 130580 나이스디앤비
# 130660 한전산업
# 130740 티피씨글로벌
# 131030 디에이치피코리아
# 131090 시큐브
# 131100 리켐
# 131180 딜리
# 131220 대한과학
# 131290 티에스이
# 131370 알서포트
# 131390 피앤이솔루션
# 131400 액트
# 131760 파인텍
# 131970 테스나
# 133750 메가엠디
# 133820 화인베스틸
# 134060 이퓨쳐
# 134380 미원화학
# 134580 디엠티
# 134780 화진
# 134790 시디즈
# 136480 하림
# 136490 선진
# 136510 쎄미시스코
# 136540 윈스
# 137400 피엔티
# 137940 넥스트아이
# 137950 제이씨케미칼
# 138040 메리츠금융지주
# 138070 신진에스엠
# 138080 오이솔루션
# 138250 엔에스쇼핑
# 138360 에이씨티
# 138490 코오롱플라스틱
# 138580 비즈니스온
# 138610 나이벡
# 138690 엘아이에스
# 138930 BNK금융지주
# 139050 데일리블록체인
# 139130 DGB금융지주
# 139480 이마트
# 139670 넥스트리밍
# 140070 서플러스글로벌
# 140410 메지온
# 140520 대창스틸
# 140670 알에스오토메이션
# 140860 파크시스템스
# 140890 트러스제7호
# 140910 에이리츠
# 141000 비아트론
# 141020 포티스
# 141070 맥스로텍
# 141080 레고켐바이오
# 142210 유니트론텍
# 142280 녹십자엠에스
# 142760 바이오리더스
# 143160 아이디스
# 143210 핸즈코퍼레이션
# 143240 사람인에이치알
# 143540 영우디에스피
# 144510 녹십자랩셀
# 144620 코오롱머티리얼
# 144960 뉴파워프라즈마
# 145020 휴젤
# 145210 세화아이엠씨
# 145270 케이탑리츠
# 145720 덴티움
# 145990 삼양사
# 145995 삼양사우
# 147760 마이크로프랜드
# 147830 제룡산업
# 148140 비디아이
# 148250 알엔투테크놀로지
# 149940 모다
# 149950 아바텍
# 149980 하이로닉
# 150840 인트로메딕
# 150900 파수닷컴
# 151860 KG ETS
# 151910 나노스
# 152330 코리아오토글라스
# 152550 한국ANKOR유전
# 153360 하이골드3호
# 153460 네이블
# 153490 우리이앤엘
# 153710 옵티팜
# 154030 아시아종묘
# 154040 솔루에타
# 155650 와이엠씨
# 155660 DSR
# 155900 바다로19호
# 156100 엘앤케이바이오
# 158310 인터불스
# 159580 제로투세븐
# 159650 하이골드8호
# 159910 스킨앤스킨
# 160550 NEW
# 160600 에스엔텍
# 160980 싸이맥스
# 161000 애경유화
# 161390 한국타이어
# 161570 THE MIDONG
# 161580 필옵틱스
# 161890 한국콜마
# 163560 동일고무벨트
# 166090 하나머티리얼즈
# 166480 코아스템
# 168330 내츄럴엔도텍
# 168490 한국패러랠
# 170030 현대공업
# 170790 파이오링크
# 170900 동아에스티
# 170920 엘티씨
# 171010 램테크놀러지
# 171090 선익시스템
# 171120 라이온켐텍
# 172580 하이골드12호
# 173130 오파스넷
# 173940 에프엔씨엔터
# 174880 장원테크
# 174900 앱클론
# 175140 인포마크
# 175250 아이큐어
# 175330 JB금융지주
# 176440 에이치엔티
# 177350 베셀
# 177830 파버나인
# 178320 서진시스템
# 178780 유테크
# 178920 SKC코오롱PI
# 179290 엠아이텍
# 179900 유티아이
# 180400 캔서롭
# 180640 한진칼
# 181340 이즈미디어
# 181710 NHN엔터테인먼트
# 182360 큐브엔터
# 182400 에이티젠
# 182690 테라셈
# 183190 아세아시멘트
# 183300 코미코
# 183490 엔지켐생명과학
# 184230 SGA솔루션즈
# 185490 아이진
# 185750 종근당
# 187220 디티앤씨
# 187270 신화콘텍
# 187420 제노포커스
# 187790 나노
# 187870 디바이스이엔지
# 189300 인텔리안테크
# 189690 포시에스
# 189860 서전기전
# 189980 흥국에프엔비
# 190510 나무가
# 191410 육일씨엔에쓰
# 191420 테고사이언스
# 192080 더블유게임즈
# 192250 케이사인
# 192390 윈하이텍
# 192400 쿠쿠홀딩스
# 192410 감마누
# 192440 슈피겐코리아
# 192820 코스맥스
# 193250 와이제이엠게임즈
# 194370 제이에스코퍼레이션
# 194480 데브시스터즈
# 194510 파티게임즈
# 194700 노바렉스
# 195440 퓨전데이타
# 195870 해성디에스
# 195990 유지인트
# 196170 알테오젠
# 196300 애니젠
# 196450 텔루스
# 196490 디에이테크놀로지
# 196700 웹스
# 197140 디지캡
# 197210 리드
# 198440 고려시멘트
# 200130 콜마비앤에이치
# 200230 텔콘RF제약
# 200470 하이셈
# 200670 휴메딕스
# 200710 에이디테크놀로지
# 200780 비씨월드제약
# 200880 서연이화
# 201490 미투온
# 203450 유니온커뮤니티
# 203650 드림시큐리티
# 203690 프로스테믹스
# 204020 엠코르셋
# 204210 모두투어리츠
# 204320 만도
# 204620 글로벌텍스프리
# 204630 화이브라더스코리아
# 204840 지엘팜텍
# 204990 현성바이탈
# 205100 엑셈
# 205470 휴마시스
# 205500 액션스퀘어
# 206400 엔터메이트
# 206560 덱스터
# 206640 바디텍메드
# 206650 유바이오로직스
# 207760 미스터블루
# 207940 삼성바이오로직스
# 208140 정다운
# 208340 파멥신
# 208350 지란지교시큐리티
# 208370 셀바스헬스케어
# 208640 썸에이지
# 208710 바이오로그디바이스
# 208860 엔지스테크널러지
# 210540 디와이파워
# 210980 SK디앤디
# 211270 AP위성
# 212560 네오오토
# 213090 미래테크놀로지
# 213420 덕산네오룩스
# 213500 한솔제지
# 214150 클래시스
# 214180 민앤지
# 214270 퓨쳐스트림네트웍스
# 214310 세미콘라이트
# 214320 이노션
# 214330 금호에이치티
# 214370 케어젠
# 214390 경보제약
# 214420 토니모리
# 214430 아이쓰리시스템
# 214450 파마리서치프로덕트
# 214680 디알텍
# 214870 에치디프로
# 215000 골프존
# 215090 한컴유니맥스
# 215100 로보로보
# 215200 메가스터디교육
# 215360 우리산업
# 215380 우정바이오
# 215480 토박스코리아
# 215600 신라젠
# 215790 이노인스트루먼트
# 216050 인크로스
# 217190 제너셈
# 217270 넵튠
# 217330 싸이토젠
# 217480 에스디생명공학
# 217500 러셀
# 217600 켐온
# 217620 디딤
# 217730 강스템바이오텍
# 217820 엔에스
# 218150 미래생명자원
# 218410 RFHIC
# 219130 타이거일렉
# 219420 링크제니시스
# 219550 MP한강
# 219750 지티지웰니스
# 220100 퓨쳐켐
# 220180 핸디소프트
# 220260 켐트로스
# 220630 해마로푸드서비스
# 221610 한솔씨앤피
# 221840 하이즈항공
# 221980 케이디켐
# 222040 뉴트리바이오텍
# 222080 씨아이에스
# 222110 팬젠
# 222420 쎄노텍
# 222800 심텍
# 222810 한류AI센터
# 222980 한국맥널티
# 223310 이에스브이
# 224060 코디엠
# 224110 에이텍티앤
# 225190 삼양옵틱스
# 225330 씨엠에스에듀
# 225430 케이엠제약
# 225530 보광산업
# 225570 넷게임즈
# 225590 패션플랫폼
# 225650 쿠첸
# 226320 잇츠한불
# 226340 본느
# 226350 아이엠텍
# 226360 이엑스티
# 226400 오스테오닉
# 226440 한송네오텍
# 226950 올릭스
# 227100 디자인
# 227610 아우딘퓨쳐스
# 227840 현대코퍼레이션홀딩스
# 227950 마이크로텍
# 228340 동양파일
# 228850 레이언스
# 229640 LS전선아시아
# 230240 에치에프알
# 230360 에코마케팅
# 230980 솔트웍스
# 232140 와이아이케이
# 232330 SK3호스팩
# 234080 JW생명과학
# 234100 세원
# 234300 에스트래픽
# 234920 자이글
# 236200 슈프리마
# 237690 에스티팜
# 237750 피앤씨테크
# 237880 클리오
# 238090 앤디포스
# 238120 로고스바이오
# 238200 비피도
# 238490 힘스
# 239340 미래에셋제5호스팩
# 239610 에이치엘사이언스
# 240540 한국4호스팩
# 240810 원익IPS
# 241520 DSC인베스트먼트
# 241560 두산밥캣
# 241590 화승엔터프라이즈
# 241690 유니테크노
# 241710 코스메카코리아
# 241770 메카로
# 241790 오션브릿지
# 241820 피씨엘
# 242040 나무기술
# 243070 휴온스
# 243840 신흥에스이씨
# 245620 EDGC
# 246690 티에스인베스트먼트
# 246710 티앤알바이오팹
# 246720 아스타
# 248170 샘표식품
# 249420 일동제약
# 250000 보라티알
# 250060 모비스
# 250930 케이비제10호스팩
# 251270 넷마블
# 251370 와이엠티
# 251630 브이원텍
# 252500 세화피앤씨
# 253450 스튜디오드래곤
# 253590 대신밸런스제3호스팩
# 254120 IBKS제5호스팩
# 255220 SG
# 255440 야스
# 256630 엔에이치스팩10호
# 256840 엔에이치스팩11호
# 256940 케이피에스
# 257370 명성티엔에스
# 257730 신한제3호스팩
# 258610 이더블유케이
# 258790 케이비제11호스팩
# 258830 세종메디칼
# 259630 엠플러스
# 260660 알리코제약
# 260930 씨티케이코스메틱스
# 261200 하나금융9호스팩
# 262830 대신밸런스제4호스팩
# 263020 디케이앤디
# 263050 유틸렉스
# 263540 샘코
# 263600 덕우전자
# 263690 디알젬
# 263700 케어랩스
# 263720 디앤씨미디어
# 263750 펄어비스
# 263770 유에스티
# 263800 데이타솔루션
# 263810 상신전자
# 263860 지니언스
# 263920 에스엔피월드
# 264290 한화에이스스팩3호
# 264450 유비쿼스
# 264660 씨앤지하이테크
# 264850 IBKS제6호스팩
# 264900 크라운제과
# 265480 미래에셋대우스팩1호
# 265520 AP시스템
# 265560 영화테크
# 265920 한화수성스팩
# 267250 현대중공업지주
# 267260 현대일렉트릭
# 267270 현대건설기계
# 267290 경동도시가스
# 267320 교보7호스팩
# 267790 배럴
# 267850 아시아나IDT
# 267980 매일유업
# 268280 미원에스씨
# 268600 셀리버리
# 269620 시스웍
# 270520 하나금융10호스팩
# 270870 뉴트리
# 271560 오리온
# 271740 한국제5호스팩
# 271980 제일약품
# 272290 이녹스첨단소재
# 272450 진에어
# 272550 삼양패키징
# 273060 엔에이치스팩12호
# 275630 에스에스알
# 276920 IBKS제7호스팩
# 277070 린드먼아시아
# 277410 인산가
# 277480 신한제4호스팩
# 279410 한화에이스스팩4호
# 280360 롯데제과
# 281410 한국제6호스팩
# 281740 동부스팩5호
# 281820 케이씨텍
# 282330 BGF리테일
# 282690 동아타이어
# 284620 하나금융11호스팩
# 284740 쿠쿠홈시스
# 285130 SK케미칼
# 285490 노바텍
# 286940 롯데정보통신
# 287410 유안타제3호스팩
# 288620 에스퓨얼셀
# 289080 SV인베스트먼트
# 290120 대유에이피
# 290270 휴네시온
# 290380 대유
# 290550 디케이티
# 290650 엘앤씨바이오
# 290660 네오펙트
# 290670 대보마그네틱
# 290720 푸드나무
# 290740 액트로
# 291210 한국제7호스팩
# 291230 삼성스팩2호
# 293480 하나제약
# 293580 나우아이비캐피탈
# 293940 신한알파리츠
# 294870 HDC현대산업개발
# 297570 IBKS제9호스팩
# 298000 효성화학
# 298020 효성티앤씨
# 298040 효성중공업
# 298050 효성첨단소재
# 298380 에이비엘바이오
# 298690 에어부산
# 299170 IBKS제10호스팩
# 299900 위지윅스튜디오
# 299910 베스파
# 300720 한일시멘트
# 302430 이노메트리
# 303030 대신밸런스제5호스팩
# 306200 세아제강
# 306620 DB금융스팩6호
# 307070 SK4호스팩
# 307160 하나머스트제6호스팩
# 307180 신영스팩4호
# 307280 교보8호스팩
# 307750 대신밸런스제6호스팩
# 307870 골든브릿지이안5호
# 309930 삼성머스트스팩3호
# 310200 미래에셋대우스팩2호
# 310840 엔에이치스팩13호
# 310870 한국제8호스팩
# 311270 키움제5호스팩
# 900040 차이나그레이트
# 900070 글로벌에스엠
# 900080 에스앤씨엔진그룹
# 900100 뉴프라이드
# 900110 이스트아시아홀딩스
# 900120 씨케이에이치
# 900140 엘브이엠씨홀딩스
# 900250 크리스탈신소재
# 900260 로스웰
# 900270 헝셩그룹
# 900280 골든센츄리
# 900290 GRT
# 900300 오가닉티코스메틱
# 900310 컬러레이
# 900340 윙입푸드
# 950110 SBI핀테크솔루션즈
# 950130 엑세스바이오
# 950140 잉글우드랩
# 950160 코오롱티슈진
# 950170 JTC

# %%
# KOSPI_STOCK PRICE TO MYSQL

import pandas as pd
import FinanceDataReader as fdr
import sqlalchemy 
import pymysql
pymysql.install_as_MySQLdb() # MySQLdb와 호환 
import MySQLdb

engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
conn = engine.connect()

df=pd.read_excel('d:\\moneytrend.xlsx')
df.columns=['Date', '고객예탁금', '신용잔고','주식형펀드','혼합형펀드','채권형펀드']
df = df.set_index('Date')        
df.to_sql(name='moneytrend', con=engine, if_exists='append')
df
# Out:
#              고객예탁금    신용잔고   주식형펀드   혼합형펀드    채권형펀드
# Date
# 2019-02-07  282083   98843  884180  275677  1040890
# 2019-02-08  251816   98875  885919  275367  1041711
# 2019-02-11  266626   99418  884835  275458  1045127
# 2019-02-12  250298   99283  880588  275405  1046784
# 2019-02-13  261868   99495  879901  275190  1047133
# 2019-02-14  249473  100523  879451  275172  1048776

# %%
df = pd.read_excel('d:\\kkang.xlsx')
df
# Out:
#         종목코드         종목명
# 0     010040        한국내화
# 1     010050        우리종금
# 2     010060         OCI
# 3     010100       한국프랜지
# 4     010120        LS산전
# 5     010130        고려아연
# 6     010140       삼성중공업
# 7     010145       삼성중공우
# 8     010400     우진아이엔에스
# 9     010420       한솔PNS
# 10    010580          지코
# 11    010600       웰바이오텍
# 12    010620      현대미포조선
# 13    010640        진양폴리
# 14    010660        화천기계
# 15    010690          화신
# 16    010770       평화홀딩스
# 17    010780      아이에스동서
# 18    010820         퍼스텍
# 19    010950       S-Oil
# 20    010955      S-Oil우
# 21    010960        삼호개발
# 22    011000      진원생명과학
# 23    011070       LG이노텍
# 24    011090         에넥스
# 25    011150       CJ씨푸드
# 26    011155     CJ씨푸드1우
# 27    011160        두산건설
# 28    011170       롯데케미칼
# 29    011200        현대상선
# ...      ...         ...
# 1772  307070      SK4호스팩
# 1773  307160  하나머스트제6호스팩
# 1774  307180      신영스팩4호
# 1775  307280      교보8호스팩
# 1776  307750  대신밸런스제6호스팩
# 1777  307870   골든브릿지이안5호
# 1778  309930   삼성머스트스팩3호
# 1779  310200  미래에셋대우스팩2호
# 1780  310840   엔에이치스팩13호
# 1781  310870     한국제8호스팩
# 1782  311270     키움제5호스팩
# 1783  900040     차이나그레이트
# 1784  900070      글로벌에스엠
# 1785  900080    에스앤씨엔진그룹
# 1786  900100       뉴프라이드
# 1787  900110   이스트아시아홀딩스
# 1788  900120      씨케이에이치
# 1789  900250     크리스탈신소재
# 1790  900260         로스웰
# 1791  900270        헝셩그룹
# 1792  900280       골든센츄리
# 1793  900290         GRT
# 1794  900300    오가닉티코스메틱
# 1795  900310        컬러레이
# 1796  900340        윙입푸드
# 1797  950110  SBI핀테크솔루션즈
# 1798  950130      엑세스바이오
# 1799  950140       잉글우드랩
# 1800  950160      코오롱티슈진
# 1801  950170         JTC
#
# [1802 rows x 2 columns]

# %%
import pandas as pd
import FinanceDataReader as fdr
import sqlalchemy 
import pymysql
pymysql.install_as_MySQLdb() # MySQLdb와 호환 
import MySQLdb

engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
conn = engine.connect()

data = pd.read_excel('d:\\market_list.xlsx')

code_list = data['종목코드'].tolist()
code_list = [str(item).zfill(6) for item in code_list]
name_list = data['종목명'].tolist()

# 코스피 상장종목 전체
stock_dic = dict(list(zip(code_list,name_list)))

for code in sorted(stock_dic.keys()):
    df  = fdr.DataReader(code,'2019-02-22')
    print(code,stock_dic[code])
    df['Code'],df['Name'] = code,stock_dic[code]
    df = df[['Code','Name','Open','High','Low','Volume','Close']]
    df.to_sql(name='market', con=engine, if_exists='append')
# Out:
# 000020 동화약품
# 000030 우리은행
# 000040 KR모터스
# 000050 경방
# 000060 메리츠화재
# 000070 삼양홀딩스
# 000075 삼양홀딩스우
# 000080 하이트진로
# 000087 하이트진로2우B
# 000100 유한양행
# 000105 유한양행우
# 000120 CJ대한통운
# 000140 하이트진로홀딩스
# 000145 하이트진로홀딩스우
# 000150 두산
# 000155 두산우
# 000157 두산2우B
# 000180 성창기업지주
# 000210 대림산업
# 000215 대림산업우
# 000220 유유제약
# 000225 유유제약1우
# 000227 유유제약2우B
# 000230 일동홀딩스
# 000240 한국타이어월드와이드
# 000250 삼천당제약
# 000270 기아차
# 000300 대유플러스
# 000320 노루홀딩스
# 000325 노루홀딩스우
# 000370 한화손해보험
# 000390 삼화페인트
# 000400 롯데손해보험
# 000430 대원강업
# 000440 중앙에너비스
# 000480 조선내화
# 000490 대동공업
# 000500 가온전선
# 000520 삼일제약
# 000540 흥국화재
# 000545 흥국화재우
# 000547 흥국화재2우B
# 000590 CS홀딩스
# 000640 동아쏘시오홀딩스
# 000650 천일고속
# 000660 SK하이닉스
# 000670 영풍
# 000680 LS네트웍스
# 000700 유수홀딩스
# 000720 현대건설
# 000725 현대건설우
# 000760 이화산업
# 000810 삼성화재
# 000815 삼성화재우
# 000850 화천기공
# 000860 강남제비스코
# 000880 한화
# 000885 한화우
# 000890 보해양조
# 000910 유니온
# 000950 전방
# 000970 한국주철관
# 000990 DB하이텍
# 000995 DB하이텍1우
# 001000 신라섬유
# 001020 페이퍼코리아
# 001040 CJ
# 001045 CJ우
# 001060 JW중외제약
# 001065 JW중외제약우
# 001067 JW중외제약2우B
# 001070 대한방직
# 001080 만호제강
# 001120 LG상사
# 001130 대한제분
# 001140 국보
# 001200 유진투자증권
# 001210 금호전기
# 001230 동국제강
# 001250 GS글로벌
# 001260 남광토건
# 001270 부국증권
# 001275 부국증권우
# 001290 골든브릿지증권
# 001340 백광산업
# 001360 삼성제약
# 001380 SG충방
# 001390 KG케미칼
# 001420 태원물산
# 001430 세아베스틸
# 001440 대한전선
# 001450 현대해상
# 001460 BYC
# 001465 BYC우
# 001470 삼부토건
# 001500 현대차증권
# 001510 SK증권
# 001515 SK증권우
# 001520 동양
# 001525 동양우
# 001527 동양2우B
# 001529 동양3우B
# 001530 동일방직
# 001540 안국약품
# 001550 조비
# 001560 제일연마
# 001570 금양
# 001620 동국실업
# 001630 종근당홀딩스
# 001680 대상
# 001685 대상우
# 001720 신영증권
# 001725 신영증권우
# 001740 SK네트웍스
# 001745 SK네트웍스우
# 001750 한양증권
# 001755 한양증권우
# 001770 신화실업
# 001780 알루코
# 001790 대한제당
# 001795 대한제당우
# 001799 대한제당3우B
# 001800 오리온홀딩스
# 001810 무림SP
# 001820 삼화콘덴서
# 001840 이화공영
# 001880 삼호
# 001940 KISCO홀딩스
# 002020 코오롱
# 002025 코오롱우
# 002030 아세아
# 002070 남영비비안
# 002100 경농
# 002140 고려산업
# 002150 도화엔지니어링
# 002170 삼양통상
# 002200 수출포장
# 002210 동성제약
# 002220 한일철강
# 002230 피에스텍
# 002240 고려제강
# 002250 알보젠코리아
# 002270 롯데푸드
# 002290 삼일기업공사
# 002300 한국제지
# 002310 아세아제지
# 002320 한진
# 002350 넥센타이어
# 002355 넥센타이어1우B
# 002360 SH에너지화학
# 002380 KCC
# 002390 한독
# 002410 범양건영
# 002420 세기상사
# 002450 삼익악기
# 002460 화성산업
# 002600 조흥
# 002620 제일파마홀딩스
# 002630 오리엔트바이오
# 002680 한탑
# 002690 동일제강
# 002700 신일산업
# 002710 TCC동양
# 002720 국제약품
# 002760 보락
# 002780 진흥기업
# 002785 진흥기업우B
# 002787 진흥기업2우B
# 002790 아모레G
# 002795 아모레G우
# 002800 신신제약
# 002810 삼영무역
# 002820 선창산업
# 002840 미원상사
# 002870 신풍제지
# 002880 대유에이텍
# 002900 동양물산
# 002920 유성기업
# 002960 한국쉘석유
# 002990 금호산업
# 002995 금호산업우
# 003000 부광약품
# 003010 혜인
# 003030 세아제강지주
# 003060 에이프로젠제약
# 003070 코오롱글로벌
# 003075 코오롱글로벌우
# 003080 성보화학
# 003090 대웅
# 003100 선광
# 003120 일성신약
# 003160 디아이
# 003200 일신방직
# 003220 대원제약
# 003230 삼양식품
# 003240 태광산업
# 003280 흥아해운
# 003300 한일홀딩스
# 003310 대주산업
# 003350 한국화장품제조
# 003380 하림지주
# 003410 쌍용양회
# 003415 쌍용양회우
# 003460 유화증권
# 003465 유화증권우
# 003470 유안타증권
# 003475 유안타증권우
# 003480 한진중공업홀딩스
# 003490 대한항공
# 003495 대한항공우
# 003520 영진약품
# 003530 한화투자증권
# 003535 한화투자증권우
# 003540 대신증권
# 003545 대신증권우
# 003547 대신증권2우B
# 003550 LG
# 003555 LG우
# 003560 IHQ
# 003570 S&T중공업
# 003580 넥스트사이언스
# 003610 방림
# 003620 쌍용차
# 003650 미창석유
# 003670 포스코켐텍
# 003680 한성기업
# 003690 코리안리
# 003720 삼영화학
# 003780 진양산업
# 003800 에이스침대
# 003830 대한화섬
# 003850 보령제약
# 003920 남양유업
# 003925 남양유업우
# 003960 사조대림
# 004000 롯데정밀화학
# 004020 현대제철
# 004060 SG세계물산
# 004080 신흥
# 004090 한국석유
# 004100 태양금속
# 004105 태양금속우
# 004140 동방
# 004150 한솔홀딩스
# 004170 신세계
# 004200 고려개발
# 004250 NPC
# 004255 NPC우
# 004270 남성
# 004310 현대약품
# 004360 세방
# 004365 세방우
# 004370 농심
# 004380 삼익THK
# 004410 서울식품
# 004415 서울식품우
# 004430 송원산업
# 004440 대림씨엔에스
# 004450 삼화왕관
# 004490 세방전지
# 004540 깨끗한나라
# 004545 깨끗한나라우
# 004560 현대비앤지스틸
# 004565 현대비앤지스틸우
# 004590 한국가구
# 004650 창해에탄올
# 004690 삼천리
# 004700 조광피혁
# 004710 한솔테크닉스
# 004720 우리들제약
# 004770 써니전자
# 004780 대륙제관
# 004800 효성
# 004830 덕성
# 004835 덕성우
# 004840 DRB동일
# 004870 티웨이홀딩스
# 004890 동일산업
# 004910 조광페인트
# 004920 씨아이테크
# 004960 한신공영
# 004970 신라교역
# 004980 성신양회
# 004985 성신양회우
# 004987 성신양회2우B
# 004989 성신양회3우B
# 004990 롯데지주
# 005010 휴스틸
# 005030 부산주공
# 005070 코스모신소재
# 005090 삼광글라스
# 005110 한창
# 005160 동국산업
# 005180 빙그레
# 005190 동성화학
# 005250 녹십자홀딩스
# 005257 녹십자홀딩스2우
# 005290 동진쎄미켐
# 005300 롯데칠성
# 005305 롯데칠성우
# 005320 국동
# 005360 모나미
# 005380 현대차
# 005385 현대차우
# 005387 현대차2우B
# 005389 현대차3우B
# 005390 신성통상
# 005420 코스모화학
# 005430 한국공항
# 005440 현대그린푸드
# 005450 신한
# 005490 POSCO
# 005500 삼진제약
# 005610 SPC삼립
# 005670 푸드웰
# 005680 삼영전자
# 005690 파미셀
# 005710 대원산업
# 005720 넥센
# 005725 넥센우
# 005740 크라운해태홀딩스
# 005745 크라운해태홀딩스우
# 005750 대림B&Co
# 005800 신영와코루
# 005810 풍산홀딩스
# 005820 원림
# 005830 DB손해보험
# 005850 에스엘
# 005860 한일사료
# 005870 휴니드
# 005880 대한해운
# 005930 삼성전자
# 005935 삼성전자우
# 005940 NH투자증권
# 005945 NH투자증권우
# 005950 이수화학
# 005960 동부건설
# 005965 동부건설우
# 005990 매일홀딩스
# 006040 동원산업
# 006050 국영지앤엠
# 006060 화승인더
# 006090 사조오양
# 006110 삼아알미늄
# 006120 SK디스커버리
# 006125 SK디스커버리우
# 006140 피제이전자
# 006200 한국전자홀딩스
# 006220 제주은행
# 006260 LS
# 006280 녹십자
# 006340 대원전선
# 006345 대원전선우
# 006360 GS건설
# 006370 대구백화점
# 006380 카프로
# 006390 한일현대시멘트
# 006400 삼성SDI
# 006405 삼성SDI우
# 006490 인스코비
# 006570 대림통상
# 006580 대양제지
# 006620 동구바이오제약
# 006650 대한유화
# 006660 삼성공조
# 006730 서부T&D
# 006740 영풍제지
# 006800 미래에셋대우
# 006805 미래에셋대우우
# 006840 AK홀딩스
# 006880 신송홀딩스
# 006890 태경화학
# 006910 보성파워텍
# 006920 모헨즈
# 006980 우성사료
# 007070 GS리테일
# 007110 일신석재
# 007120 미래아이앤지
# 007160 사조산업
# 007210 벽산
# 007280 한국특수형강
# 007310 오뚜기
# 007330 푸른저축은행
# 007340 디티알오토모티브
# 007370 진양제약
# 007390 네이처셀
# 007460 에이프로젠 KIC
# 007530 영신금속
# 007540 샘표
# 007570 일양약품
# 007575 일양약품우
# 007590 동방아그로
# 007610 선도전기
# 007630 폴루스바이오팜
# 007660 이수페타시스
# 007680 대원
# 007690 국도화학
# 007700 F&F
# 007720 대명코퍼레이션
# 007770 한일화학
# 007810 코리아써키트
# 007815 코리아써우
# 007820 에스엠코어
# 007860 서연
# 007980 태평양물산
# 008040 사조동아원
# 008060 대덕전자
# 008110 대동전자
# 008250 이건산업
# 008260 NI스틸
# 008290 원풍물산
# 008350 남선알미늄
# 008355 남선알미우
# 008370 원풍
# 008420 문배철강
# 008470 부스타
# 008490 서흥
# 008500 일정실업
# 008560 메리츠종금증권
# 008600 윌비스
# 008700 아남전자
# 008730 율촌화학
# 008770 호텔신라
# 008775 호텔신라우
# 008800 행남사
# 008830 대동기어
# 008870 금비
# 008930 한미사이언스
# 008970 동양철관
# 009070 KCTC
# 009140 경인전자
# 009150 삼성전기
# 009155 삼성전기우
# 009160 SIMPAC
# 009180 한솔로지스틱스
# 009190 대양금속
# 009200 무림페이퍼
# 009240 한샘
# 009270 신원
# 009275 신원우
# 009290 광동제약
# 009300 삼아제약
# 009310 참엔지니어링
# 009320 대우부품
# 009410 태영건설
# 009415 태영건설우
# 009420 한올바이오파마
# 009440 KC그린홀딩스
# 009450 경동나비엔
# 009460 한창제지
# 009470 삼화전기
# 009520 포스코엠텍
# 009540 현대중공업
# 009580 무림P&P
# 009620 삼보산업
# 009680 모토닉
# 009730 코센
# 009770 삼정펄프
# 009780 엠에스씨
# 009810 엔케이물산
# 009830 한화케미칼
# 009835 한화케미칼우
# 009970 영원무역홀딩스
# 010040 한국내화
# 010050 우리종금
# 010060 OCI
# 010100 한국프랜지
# 010120 LS산전
# 010130 고려아연
# 010140 삼성중공업
# 010145 삼성중공우
# 010170 대한광통신
# 010240 흥국
# 010280 쌍용정보통신
# 010400 우진아이엔에스
# 010420 한솔PNS
# 010470 오리콤
# 010580 지코
# 010600 웰바이오텍
# 010620 현대미포조선
# 010640 진양폴리
# 010660 화천기계
# 010690 화신
# 010770 평화홀딩스
# 010780 아이에스동서
# 010820 퍼스텍
# 010950 S-Oil
# 010955 S-Oil우
# 010960 삼호개발
# 011000 진원생명과학
# 011040 경동제약
# 011070 LG이노텍
# 011080 형지I&C
# 011090 에넥스
# 011150 CJ씨푸드
# 011155 CJ씨푸드1우
# 011160 두산건설
# 011170 롯데케미칼
# 011200 현대상선
# 011210 현대위아
# 011230 삼화전자
# 011280 태림포장
# 011300 성안
# 011320 유니크
# 011330 유니켐
# 011370 서한
# 011390 부산산업
# 011420 갤럭시아에스엠
# 011500 한농화성
# 011560 세보엠이씨
# 011690 유양디앤유
# 011700 한신기계
# 011760 현대상사
# 011780 금호석유
# 011785 금호석유우
# 011790 SKC
# 011810 STX
# 011930 신성이엔지
# 012030 DB
# 012160 영흥철강
# 012170 키위미디어그룹
# 012200 계양전기
# 012205 계양전기우
# 012280 영화금속
# 012320 경동인베스트
# 012330 현대모비스
# 012340 뉴인텍
# 012450 한화에어로스페이스
# 012510 더존비즈온
# 012600 청호컴넷
# 012610 경인양행
# 012620 원일특강
# 012630 HDC
# 012690 모나리자
# 012700 리드코프
# 012750 에스원
# 012790 신일제약
# 012800 대창
# 012860 서연전자
# 013000 세우글로벌
# 013030 하이록코리아
# 013120 동원개발
# 013310 아진산업
# 013360 일성건설
# 013520 화승알앤에이
# 013570 디와이
# 013580 계룡건설
# 013700 까뮤이앤씨
# 013720 청보산업
# 013810 스페코
# 013870 지엠비코리아
# 013990 아가방컴퍼니
# 014100 보령메디앙스
# 014130 한익스프레스
# 014160 대영포장
# 014190 원익큐브
# 014200 광림
# 014280 금강공업
# 014285 금강공업우
# 014440 영보화학
# 014470 부방
# 014530 극동유화
# 014570 고려제약
# 014580 백광소재
# 014620 성광벤드
# 014680 한솔케미칼
# 014710 사조씨푸드
# 014790 한라
# 014820 동원시스템즈
# 014825 동원시스템즈우
# 014830 유니드
# 014910 성문전자
# 014915 성문전자우
# 014940 오리엔탈정공
# 014970 삼륭물산
# 014990 인디에프
# 015020 이스타코
# 015230 대창단조
# 015260 에이엔피
# 015350 부산가스
# 015360 예스코홀딩스
# 015540 메디플란트
# 015590 큐로
# 015710 코콤
# 015750 성우하이텍
# 015760 한국전력
# 015860 일진홀딩스
# 015890 태경산업
# 016090 대현
# 016100 리더스코스메틱
# 016250 이테크건설
# 016360 삼성증권
# 016380 동부제철
# 016385 동부제철우
# 016450 한세예스24홀딩스
# 016580 환인제약
# 016590 신대양제지
# 016600 큐캐피탈
# 016610 DB금융투자
# 016670 포비스티앤씨
# 016710 대성홀딩스
# 016740 두올
# 016790 현대사료
# 016800 퍼시스
# 016880 웅진
# 016920 카스
# 017000 신원종합개발
# 017040 광명전기
# 017180 명문제약
# 017250 인터엠
# 017370 우신시스템
# 017390 서울가스
# 017480 삼현철강
# 017510 세명전기
# 017550 수산중공업
# 017650 대림제지
# 017670 SK텔레콤
# 017680 데코앤이
# 017800 현대엘리베이
# 017810 풀무원
# 017890 한국알콜
# 017900 광전자
# 017940 E1
# 017960 한국카본
# 018000 유니슨
# 018120 진로발효
# 018250 애경산업
# 018260 삼성에스디에스
# 018290 지엠피
# 018310 삼목에스폼
# 018470 조일알미늄
# 018500 동원금속
# 018620 우진비앤지
# 018670 SK가스
# 018680 서울제약
# 018700 바른손
# 018880 한온시스템
# 019010 그랜드백화점
# 019170 신풍제약
# 019175 신풍제약우
# 019180 티에이치엔
# 019210 와이지-원
# 019440 세아특수강
# 019490 하이트론
# 019540 일지테크
# 019550 SBI인베스트먼트
# 019570 제미니투자
# 019590 엠벤처투자
# 019660 글로본
# 019680 대교
# 019685 대교우B
# 019770 서연탑메탈
# 019990 에너토크
# 020000 한섬
# 020120 키다리스튜디오
# 020150 일진머티리얼즈
# 020180 대신정보통신
# 020400 대동금속
# 020560 아시아나항공
# 020710 시공테크
# 020760 일진디스플
# 021040 대호피앤씨
# 021045 대호피앤씨우
# 021050 서원
# 021080 에이티넘인베스트
# 021240 코웨이
# 021320 KCC건설
# 021650 한국큐빅
# 021820 세원정공
# 021880 메이슨캐피탈
# 022100 포스코 ICT
# 022220 정산애강
# 023000 삼원강재
# 023150 MH에탄올
# 023160 태광
# 023350 한국종합기술
# 023410 유진기업
# 023440 제일제강
# 023450 동남합성
# 023460 CNH
# 023530 롯데쇼핑
# 023590 다우기술
# 023600 삼보판지
# 023760 한국캐피탈
# 023770 플레이위드
# 023790 동일철강
# 023800 인지컨트롤스
# 023810 인팩
# 023890 아트라스BX
# 023900 풍국주정
# 023910 대한약품
# 023960 에쓰씨엔지니어링
# 024060 흥구석유
# 024070 WISCOM
# 024090 디씨엠
# 024110 기업은행
# 024120 KB오토시스
# 024720 한국콜마홀딩스
# 024740 한일단조
# 024800 유성티엔에스
# 024810 이화전기
# 024830 세원물산
# 024840 갑을메탈
# 024850 피에스엠씨
# 024880 케이피에프
# 024890 대원화성
# 024900 덕양산업
# 024910 경창산업
# 024940 PN풍년
# 024950 삼천리자전거
# 025000 KPX케미칼
# 025320 시노펙스
# 025440 대성엘텍
# 025530 SJM홀딩스
# 025540 한국단자
# 025550 한국선재
# 025560 미래산업
# 025620 제이준코스메틱
# 025750 한솔홈데코
# 025770 한국정보통신
# 025820 이구산업
# 025860 남해화학
# 025870 신라에스지
# 025880 케이씨피드
# 025890 한국주강
# 025900 동화기업
# 025950 동신건설
# 025980 아난티
# 026040 제이에스티나
# 026150 특수건설
# 026180 현대정보기술
# 026890 디피씨
# 026910 광진실업
# 026940 부국철강
# 026960 동서
# 027040 서울전자통신
# 027050 코리아나
# 027360 아주IB투자
# 027390 한화갤러리아타임월드
# 027410 BGF
# 027580 상보
# 027710 팜스토리
# 027740 마니커
# 027830 대성창투
# 027970 세하
# 028040 미래SCI
# 028050 삼성엔지니어링
# 028080 휴맥스홀딩스
# 028100 동아지질
# 028150 GS홈쇼핑
# 028260 삼성물산
# 028300 에이치엘비
# 028670 팬오션
# 029460 케이씨
# 029480 바른테크놀로지
# 029530 신도리코
# 029780 삼성카드
# 029960 코엔텍
# 030000 제일기획
# 030190 NICE평가정보
# 030200 KT
# 030210 KTB투자증권
# 030270 에스마크
# 030350 드래곤플라이
# 030520 한글과컴퓨터
# 030530 원익홀딩스
# 030610 교보증권
# 030720 동원수산
# 030790 동양네트웍스
# 030960 양지사
# 031310 아이즈비전
# 031330 에스에이엠티
# 031390 녹십자셀
# 031430 신세계인터내셔날
# 031440 신세계푸드
# 031510 오스템
# 031820 콤텍시스템
# 031860 엔에스엔
# 031980 피에스케이
# 032080 아즈텍WB
# 032190 다우데이타
# 032280 삼일
# 032350 롯데관광개발
# 032500 케이엠더블유
# 032540 TJ미디어
# 032560 황금에스티
# 032580 피델릭스
# 032620 유비케어
# 032640 LG유플러스
# 032680 소프트센
# 032685 소프트센우
# 032750 삼진
# 032790 엠젠플러스
# 032800 판타지오
# 032820 우리기술
# 032830 삼성생명
# 032850 비트컴퓨터
# 032860 GMR 머티리얼즈
# 032940 원익
# 032960 동일기연
# 032980 바이온
# 033050 제이엠아이
# 033100 제룡전기
# 033110 이디
# 033130 디지틀조선
# 033160 엠케이전자
# 033170 시그네틱스
# 033180 필룩스
# 033200 모아텍
# 033230 인성정보
# 033240 자화전자
# 033250 체시스
# 033270 유나이티드제약
# 033290 코웰패션
# 033310 디케이디앤아이
# 033320 제이씨현시스템
# 033340 좋은사람들
# 033430 디에스티
# 033500 동성화인텍
# 033530 세종공업
# 033540 파라텍
# 033560 블루콤
# 033600 에이코넬
# 033640 네패스
# 033660 아주캐피탈
# 033780 KT&G
# 033790 스카이문스테크놀로지
# 033830 티비씨
# 033920 무학
# 034020 두산중공업
# 034120 SBS
# 034220 LG디스플레이
# 034230 파라다이스
# 034300 신세계건설
# 034310 NICE
# 034590 인천도시가스
# 034730 SK
# 034810 해성산업
# 034830 한국토지신탁
# 034940 조아제약
# 034950 한국기업평가
# 035000 지투알
# 035080 인터파크홀딩스
# 035150 백산
# 035200 프럼파스트
# 035250 강원랜드
# 035290 더블유에프엠
# 035420 NAVER
# 035460 기산텔레콤
# 035480 마제스타
# 035510 신세계 I&C
# 035600 KG이니시스
# 035610 솔본
# 035620 바른손이앤에이
# 035720 카카오
# 035760 CJ ENM
# 035810 이지바이오
# 035890 서희건설
# 035900 JYP Ent.
# 036000 예림당
# 036010 아비코전자
# 036030 KTH
# 036090 위지트
# 036120 SCI평가정보
# 036170 씨티젠
# 036180 영인프런티어
# 036190 금화피에스시
# 036200 유니셈
# 036260 이매진아시아
# 036420 제이콘텐트리
# 036460 한국가스공사
# 036480 대성미생물
# 036490 SK머티리얼즈
# 036530 S&T홀딩스
# 036540 SFA반도체
# 036560 영풍정밀
# 036570 엔씨소프트
# 036580 팜스코
# 036620 버추얼텍
# 036630 세종텔레콤
# 036640 HRS
# 036670 KCI
# 036690 코맥스
# 036710 심텍홀딩스
# 036800 나이스정보통신
# 036810 에프에스티
# 036830 솔브레인
# 036890 진성티이씨
# 036930 주성엔지니어링
# 037030 파워넷
# 037070 파세코
# 037230 한국팩키지
# 037270 YG PLUS
# 037330 인지디스플레
# 037350 성도이엔지
# 037370 EG
# 037400 우리조명
# 037440 희림
# 037460 삼지전자
# 037560 CJ헬로
# 037710 광주신세계
# 037760 쎄니트
# 037950 엘컴텍
# 038010 제일테크노스
# 038060 루멘스
# 038070 서린바이오
# 038110 에코플라스틱
# 038160 팍스넷
# 038290 마크로젠
# 038340 UCI
# 038390 레드캡투어
# 038460 바이오스마트
# 038500 삼표시멘트
# 038530 골드퍼시픽
# 038540 상상인
# 038620 위즈코프
# 038680 에스넷
# 038870 에코바이오
# 038880 아이에이
# 038950 파인디지털
# 039010 현대통신
# 039020 이건홀딩스
# 039030 이오테크닉스
# 039130 하나투어
# 039200 오스코텍
# 039230 에이아이비트
# 039240 경남스틸
# 039290 인포뱅크
# 039310 세중
# 039340 한국경제TV
# 039420 케이엘넷
# 039440 에스티아이
# 039490 키움증권
# 039560 다산네트웍스
# 039570 HDC아이콘트롤스
# 039610 화성밸브
# 039670 스포츠서울
# 039740 한국정보공학
# 039830 오로라
# 039840 디오
# 039860 나노엔텍
# 039980 리노스
# 040160 누리텔레콤
# 040300 YTN
# 040350 큐로컴
# 040420 정상제이엘에스
# 040610 SG&G
# 040910 아이씨디
# 041020 인프라웨어
# 041140 넥슨지티
# 041190 우리기술투자
# 041440 에버다임
# 041460 한국전자인증
# 041510 에스엠
# 041520 이라이콤
# 041590 에너전트
# 041650 상신브레이크
# 041830 인바디
# 041910 에스텍파마
# 041920 메디아나
# 041930 동아화성
# 041960 코미팜
# 042000 카페24
# 042040 케이피엠테크
# 042110 에스씨디
# 042370 비츠로테크
# 042420 네오위즈홀딩스
# 042500 링네트
# 042510 라온시큐어
# 042520 한스바이오메드
# 042600 새로닉스
# 042660 대우조선해양
# 042670 두산인프라코어
# 042700 한미반도체
# 042940 상지카일룸
# 043090 팜스웰바이오
# 043100 솔고바이오
# 043150 바텍
# 043200 파루
# 043220 에이치엘비파워
# 043260 성호전자
# 043290 케이맥
# 043340 에쎈테크
# 043360 디지아이
# 043370 평화정공
# 043590 크로바하이텍
# 043610 지니뮤직
# 043650 국순당
# 043710 서울리거
# 043910 자연과환경
# 044060 조광ILI
# 044180 KD건설
# 044340 위닉스
# 044380 주연테크
# 044450 KSS해운
# 044480 바이오제네틱스
# 044490 태웅
# 044780 에이치케이
# 044820 코스맥스비티아이
# 044960 이글벳
# 044990 에이치엔에스하이텍
# 045060 오공
# 045100 한양이엔지
# 045300 성우테크론
# 045340 토탈소프트
# 045390 대아티아이
# 045510 정원엔시스
# 045520 크린앤사이언스
# 045660 에이텍
# 045890 GV
# 045970 코아시아홀딩스
# 046070 코다코
# 046110 한일네트웍스
# 046120 오르비텍
# 046140 SBS콘텐츠허브
# 046210 파나진
# 046310 백금T&A
# 046390 삼화네트웍스
# 046440 KG모빌리언스
# 046890 서울반도체
# 046940 우원개발
# 046970 우리로
# 047040 대우건설
# 047050 포스코대우
# 047080 한빛소프트
# 047310 파워로직스
# 047400 유니온머티리얼
# 047560 이스트소프트
# 047770 코데즈컴바인
# 047810 한국항공우주
# 047820 초록뱀
# 047920 씨트리
# 048260 오스템임플란트
# 048410 현대바이오
# 048430 유라테크
# 048470 대동스틸
# 048530 인트론바이오
# 048550 SM C&C
# 048770 TPC
# 048830 엔피케이
# 048870 시너지이노베이션
# 048910 대원미디어
# 049070 인탑스
# 049080 기가레인
# 049120 파인디앤씨
# 049180 셀루메드
# 049430 코메론
# 049470 SGA
# 049480 오픈베이스
# 049520 유아이엘
# 049550 잉크테크
# 049630 재영솔루텍
# 049720 고려신용정보
# 049770 동원F&B
# 049800 우진플라임
# 049830 승일
# 049950 미래컴퍼니
# 049960 쎌바이오텍
# 050090 휘닉스소재
# 050110 캠시스
# 050120 라이브플렉스
# 050320 에이앤티앤
# 050540 한국코퍼레이션
# 050760 에스폴리텍
# 050860 아세아텍
# 050890 쏠리드
# 050960 수산아이앤티
# 051160 지어소프트
# 051360 토비스
# 051370 인터플렉스
# 051380 피씨디렉트
# 051390 YW
# 051490 나라엠앤디
# 051500 CJ프레시웨이
# 051600 한전KPS
# 051630 진양화학
# 051780 큐로홀딩스
# 051900 LG생활건강
# 051905 LG생활건강우
# 051910 LG화학
# 051915 LG화학우
# 051980 중앙리빙테크
# 052020 에스티큐브
# 052190 이에스에이
# 052220 iMBC
# 052260 SK바이오랜드
# 052300 W홀딩컴퍼니
# 052330 코텍
# 052400 코나아이
# 052420 오성첨단소재
# 052460 아이크래프트
# 052600 한네트
# 052670 제일바이오
# 052690 한전기술
# 052710 아모텍
# 052770 와이디온라인
# 052790 액토즈소프트
# 052860 아이앤씨
# 052900 KMH하이텍
# 053030 바이넥스
# 053050 지에스이
# 053060 세동
# 053110 소리바다
# 053160 프리엠스
# 053210 스카이라이프
# 053260 금강철강
# 053270 구영테크
# 053280 예스24
# 053290 NE능률
# 053300 한국정보인증
# 053350 이니텍
# 053450 세코닉스
# 053580 웹케시
# 053590 한국테크놀로지
# 053610 프로텍
# 053620 태양
# 053660 현진소재
# 053690 한미글로벌
# 053700 삼보모터스
# 053800 안랩
# 053950 경남제약
# 053980 오상자이엘
# 054040 한국컴퓨터
# 054050 농우바이오
# 054090 삼진엘앤디
# 054180 중앙오션
# 054210 이랜텍
# 054220 비츠로시스
# 054300 팬스타엔터프라이즈
# 054340 피앤텔
# 054410 케이피티유
# 054450 텔레칩스
# 054540 삼영엠텍
# 054620 APS홀딩스
# 054630 에이디칩스
# 054670 대한뉴팜
# 054780 키이스트
# 054800 아이디스홀딩스
# 054920 한컴시큐어
# 054930 유신
# 054940 엑사이엔씨
# 054950 제이브이엠
# 055490 테이팩스
# 055550 신한지주
# 056000 신스타임즈
# 056080 유진로봇
# 056090 유앤아이
# 056190 에스에프에이
# 056360 코위버
# 056700 신화인터텍
# 056730 포스링크
# 057030 와이비엠넷
# 057050 현대홈쇼핑
# 057500 SKC 솔믹스
# 057540 옴니시스템
# 057680 옴니텔
# 057880 토필드
# 058110 멕아이씨에스
# 058220 아리온
# 058400 KNN
# 058420 제이웨이
# 058430 포스코강판
# 058450 일야
# 058470 리노공업
# 058530 슈펙스비앤피
# 058610 에스피지
# 058630 엠게임
# 058650 세아홀딩스
# 058730 다스코
# 058820 CMG제약
# 058850 KTcs
# 058860 케이티스
# 058970 엠로
# 059090 미코
# 059100 아이컴포넌트
# 059120 아진엑스텍
# 059210 메타바이오메드
# 060150 인선이엔티
# 060230 이그잭스
# 060240 룽투코리아
# 060250 NHN한국사이버결제
# 060260 뉴보텍
# 060280 큐렉소
# 060300 레드로버
# 060310 3S
# 060370 KT서브마린
# 060380 동양에스텍
# 060480 국일신동
# 060540 에스에이티
# 060560 홈센타홀딩스
# 060570 아이리버
# 060590 씨티씨바이오
# 060720 KH바텍
# 060900 퍼시픽바이오
# 060980 한라홀딩스
# 061040 알에프텍
# 061250 화일약품
# 061970 엘비세미콘
# 062860 티엘아이
# 063080 게임빌
# 063160 종근당바이오
# 063170 서울옥션
# 063440 SM Life Design
# 063570 한국전자금융
# 063760 이엘피
# 064090 에프앤리퍼블릭
# 064240 홈캐스트
# 064260 다날
# 064290 인텍플러스
# 064350 현대로템
# 064480 브리지텍
# 064510 에코마이스터
# 064520 바른전자
# 064550 바이오니아
# 064760 티씨케이
# 064800 필링크
# 064820 케이프
# 064850 에프앤가이드
# 064960 S&T모티브
# 065060 지엔코
# 065130 탑엔지니어링
# 065150 MP그룹
# 065160 에프티이앤이
# 065170 넥스트BT
# 065350 신성델타테크
# 065370 위세아이텍
# 065420 에스아이리소스
# 065440 이루온
# 065450 빅텍
# 065500 오리엔트정공
# 065510 휴비츠
# 065530 전파기지국
# 065560 녹원씨엔아이
# 065570 삼영이엔씨
# 065620 제낙스
# 065650 메디프론
# 065660 안트로젠
# 065680 우주일렉트로
# 065690 대진디엠피
# 065710 서호전기
# 065770 CS
# 065940 바이오빌
# 065950 웰크론
# 066110 한프
# 066130 하츠
# 066310 큐에스아이
# 066360 체리부로
# 066410 버킷스튜디오
# 066430 와이오엠
# 066570 LG전자
# 066575 LG전자우
# 066590 우수AMS
# 066620 국보디자인
# 066670 디스플레이텍
# 066700 테라젠이텍스
# 066790 씨씨에스
# 066830 제노텍
# 066900 디에이피
# 066910 손오공
# 066970 엘앤에프
# 066980 브레인콘텐츠
# 067000 조이시티
# 067010 이씨에스
# 067080 대화제약
# 067160 아프리카TV
# 067170 오텍
# 067280 멀티캠퍼스
# 067290 JW신약
# 067310 하나마이크론
# 067370 선바이오
# 067390 아스트
# 067570 엔브이에이치코리아
# 067630 에이치엘비생명과학
# 067730 로지시스
# 067770 세진티에스
# 067830 세이브존I&C
# 067900 와이엔텍
# 067920 이글루시큐리티
# 067990 도이치모터스
# 068050 팬엔터테인먼트
# 068240 다원시스
# 068270 셀트리온
# 068290 삼성출판사
# 068330 일신바이오
# 068400 AJ렌터카
# 068760 셀트리온제약
# 068790 DMS
# 068930 디지털대성
# 068940 아이씨케이
# 069080 웹젠
# 069110 코스온
# 069140 누리플랜
# 069260 휴켐스
# 069330 유아이디
# 069410 엔텔스
# 069460 대호에이엘
# 069510 에스텍
# 069540 라이트론
# 069620 대웅제약
# 069640 한세엠케이
# 069730 DSR제강
# 069920 아이에스이커머스
# 069960 현대백화점
# 070300 한솔시큐어
# 070590 한솔인티큐브
# 070960 용평리조트
# 071050 한국금융지주
# 071055 한국금융지주우
# 071090 하이스틸
# 071200 인피니트헬스케어
# 071280 로체시스템즈
# 071320 지역난방공사
# 071460 대유위니아
# 071670 에이테크솔루션
# 071840 롯데하이마트
# 071850 캐스텍코리아
# 071950 코아스
# 071970 STX중공업
# 072020 중앙백신
# 072130 유엔젤
# 072470 우리산업홀딩스
# 072520 제넨바이오
# 072710 농심홀딩스
# 072770 네오디안테크놀로지
# 072870 메가스터디
# 072950 빛샘전자
# 072990 에이치시티
# 073010 케이에스피
# 073070 에스모
# 073110 엘엠에스
# 073190 듀오백
# 073240 금호타이어
# 073490 이노와이어리스
# 073540 에프알텍
# 073560 우리손에프앤지
# 073570 피엠지파마
# 073640 삼원테크
# 074430 아미노로직스
# 074600 원익QnC
# 074610 나노메딕스
# 075130 플랜티넷
# 075180 새론오토모티브
# 075580 세진중공업
# 075970 동국알앤에스
# 076080 웰크론한텍
# 076340 관악산업
# 076610 해성옵틱스
# 077280 한컴지엠디
# 077360 덕산하이메탈
# 077500 유니퀘스트
# 077970 STX엔진
# 078000 텔코웨어
# 078020 이베스트투자증권
# 078070 유비쿼스홀딩스
# 078130 국일제지
# 078140 대봉엘에스
# 078150 HB테크놀러지
# 078160 메디포스트
# 078340 컴투스
# 078350 한양디지텍
# 078520 에이블씨엔씨
# 078590 두올산업
# 078600 대주전자재료
# 078650 코렌
# 078860 아이오케이
# 078890 가온미디어
# 078930 GS
# 078935 GS우
# 078940 일경산업개발
# 079000 와토스코리아
# 079160 CJ CGV
# 079170 한창산업
# 079190 EMW
# 079370 제우스
# 079430 현대리바트
# 079440 오렌지라이프
# 079550 LIG넥스원
# 079650 서산
# 079660 사조해표
# 079810 디이엔티
# 079940 가비아
# 079950 인베니아
# 079960 동양이엔피
# 079970 투비소프트
# 079980 휴비스
# 080000 에스엔유
# 080010 이상네트웍스
# 080160 모두투어
# 080220 제주반도체
# 080420 모다이노칩
# 080440 에스제이케이
# 080470 성창오토텍
# 080520 오디텍
# 080530 코디
# 080580 오킨스전자
# 080720 한국유니온제약
# 081000 일진다이아
# 081150 티플랙스
# 081580 성우전자
# 081660 휠라코리아
# 082210 옵트론텍
# 082270 젬백스
# 082640 동양생명
# 082660 삼우엠스
# 082740 HSD엔진
# 082800 루미마이크로
# 082850 우리이티아이
# 082920 비츠로셀
# 083310 엘오티베큠
# 083370 동북아12호
# 083380 동북아13호
# 083420 그린케미칼
# 083450 GST
# 083470 KJ프리텍
# 083500 에프엔에스테크
# 083550 케이엠
# 083640 인콘
# 083650 비에이치아이
# 083660 CSA 코스믹
# 083790 크리스탈
# 083930 아바코
# 084010 대한제강
# 084110 휴온스글로벌
# 084180 수성
# 084370 유진테크
# 084440 유비온
# 084650 랩지노믹스
# 084670 동양고속
# 084680 이월드
# 084690 대상홀딩스
# 084695 대상홀딩스우
# 084730 팅크웨어
# 084870 TBH글로벌
# 084990 바이로메드
# 085310 엔케이
# 085370 루트로닉
# 085620 미래에셋생명
# 085660 차바이오텍
# 085670 뉴프렉스
# 085810 알티캐스트
# 085910 네오티스
# 086040 바이오톡스텍
# 086060 진바이오텍
# 086080 다이노나
# 086220 네추럴FNP
# 086250 화신테크
# 086280 현대글로비스
# 086390 유니테스트
# 086450 동국제약
# 086460 에스엔피제네틱스
# 086520 에코프로
# 086670 비엠티
# 086790 하나금융지주
# 086820 바이오솔루션
# 086890 이수앱지스
# 086900 메디톡스
# 086960 한컴MDS
# 086980 쇼박스
# 087010 펩트론
# 087260 모바일어플라이언스
# 087600 픽셀플러스
# 087730 네패스신소재
# 088130 동아엘텍
# 088260 이리츠코크렙
# 088290 이원컴포텍
# 088350 한화생명
# 088390 이녹스
# 088790 진도
# 088800 에이스테크
# 088910 동우팜투테이블
# 088980 맥쿼리인프라
# 089010 켐트로닉스
# 089030 테크윙
# 089140 넥스턴
# 089150 케이씨티
# 089230 THE E&M
# 089470 HDC현대EP
# 089530 에이티세미콘
# 089590 제주항공
# 089600 나스미디어
# 089790 제이티
# 089850 유비벨록스
# 089890 코세스
# 089970 에이피티씨
# 089980 상아프론테크
# 090080 평화산업
# 090150 광진윈텍
# 090350 노루페인트
# 090355 노루페인트우
# 090360 로보스타
# 090370 메타랩스
# 090410 덕신하우징
# 090430 아모레퍼시픽
# 090435 아모레퍼시픽우
# 090460 비에이치
# 090470 제이스텍
# 090710 디에스티로봇
# 090740 연이정보통신
# 090850 이지웰페어
# 091090 세원셀론텍
# 091120 이엠텍
# 091340 S&K폴리텍
# 091440 텔레필드
# 091580 상신이디피
# 091590 남화토건
# 091700 파트론
# 091810 티웨이항공
# 091970 나노캠텍
# 091990 셀트리온헬스케어
# 092040 아미코젠
# 092070 디엔에프
# 092130 이크레더블
# 092200 디아이씨
# 092220 KEC
# 092230 KPX홀딩스
# 092300 현우산업
# 092440 기신정기
# 092460 한라IMS
# 092590 럭스피아
# 092600 넥스트칩
# 092730 네오팜
# 092780 동양피스톤
# 092870 엑시콘
# 093050 LF
# 093190 빅솔론
# 093230 이아이디
# 093240 형지엘리트
# 093320 케이아이엔엑스
# 093370 후성
# 093380 풍강
# 093520 매커스
# 093640 다믈멀티미디어
# 093920 서원인텍
# 094170 동운아나텍
# 094190 이엘케이
# 094280 효성ITX
# 094360 칩스앤미디어
# 094480 갤럭시아컴즈
# 094800 맵스리얼티1
# 094820 일진파워
# 094840 슈프리마에이치큐
# 094850 참좋은여행
# 094860 코닉글로리
# 094940 푸른기술
# 094970 제이엠티
# 095190 이엠코리아
# 095270 웨이브일렉트로
# 095340 ISC
# 095500 미래나노텍
# 095570 AJ네트웍스
# 095610 테스
# 095660 네오위즈
# 095700 제넥신
# 095720 웅진씽크빅
# 095910 에스에너지
# 096040 이트론
# 096240 청담러닝
# 096300 베트남개발1
# 096350 대창솔루션
# 096530 씨젠
# 096610 알에프세미
# 096630 에스코넥
# 096640 멜파스
# 096690 제이스테판
# 096760 JW홀딩스
# 096770 SK이노베이션
# 096775 SK이노베이션우
# 096870 엘디티
# 097230 한진중공업
# 097520 엠씨넥스
# 097780 에스맥
# 097800 윈팩
# 097870 효성오앤비
# 097950 CJ제일제당
# 097955 CJ제일제당 우
# 098120 마이크로컨텍솔
# 098460 고영
# 098660 에스티오
# 099190 아이센스
# 099220 SDN
# 099320 쎄트렉아이
# 099340 하나니켈1호
# 099350 하나니켈2호
# 099410 동방선기
# 099440 스맥
# 099520 ITX엠투엠
# 100030 모바일리더
# 100090 삼강엠앤티
# 100120 뷰웍스
# 100130 동국S&C
# 100220 비상교육
# 100250 진양홀딩스
# 100590 머큐리
# 100660 서암기계공업
# 100700 세운메디칼
# 100840 S&TC
# 101000 디엠씨
# 101060 SBS미디어홀딩스
# 101140 아티스
# 101160 월덱스
# 101170 우림기계
# 101240 씨큐브
# 101330 모베이스
# 101360 이엔드디
# 101390 아이엠
# 101400 엔시트론
# 101490 에스앤에스텍
# 101530 해태제과식품
# 101670 코리아에스이
# 101680 한국정밀기계
# 101730 조이맥스
# 101930 인화정공
# 102120 어보브반도체
# 102210 해덕파워웨이
# 102260 동성코퍼레이션
# 102280 쌍방울
# 102460 이연제약
# 102710 이엔에프테크놀로지
# 102940 코오롱생명과학
# 103130 웅진에너지
# 103140 풍산
# 103230 에스앤더블류
# 103590 일진전기
# 103660 씨앗
# 104040 대성파인텍
# 104200 NHN벅스
# 104460 동양피엔에프
# 104480 티케이케미칼
# 104540 코렌텍
# 104620 노랑풍선
# 104700 한국철강
# 104830 원익머트리얼즈
# 105330 케이엔더블유
# 105550 트루윈
# 105560 KB금융
# 105630 한세실업
# 105740 디케이락
# 105840 우진
# 106080 지투하이소닉
# 106190 하이텍팜
# 106240 파인테크닉스
# 106520 디지탈옵틱
# 107590 미원홀딩스
# 107640 한중엔시에스
# 108230 톱텍
# 108320 실리콘웍스
# 108380 대양전기공업
# 108490 로보티즈
# 108670 LG하우시스
# 108675 LG하우시스우
# 108790 인터파크
# 108860 셀바스AI
# 109070 컨버즈
# 109080 옵티시스
# 109610 에스와이패널
# 109740 디에스케이
# 109820 진매트릭스
# 109860 동일금속
# 109960 에이프로젠 H&G
# 110020 전진바이오팜
# 110790 크리스에프앤씨
# 110990 디아이티
# 111110 호전실업
# 111710 남화산업
# 111770 영원무역
# 111820 지와이커머스
# 111870 삼본정밀전자
# 112040 위메이드
# 112190 KC산업
# 112240 에스에프씨
# 112610 씨에스윈드
# 113810 디젠스
# 114090 GKL
# 114120 크루셜텍
# 114190 웰크론강원
# 114450 KPX생명과학
# 114570 지스마트글로벌
# 114630 우노앤컴퍼니
# 114810 아이원스
# 114920 대주이엔티
# 115160 휴맥스
# 115180 큐리언트
# 115310 인포바인
# 115390 락앤락
# 115440 우리넷
# 115450 지트리비앤티
# 115480 씨유메디칼
# 115500 케이씨에스
# 115530 씨엔플러스
# 115570 스타플렉스
# 115610 이미지스
# 115960 연우
# 116100 태양기계
# 117580 대성에너지
# 117670 알파홀딩스
# 117730 티로보틱스
# 118000 우리들휴브레인
# 118990 모트렉스
# 119500 포메탈
# 119610 인터로조
# 119650 KC코트렐
# 119830 아이텍반도체
# 119850 지엔씨에너지
# 119860 다나와
# 120030 조선선재
# 120110 코오롱인더
# 120115 코오롱인더우
# 120240 대정화금
# 120780 전우정밀
# 121060 유니포인트
# 121440 골프존뉴딘홀딩스
# 121600 나노신소재
# 121800 비덴트
# 121850 코이즈
# 121890 에스디시스템
# 122050 아이엘사이언스
# 122310 제노레이
# 122350 삼기오토모티브
# 122450 KMH
# 122640 예스티
# 122690 서진오토모티브
# 122800 썬텍
# 122870 와이지엔터테인먼트
# 122900 아이마켓코리아
# 122990 와이솔
# 123010 옵토팩
# 123040 엠에스오토텍
# 123100 원익테라세미콘
# 123260 STC
# 123330 제닉
# 123410 코리아에프티
# 123420 선데이토즈
# 123570 이엠넷
# 123690 한국화장품
# 123700 SJM
# 123750 알톤스포츠
# 123840 한일진공
# 123860 아나패스
# 123890 한국자산신탁
# 124500 아이티센
# 126340 비나텍
# 126560 현대에이치씨엔
# 126600 코프라
# 126640 화신정공
# 126700 하이비젼시스템
# 126870 뉴로스
# 126880 제이엔케이히터
# 127120 디엔에이링크
# 127160 매직마이크로
# 127710 아시아경제
# 128540 에코캡
# 128660 피제이메탈
# 128820 대성산업
# 128940 한미약품
# 129260 인터지스
# 130500 GH신소재
# 130580 나이스디앤비
# 130660 한전산업
# 130740 티피씨글로벌
# 131030 디에이치피코리아
# 131090 시큐브
# 131100 리켐
# 131180 딜리
# 131220 대한과학
# 131290 티에스이
# 131370 알서포트
# 131390 피앤이솔루션
# 131400 액트
# 131760 파인텍
# 131970 테스나
# 133750 메가엠디
# 133820 화인베스틸
# 134060 이퓨쳐
# 134380 미원화학
# 134580 디엠티
# 134780 화진
# 134790 시디즈
# 135160 지오씨
# 135270 세종머티리얼즈
# 136480 하림
# 136490 선진
# 136510 쎄미시스코
# 136540 윈스
# 136660 큐엠씨
# 137400 피엔티
# 137940 넥스트아이
# 137950 제이씨케미칼
# 138040 메리츠금융지주
# 138070 신진에스엠
# 138080 오이솔루션
# 138250 엔에스쇼핑
# 138360 에이씨티
# 138490 코오롱플라스틱
# 138580 비즈니스온
# 138610 나이벡
# 138690 엘아이에스
# 138930 BNK금융지주
# 139050 데일리블록체인
# 139130 DGB금융지주
# 139480 이마트
# 139670 넥스트리밍
# 140070 서플러스글로벌
# 140290 청광종건
# 140410 메지온
# 140520 대창스틸
# 140610 엔솔바이오사이언스
# 140660 위월드
# 140670 알에스오토메이션
# 140860 파크시스템스
# 140890 트러스제7호
# 140910 에이리츠
# 141000 비아트론
# 141020 포티스
# 141070 맥스로텍
# 141080 레고켐바이오
# 142210 유니트론텍
# 142280 녹십자엠에스
# 142760 바이오리더스
# 143160 아이디스
# 143210 핸즈코퍼레이션
# 143240 사람인에이치알
# 143540 영우디에스피
# 144510 녹십자랩셀
# 144620 코오롱머티리얼
# 144960 뉴파워프라즈마
# 145020 휴젤
# 145210 세화아이엠씨
# 145270 케이탑리츠
# 145720 덴티움
# 145990 삼양사
# 145995 삼양사우
# 147760 마이크로프랜드
# 147830 제룡산업
# 148140 비디아이
# 148250 알엔투테크놀로지
# 148780 비플라이소프트
# 149010 아이케이세미콘
# 149940 모다
# 149950 아바텍
# 149980 하이로닉
# 150440 피노텍
# 150840 인트로메딕
# 150900 파수닷컴
# 151860 KG ETS
# 151910 나노스
# 152330 코리아오토글라스
# 152550 한국ANKOR유전
# 153360 하이골드3호
# 153460 네이블
# 153490 우리이앤엘
# 153710 옵티팜
# 154030 아시아종묘
# 154040 솔루에타
# 155650 와이엠씨
# 155660 DSR
# 155900 바다로19호
# 156100 엘앤케이바이오
# 158300 에스에이티이엔지
# 158310 인터불스
# 159580 제로투세븐
# 159650 하이골드8호
# 159910 스킨앤스킨
# 160550 NEW
# 160600 에스엔텍
# 160980 싸이맥스
# 161000 애경유화
# 161390 한국타이어
# 161570 THE MIDONG
# 161580 필옵틱스
# 161890 한국콜마
# 162120 루켄테크놀러지스
# 163430 디피코
# 163560 동일고무벨트
# 166090 하나머티리얼즈
# 166480 코아스템
# 168330 내츄럴엔도텍
# 168490 한국패러랠
# 170030 현대공업
# 170790 파이오링크
# 170900 동아에스티
# 170920 엘티씨
# 171010 램테크놀러지
# 171090 선익시스템
# 171120 라이온켐텍
# 172580 하이골드12호
# 173130 오파스넷
# 173940 에프엔씨엔터
# 174880 장원테크
# 174900 앱클론
# 175140 인포마크
# 175250 아이큐어
# 175330 JB금융지주
# 176440 에이치엔티
# 176560 포인트엔지니어링
# 176750 듀켐바이오
# 177350 베셀
# 177830 파버나인
# 178320 서진시스템
# 178600 대동고려삼
# 178780 유테크
# 178920 SKC코오롱PI
# 179290 엠아이텍
# 179720 옐로페이
# 179900 유티아이
# 180060 탑선
# 180400 캔서롭
# 180640 한진칼
# 181340 이즈미디어
# 181710 NHN엔터테인먼트
# 182360 큐브엔터
# 182400 에이티젠
# 182690 테라셈
# 183190 아세아시멘트
# 183300 코미코
# 183350 엘피케이
# 183410 골프존데카
# 183490 엔지켐생명과학
# 184230 SGA솔루션즈
# 185190 수프로
# 185490 아이진
# 185750 종근당
# 186230 그린플러스
# 187220 디티앤씨
# 187270 신화콘텍
# 187420 제노포커스
# 187790 나노
# 187870 디바이스이엔지
# 189300 인텔리안테크
# 189330 씨이랩
# 189350 코셋
# 189540 씨티네트웍스
# 189690 포시에스
# 189860 서전기전
# 189980 흥국에프엔비
# 190510 나무가
# 191410 육일씨엔에쓰
# 191420 테고사이언스
# 191600 티케이씨
# 192080 더블유게임즈
# 192250 케이사인
# 192390 윈하이텍
# 192400 쿠쿠홀딩스
# 192410 감마누
# 192440 슈피겐코리아
# 192820 코스맥스
# 193250 와이제이엠게임즈
# 194370 제이에스코퍼레이션
# 194480 데브시스터즈
# 194510 파티게임즈
# 194700 노바렉스
# 195440 퓨전데이타
# 195870 해성디에스
# 195990 유지인트
# 196170 알테오젠
# 196300 애니젠
# 196450 텔루스
# 196490 디에이테크놀로지
# 196700 웹스
# 197140 디지캡
# 197210 리드
# 198440 고려시멘트
# 199150 데이터스트림즈
# 199290 바이오프로테크
# 199800 툴젠
# 200130 콜마비앤에이치
# 200230 텔콘RF제약
# 200350 래몽래인
# 200470 하이셈
# 200580 메디쎄이
# 200670 휴메딕스
# 200710 에이디테크놀로지
# 200780 비씨월드제약
# 200880 서연이화
# 201490 미투온
# 202960 판도라티비
# 203400 에이비온
# 203450 유니온커뮤니티
# 203650 드림시큐리티
# 203690 프로스테믹스
# 204020 엠코르셋
# 204210 모두투어리츠
# 204320 만도
# 204620 글로벌텍스프리
# 204630 화이브라더스코리아
# 204840 지엘팜텍
# 204990 현성바이탈
# 205100 엑셈
# 205290 케미메디
# 205470 휴마시스
# 205500 액션스퀘어
# 206400 엔터메이트
# 206560 덱스터
# 206640 바디텍메드
# 206650 유바이오로직스
# 206950 볼빅
# 207490 에이펙스인텍
# 207760 미스터블루
# 207940 삼성바이오로직스
# 208140 정다운
# 208340 파멥신
# 208350 지란지교시큐리티
# 208370 셀바스헬스케어
# 208640 썸에이지
# 208710 바이오로그디바이스
# 208850 이비테크
# 208860 엔지스테크널러지
# 208890 에듀파트너
# 210120 빅텐츠
# 210540 디와이파워
# 210610 소프트캠프
# 210980 SK디앤디
# 211050 인카금융서비스
# 211270 AP위성
# 212310 휴벡셀
# 212560 네오오토
# 213090 미래테크놀로지
# 213420 덕산네오룩스
# 213500 한솔제지
# 214150 클래시스
# 214180 민앤지
# 214270 퓨쳐스트림네트웍스
# 214310 세미콘라이트
# 214320 이노션
# 214330 금호에이치티
# 214370 케어젠
# 214390 경보제약
# 214420 토니모리
# 214430 아이쓰리시스템
# 214450 파마리서치프로덕트
# 214610 미코바이오메드
# 214680 디알텍
# 214870 에치디프로
# 215000 골프존
# 215050 비엔디생활건강
# 215090 한컴유니맥스
# 215100 로보로보
# 215200 메가스터디교육
# 215360 우리산업
# 215380 우정바이오
# 215480 토박스코리아
# 215570 크로넥스
# 215600 신라젠
# 215790 이노인스트루먼트
# 216050 인크로스
# 216280 원텍
# 216400 바이오코아
# 217190 제너셈
# 217270 넵튠
# 217320 썬테크
# 217330 싸이토젠
# 217480 에스디생명공학
# 217500 러셀
# 217600 켐온
# 217620 디딤
# 217730 강스템바이오텍
# 217820 엔에스
# 217880 틸론
# 217910 에스제이켐
# 217950 파마리서치바이오
# 218150 미래생명자원
# 218410 RFHIC
# 219130 타이거일렉
# 219420 링크제니시스
# 219550 MP한강
# 219750 지티지웰니스
# 220100 퓨쳐켐
# 220110 드림티엔터테인먼트
# 220180 핸디소프트
# 220250 카이노스메드
# 220260 켐트로스
# 220630 해마로푸드서비스
# 221610 한솔씨앤피
# 221670 주노콜렉션
# 221800 유투바이오
# 221840 하이즈항공
# 221980 케이디켐
# 222040 뉴트리바이오텍
# 222080 씨아이에스
# 222110 팬젠
# 222160 바이옵트로
# 222420 쎄노텍
# 222670 플럼라인생명과학
# 222800 심텍
# 222810 한류AI센터
# 222980 한국맥널티
# 223220 아이피몬스터
# 223310 이에스브이
# 224020 에스케이씨에스
# 224060 코디엠
# 224110 에이텍티앤
# 224760 엔에스컴퍼니
# 224810 엄지하우스
# 224880 SGA임베디드
# 225190 삼양옵틱스
# 225220 제놀루션
# 225330 씨엠에스에듀
# 225430 케이엠제약
# 225530 보광산업
# 225570 넷게임즈
# 225590 패션플랫폼
# 225650 쿠첸
# 225850 미애부
# 225860 엠앤씨생명과학
# 226320 잇츠한불
# 226340 본느
# 226350 아이엠텍
# 226360 이엑스티
# 226400 오스테오닉
# 226440 한송네오텍
# 226610 한국비엔씨
# 226950 올릭스
# 227100 디자인
# 227420 포레스팅블록체인
# 227610 아우딘퓨쳐스
# 227840 현대코퍼레이션홀딩스
# 227950 마이크로텍
# 228180 티씨엠생명과학
# 228340 동양파일
# 228760 지노믹트리
# 228850 레이언스
# 229000 젠큐릭스
# 229480 줌인터넷
# 229500 노브메타파마
# 229640 LS전선아시아
# 230240 에치에프알
# 230360 에코마케팅
# 230400 자비스
# 230980 솔트웍스
# 232140 와이아이케이
# 232330 SK3호스팩
# 232530 이엠티
# 232680 라온테크
# 232830 시큐센
# 233250 메디안디노스틱
# 233990 질경이
# 234070 에이원알폼
# 234080 JW생명과학
# 234100 세원
# 234300 에스트래픽
# 234920 자이글
# 236030 씨알푸드
# 236200 슈프리마
# 236340 메디젠휴먼케어
# 237690 에스티팜
# 237750 피앤씨테크
# 237880 클리오
# 238090 앤디포스
# 238120 로고스바이오
# 238200 비피도
# 238490 힘스
# 238500 로보쓰리
# 239340 미래에셋제5호스팩
# 239610 에이치엘사이언스
# 239890 피엔에이치테크
# 240340 인터코스
# 240540 한국4호스팩
# 240810 원익IPS
# 241510 이에스산업
# 241520 DSC인베스트먼트
# 241560 두산밥캣
# 241590 화승엔터프라이즈
# 241690 유니테크노
# 241710 코스메카코리아
# 241770 메카로
# 241790 오션브릿지
# 241820 피씨엘
# 242040 나무기술
# 242350 피엔아이컴퍼니
# 242850 영현무역
# 243070 휴온스
# 243840 신흥에스이씨
# 243870 굿센
# 244880 나눔테크
# 245030 스페이스솔루션
# 245450 씨앤에스링크
# 245620 EDGC
# 246250 에스엘에스바이오
# 246690 티에스인베스트먼트
# 246710 티앤알바이오팹
# 246720 아스타
# 246960 이노테라피
# 247300 인프라웨어테크놀러지
# 248170 샘표식품
# 249420 일동제약
# 250000 보라티알
# 250060 모비스
# 250300 제이에스피브이
# 250930 케이비제10호스팩
# 251270 넷마블
# 251280 안지오랩
# 251370 와이엠티
# 251630 브이원텍
# 251960 엠에프엠코리아
# 252370 유쎌
# 252500 세화피앤씨
# 253450 스튜디오드래곤
# 253590 대신밸런스제3호스팩
# 253840 수젠텍
# 254120 IBKS제5호스팩
# 255220 SG
# 255440 야스
# 256630 엔에이치스팩10호
# 256840 엔에이치스팩11호
# 256940 케이피에스
# 257370 명성티엔에스
# 257730 신한제3호스팩
# 258050 테크트랜스
# 258250 셀젠텍
# 258540 스템랩
# 258610 이더블유케이
# 258790 케이비제11호스팩
# 258830 세종메디칼
# 259630 엠플러스
# 260660 알리코제약
# 260870 시그넷이브이
# 260930 씨티케이코스메틱스
# 260970 에스앤디
# 261200 하나금융9호스팩
# 262760 엔케이맥스
# 262830 대신밸런스제4호스팩
# 263020 디케이앤디
# 263050 유틸렉스
# 263540 샘코
# 263600 덕우전자
# 263690 디알젬
# 263700 케어랩스
# 263720 디앤씨미디어
# 263750 펄어비스
# 263770 유에스티
# 263800 데이타솔루션
# 263810 상신전자
# 263860 지니언스
# 263920 에스엔피월드
# 264290 한화에이스스팩3호
# 264450 유비쿼스
# 264660 씨앤지하이테크
# 264850 IBKS제6호스팩
# 264900 크라운제과
# 265480 미래에셋대우스팩1호
# 265520 AP시스템
# 265560 영화테크
# 265920 한화수성스팩
# 266170 앤유엔터테인먼트
# 266870 파워풀엑스
# 267060 명진홀딩스
# 267250 현대중공업지주
# 267260 현대일렉트릭
# 267270 현대건설기계
# 267290 경동도시가스
# 267320 교보7호스팩
# 267790 배럴
# 267810 앙츠
# 267850 아시아나IDT
# 267980 매일유업
# 268280 미원에스씨
# 268600 셀리버리
# 269620 시스웍
# 270020 두원석재
# 270210 에스알바이오텍
# 270520 하나금융10호스팩
# 270660 에브리봇
# 270870 뉴트리
# 271400 알로이스
# 271560 오리온
# 271740 한국제5호스팩
# 271780 비엔에프코퍼레이션
# 271850 다이오진
# 271980 제일약품
# 272290 이녹스첨단소재
# 272450 진에어
# 272550 삼양패키징
# 273060 엔에이치스팩12호
# 275630 에스에스알
# 276240 엘리비젼
# 276920 IBKS제7호스팩
# 277070 린드먼아시아
# 277410 인산가
# 277480 신한제4호스팩
# 277880 티에스아이
# 278990 파인이엠텍
# 279410 한화에이스스팩4호
# 279600 미디어젠
# 280360 롯데제과
# 281310 바이오시네틱스
# 281410 한국제6호스팩
# 281740 동부스팩5호
# 281820 케이씨텍
# 282330 BGF리테일
# 282690 동아타이어
# 284420 휴럼
# 284610 TS트릴리온
# 284620 하나금융11호스팩
# 284740 쿠쿠홈시스
# 285130 SK케미칼
# 285490 노바텍
# 285770 라이프사이언스테크놀로지
# 286940 롯데정보통신
# 287410 유안타제3호스팩
# 288490 나라소프트
# 288620 에스퓨얼셀
# 289080 SV인베스트먼트
# 290120 대유에이피
# 290270 휴네시온
# 290380 대유
# 290550 디케이티
# 290650 엘앤씨바이오
# 290660 네오펙트
# 290670 대보마그네틱
# 290720 푸드나무
# 290740 액트로
# 291210 한국제7호스팩
# 291230 삼성스팩2호
# 293480 하나제약
# 293580 나우아이비캐피탈
# 293940 신한알파리츠
# 294870 HDC현대산업개발
# 297570 IBKS제9호스팩
# 298000 효성화학
# 298020 효성티앤씨
# 298040 효성중공업
# 298050 효성첨단소재
# 298380 에이비엘바이오
# 298690 에어부산
# 299170 IBKS제10호스팩
# 299480 지앤이헬스케어
# 299670 에스엠비나
# 299900 위지윅스튜디오
# 299910 베스파
# 300720 한일시멘트
# 302430 이노메트리
# 302550 리메드
# 302920 더콘텐츠온
# 303030 대신밸런스제5호스팩
# 303360 프로테옴텍
# 306200 세아제강
# 306620 DB금융스팩6호
# 307070 SK4호스팩
# 307160 하나머스트제6호스팩
# 307180 신영스팩4호
# 307280 교보8호스팩
# 307750 대신밸런스제6호스팩
# 307870 골든브릿지이안5호
# 308700 테크엔
# 309930 삼성머스트스팩3호
# 310200 미래에셋대우스팩2호
# 310840 엔에이치스팩13호
# 310870 한국제8호스팩
# 311060 엘에이티
# 311270 키움제5호스팩
# 311840 대원모방
# 314130 지놈앤컴퍼니
# 900040 차이나그레이트
# 900070 글로벌에스엠
# 900080 에스앤씨엔진그룹
# 900100 뉴프라이드
# 900110 이스트아시아홀딩스
# 900120 씨케이에이치
# 900140 엘브이엠씨홀딩스
# 900250 크리스탈신소재
# 900260 로스웰
# 900270 헝셩그룹
# 900280 골든센츄리
# 900290 GRT
# 900300 오가닉티코스메틱
# 900310 컬러레이
# 900340 윙입푸드
# 950110 SBI핀테크솔루션즈
# 950130 엑세스바이오
# 950140 잉글우드랩
# 950160 코오롱티슈진
# 950170 JTC

# %%
import pandas as pd
import FinanceDataReader as fdr
import sqlalchemy 
import pymysql

df  = fdr.DataReader('053580','2019-02-02')
df
# Out:
#              Open   High    Low  Close  Volume    Change
# Date
# 2019-02-07  25850  26700  24800  26200  237717  0.021442
# 2019-02-08  26000  26600  25750  26250  116557  0.001908
# 2019-02-11  26400  27100  26050  27000  157570  0.028571
# 2019-02-12  26950  27200  26350  26350   82215 -0.024074
# 2019-02-13  26600  27300  26200  27000   82362  0.024668
# 2019-02-14  27150  27500  26550  26600   58147 -0.014815

# %%
def excel_to_mysql():

    file_name = input('파일이름을 입력하세요:')
        
    df=pd.read_excel('d:\\'+ file_name)
    if file_name=='kpi200.xlsx':
        df.columns=['Date','kpi200','거래량']
        table_name = 'kpi200'
        
        
    elif file_name=='moneytrend.xlsx':
        table_name = 'moneytrend'
        df.columns=['Date', '고객예탁금', '신용잔고','주식형펀드','혼합형펀드','채권형펀드']
        
    elif file_name=='market.xlsx':
        table_name = 'market'
        data = pd.read_excel('d:\\market.xlsx')
        start_date = input("시작날자를 입려하세요 : sample: '2015-01-01'")

        code_list = data['종목코드'].tolist()
        code_list = [str(item).zfill(6) for item in code_list]
        name_list = data['종목명'].tolist()

        # 코스피 상장종목 전체
        stock_dic = dict(list(zip(code_list,name_list)))

        for code in sorted(stock_dic.keys()):
            df  = fdr.DataReader(code,start_date)
            print(code,stock_dic[code])
            df['Code'],df['Name'] = code,stock_dic[code]
            df = df[['Code','Name','Open','High','Low','Volume','Close']]
            df.to_sql(name='market', con=engine, if_exists='append')
        return 

    else:
        print('\n file_name error\n')
    
    df.to_sql(name=table_name, con=engine, if_exists='append', index = False)

    print(df)
excel_to_mysql()
# Out:
# 파일이름을 입력하세요:market.xlsx
# 시작날자를 입려하세요 : sample: '2015-01-01'2019-02-22
# 000020 동화약품
# 000040 KR모터스

# %%
import FinanceDataReader as fdr
import pandas as pd
from bs4 import BeautifulSoup
import datetime as dt
from datetime import datetime,timedelta
from urllib.request import urlopen
import sqlalchemy 
import pymysql
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

now = dt.datetime.today().strftime('%Y-%m-%d')
engine = sqlalchemy.create_engine('mysql+pymysql://kkang:leaf2027@localhost/stock?charset=utf8',encoding='utf-8')
conn = engine.connect()

def excel_to_mysql():

    file_name = input('파일이름을 입력하세요:')
        
    df=pd.read_excel('d:\\'+ file_name)
    if file_name=='kpi200.xlsx':
        df.columns=['Date','kpi200','거래량']
        table_name = 'kpi200'
        
        
    elif file_name=='moneytrend.xlsx':
        table_name = 'moneytrend'
        df.columns=['Date', '고객예탁금', '신용잔고','주식형펀드','혼합형펀드','채권형펀드']
        
    elif file_name=='market.xlsx':
        table_name = 'moneytrend'
        get_stock_price_from_fdr(end_date=now)
        
    else:
        print('\n file_name error\n')
    
    df.to_sql(name=table_name, con=engine, if_exists='append', index = False)

    print(df)
    
excel_to_mysql()
# Out:
# 파일이름을 입력하세요:market.xlsx
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e1020b490d39> in <module>
#      43     print(df)
#      44
# ---> 45 excel_to_mysql()
#
# <ipython-input-5-e1020b490d39> in excel_to_mysql()
#      34     elif file_name=='market.xlsx':
#      35         table_name = 'moneytrend'
# ---> 36         get_stock_price_from_fdr(end_date=now)
#      37
#      38     else:
#
# NameError: name 'get_stock_price_from_fdr' is not defined

# %%
excel_to_mysql()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7c8a5e8fc175> in <module>
# ----> 1 excel_to_mysql()
#
# NameError: name 'excel_to_mysql' is not defined
